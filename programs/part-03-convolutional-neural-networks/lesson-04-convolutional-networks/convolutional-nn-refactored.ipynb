# %% [markdown]
# # Convolutional Neural Networks

# %%
import math
import numpy as np
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %% [markdown]
# ## ConvLayerOutputShapeCalculator

# %%
class ConvLayerOutputShapeCalculator:
    
    def compute_conv_output_shape(self, 
                                  input_shape, 
                                  filter_shape, 
                                  n_filters, 
                                  stride, 
                                  padding_size):

        print('Input Shape: {}'.format(input_shape))
        print('Filter Shape: {}'.format(filter_shape))
        print('Num Filters: {}'.format(n_filters))
        print('')
        
        conv_h = self.compute_conv_height(input_shape[0], filter_shape[0], padding_size, stride)
        conv_w = self.compute_conv_width(input_shape[1], filter_shape[1], padding_size, stride)
        conv_d = n_filters
        
        print('Conv Height: {}'.format(conv_h))
        print('Conv Width: {}'.format(conv_w))
        print('Conv Depth: {}'.format(conv_d))
        print('')
        
        return (conv_h, conv_w, conv_d)
    
    def compute_conv_height(self, input_h, filter_h, p, stride):
        return int((input_h - filter_h + 2*p) / stride) + 1
    
    def compute_conv_width(self, input_w, filter_w, p, stride):
        return int((input_w - filter_w + 2*p) / stride) + 1

# %%
input_shape = [32, 32, 3]
filter_shape = [8, 8, 3]
n_filters = 20
stride = 2
padding_size = 1

calculator = ConvLayerOutputShapeCalculator()
output_shape = calculator.compute_conv_output_shape(input_shape, 
                                                    filter_shape, 
                                                    n_filters, 
                                                    stride, 
                                                    padding_size)

print('Conv Output Shape: {}'.format(output_shape))
# Out:
# Input Shape: [32, 32, 3]
# Filter Shape: [8, 8, 3]
# Num Filters: 20
#
# Conv Height: 14
# Conv Width: 14
# Conv Depth: 20
#
# Conv Output Shape: (14, 14, 20)

# %% [markdown]
# ## ConvLayerOutputShapeDemo

# %%
class ConvLayerOutputShapeDemo:
    
    def run(self, input_shape, filter_shape, n_filters, stride, padding='SAME'):        
        input = tf.placeholder(tf.float32,
                               (None, input_shape[0], input_shape[1], input_shape[2]))
        
        print('Input Shape: {}'.format(input.shape))
        print('Filter Shape: {}'.format((filter_shape[0], filter_shape[1])))
        print('Output Depth: {}'.format(n_filters))
        print('')
        
        conv_weights = tf.Variable(tf.truncated_normal(
            (filter_shape[0], filter_shape[1], input_shape[2], n_filters)))
        conv_bias = tf.Variable(tf.zeros(n_filters))
        
        print('Conv Weights Shape: {}'.format(conv_weights.shape))
        print('Conv Bias Shape: {}'.format(conv_bias.shape))
        print('')
        
        conv_strides = [1, stride, stride, 1] # (batch, height, width, depth)
        
        print('Conv Strides: {}'.format(conv_strides))
        print('')
        
        conv = tf.nn.conv2d(input, conv_weights, conv_strides, padding) + conv_bias
        
        print('Conv Output Shape ({}): {}'.format(padding, conv.shape))

# %%
demo = ConvLayerOutputShapeDemo()
demo.run(input_shape, filter_shape, n_filters, stride, padding='VALID')
# Out:
# Input Shape: (?, 32, 32, 3)
# Filter Shape: (8, 8)
# Output Depth: 20
#
# Conv Weights Shape: (8, 8, 3, 20)
# Conv Bias Shape: (20,)
#
# Conv Strides: [1, 2, 2, 1]
#
# Conv Output Shape (VALID): (?, 13, 13, 20)

# %%
demo.run(input_shape, filter_shape, n_filters, stride, padding='SAME')
# Out:
# Input Shape: (?, 32, 32, 3)
# Filter Shape: (8, 8)
# Output Depth: 20
#
# Conv Weights Shape: (8, 8, 3, 20)
# Conv Bias Shape: (20,)
#
# Conv Strides: [1, 2, 2, 1]
#
# Conv Output Shape (SAME): (?, 16, 16, 20)

# %% [markdown]
# ## ConvLayerParamNumCalculator

# %%
class ConvLayerParamNumCalculator:
    
    def compute_num_params_no_param_sharing(self,
                                            input_shape,
                                            filter_shape,
                                            n_filters,
                                            stride,
                                            p_size):
        
        num_filter_neurons = self.compute_num_filter_neurons(filter_shape)
        num_output_neurons = self.compute_num_output_neurons(input_shape, 
                                                             filter_shape, 
                                                             n_filters, 
                                                             stride, 
                                                             p_size)
        return int(num_filter_neurons * num_output_neurons)
    
    def compute_num_params_with_param_sharing(self,
                                              input_shape,
                                              filter_shape,
                                              n_filters):
        
        num_filter_neurons = self.compute_num_filter_neurons(filter_shape)
        num_channels = n_filters
        
        return num_filter_neurons * num_channels
        
    def compute_num_filter_neurons(self, filter_shape):
        num_weights = filter_shape[0] * filter_shape[1] * filter_shape[2]
        num_biases = 1
        return num_weights + num_biases
    
    def compute_num_output_neurons(self, input_shape, filter_shape, n_filters, stride, p_size):
        output_shape = ConvLayerOutputShapeCalculator()\
            .compute_conv_output_shape(input_shape, 
                                       filter_shape,
                                       n_filters,
                                       stride,
                                       p_size)
        return output_shape[0] * output_shape[1] * output_shape[2]

# %%
calculator = ConvLayerParamNumCalculator()

num_params = calculator.compute_num_params_no_param_sharing(input_shape, 
                                                            filter_shape, 
                                                            n_filters,
                                                            stride, 
                                                            padding_size)

print('Number of Parameters w/o Parameter Sharing: {}\n'.format(num_params))

num_params = calculator.compute_num_params_with_param_sharing(input_shape,
                                                              filter_shape,
                                                              n_filters)

print('Number of Paramters with Parameter Sharing: {}\n'.format(num_params))
# Out:
# Input Shape: [32, 32, 3]
# Filter Shape: [8, 8, 3]
# Num Filters: 20
#
# Conv Height: 14
# Conv Width: 14
# Conv Depth: 20
#
# Number of Parameters w/o Parameter Sharing: 756560
#
# Number of Paramters with Parameter Sharing: 3860

# %% [markdown]
# ## PoolLayerOutputShapeCalculator

# %%
class PoolLayerOutputShapeCalculator:
    
    def compute_output_shape(self, input_shape, filter_shape, stride):
        output_h = self.compute_output_height(input_shape, filter_shape, stride)
        output_w = self.compute_output_width(input_shape, filter_shape, stride)
        output_d = input_shape[2]
        return (output_h, output_w, output_d)
        
    def compute_output_height(self, input_shape, filter_shape, stride):
        return int((input_shape[0]-filter_shape[0])/stride) + 1
    
    def compute_output_width(self, input_shape, filter_shape, stride):
        return int((input_shape[1]-filter_shape[1])/stride) + 1

# %%
input_shape = [4, 4, 5]
filter_shape = [2, 2]
stride = 2

calculator = PoolLayerOutputShapeCalculator()
output_shape = calculator.compute_output_shape(input_shape, filter_shape, stride)

print('Pool Layer Output Shape: {}'.format(output_shape))
# Out:
# Pool Layer Output Shape: (2, 2, 5)

# %% [markdown]
# ## PoolLayerOutputShapeDemo

# %%
class PoolLayerOutputShapeDemo:
    
    def run(self, input_shape, filter_shape, stride, padding='SAME'):
        input = tf.placeholder(tf.float32, (None, *input_shape))
        
        print('Input Shape: {}'.format(input.shape))
        print('')
        
        filters = [1, *filter_shape, 1]
        strides = [1, stride, stride, 1]
        
        print('Filters: {}'.format(filters))
        print('Strides: {}'.format(strides))
        print('')
        
        pool = tf.nn.max_pool(input, filters, strides, padding)
        
        print('Pool Output Shape ({}): {}'.format(padding, pool.shape))

# %%
demo = PoolLayerOutputShapeDemo()
demo.run(input_shape, filter_shape, stride, 'SAME')
# Out:
# Input Shape: (?, 4, 4, 5)
#
# Filters: [1, 2, 2, 1]
# Strides: [1, 2, 2, 1]
#
# Pool Output Shape (SAME): (?, 2, 2, 5)

# %%
demo.run(input_shape, filter_shape, stride, 'VALID')
# Out:
# Input Shape: (?, 4, 4, 5)
#
# Filters: [1, 2, 2, 1]
# Strides: [1, 2, 2, 1]
#
# Pool Output Shape (VALID): (?, 2, 2, 5)

# %% [markdown]
# ## ConvNetwork

# %%
class ConvNetwork:
    
    def build(self, 
              input_shape,
              conv_1_filter_shape,
              conv_1_n_outputs,
              conv_2_filter_shape,
              conv_2_n_outputs,
              fc_dim,
              fc_n_outputs,
              out_n_classes,
              dropout,
              learning_rate):
        
        self.x, self.y, self.keep_prob = self.create_placeholders(input_shape, out_n_classes)
        
        self.weights, self.biases = self.create_weights_and_biases(conv_1_filter_shape,
                                                                   conv_1_n_outputs,
                                                                   conv_2_filter_shape,
                                                                   conv_2_n_outputs,
                                                                   fc_dim,
                                                                   fc_n_outputs,
                                                                   out_n_classes)
        
        self.logits = self.build_layers(self.x, self.weights, self.biases, self.keep_prob)
        
        self.cost, self.optimizer = self.define_cost_and_optimizer(self.logits, 
                                                                   self.y, 
                                                                   learning_rate)
        
        self.accuracy = self.define_accuracy(self.logits, self.y)
        
    def create_placeholders(self, input_shape, out_n_classes):
        x = tf.placeholder(tf.float32, [None, *input_shape])
        y = tf.placeholder(tf.float32, [None, out_n_classes])
        keep_prob = tf.placeholder(tf.float32)
        return x, y, keep_prob
 
    def create_weights_and_biases(self,
                                  conv_1_filter_shape,
                                  conv_1_n_outputs,
                                  conv_2_filter_shape,
                                  conv_2_n_outputs,
                                  fc_dim,
                                  fc_n_outputs,
                                  out_n_classes):
        
        weights = {
            'wc1': tf.Variable(tf.random_normal([*conv_1_filter_shape, conv_1_n_outputs])),
            'wc2': tf.Variable(tf.random_normal([*conv_2_filter_shape, conv_2_n_outputs])),
            'wfc': tf.Variable(tf.random_normal([fc_dim, fc_n_outputs])),
            'out': tf.Variable(tf.random_normal([fc_n_outputs, out_n_classes]))
        }
        
        biases = {
            'bc1': tf.Variable(tf.random_normal([conv_1_n_outputs])),
            'bc2': tf.Variable(tf.random_normal([conv_2_n_outputs])),
            'bfc': tf.Variable(tf.random_normal([fc_n_outputs])),
            'out': tf.Variable(tf.random_normal([out_n_classes]))
        }
        
        return weights, biases
 
    def build_layers(self, x, weights, biases, dropout):
        # Conv layer 1 - 28*28*1 to 14*14*32
        conv1 = self.get_conv2d_layer(x, weights['wc1'], biases['bc1'])
        conv1 = self.get_maxpool2d_layer(conv1, k=2)

        # Conv layer 2 - 14*14*32 to 7*7*64
        conv2 = self.get_conv2d_layer(conv1, weights['wc2'], biases['bc2'])
        conv2 = self.get_maxpool2d_layer(conv2, k=2)

        # Fully-connected layer - 7*7*64 to 1024
        fc = self.get_fc_layer(conv2, weights['wfc'], biases['bfc'], dropout)
        
        # Output Layer - class prediction - 1024 to 10
        out = self.get_output_layer(fc, weights['out'], biases['out'])
        
        return out
    
    def get_conv2d_layer(self, x, w, b, s=1):
        x = tf.nn.conv2d(x, w, strides=[1, s, s, 1], padding='SAME')
        x = tf.nn.bias_add(x, b)
        return tf.nn.relu(x)
    
    def get_maxpool2d_layer(self, x, k=2):
        return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1], padding='SAME')
    
    def get_fc_layer(self, x, w, b, dropout):
        x = tf.reshape(x, [-1, w.get_shape().as_list()[0]])
        x = tf.add(tf.matmul(x, w), b)
        x = tf.nn.relu(x)
        return tf.nn.dropout(x, dropout)
    
    def get_output_layer(self, x, w, b):
        return tf.add(tf.matmul(x, w), b)
    
    def define_cost_and_optimizer(self, logits, y, learning_rate):
        cost = tf.reduce_mean(\
                              tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
        optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)\
            .minimize(cost)
        return cost, optimizer

    def define_accuracy(self, logits, y):
        correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
        return tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %% [markdown]
# ## ConvNetworkTrainer

# %%
class ConvNetworkTrainer:
    
    def train_network(self, 
                      network, 
                      mnist,
                      epochs=10,
                      batch_size=128,
                      test_valid_size=256,
                      dropout=0.75):
        
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
                
            for epoch in range(epochs):

                for batch_idx in range(mnist.train.num_examples//batch_size):
                    batch_x, batch_y = mnist.train.next_batch(batch_size)

                    sess.run(network.optimizer,
                             feed_dict={network.x: batch_x,
                                        network.y: batch_y,
                                        network.keep_prob: dropout})

                    # Calculate batch loss and validation accuracy
                    loss = sess.run(network.cost,
                                    feed_dict={network.x: batch_x,
                                               network.y: batch_y,
                                               network.keep_prob: 1.})

                    valid_acc = sess.run(network.accuracy,
                                         feed_dict={
                                            network.x: mnist.validation.images[:test_valid_size],
                                            network.y: mnist.validation.labels[:test_valid_size],
                                            network.keep_prob: 1.})

                    logStr = 'Epoch {:>2}, Batch {:>3} - Loss: {:>10.4f} Validation Accuracy: {:.6f}'

                    print(logStr.format(epoch+1, batch_idx+1, loss, valid_acc))
                          
            # Calculate test accuracy
            test_acc = sess.run(network.accuracy,
                                feed_dict={
                                    network.x: mnist.test.images[:test_valid_size],
                                    network.y: mnist.test.labels[:test_valid_size],
                                    network.keep_prob: 1.})   
                          
            print('Testing Accuracy: {}'.format(test_acc))

# %%
input_shape = [28, 28, 1]
conv_1_filter_shape = [5, 5, 1]
conv_1_n_outputs = 32
conv_2_filter_shape = [5, 5, 32]
conv_2_n_outputs = 64
fc_dim = 7*7*64
fc_n_outputs = 1024
out_n_classes = 10
dropout = 0.75
learning_rate = 0.00001
epochs = 10
batch_size = 128
test_valid_size = 256

# %%
network = ConvNetwork()

network.build(input_shape,
              conv_1_filter_shape,
              conv_1_n_outputs,
              conv_2_filter_shape,
              conv_2_n_outputs,
              fc_dim,
              fc_n_outputs,
              out_n_classes,
              dropout,
              learning_rate)

# %%
mnist = input_data.read_data_sets(".", one_hot=True, reshape=False)
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting ./train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting ./train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting ./t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting ./t10k-labels-idx1-ubyte.gz

# %%
networkTrainer = ConvNetworkTrainer()

networkTrainer.train_network(network,
                             mnist,
                             epochs,
                             batch_size,
                             test_valid_size,
                             dropout)
# Out:
# Epoch  1, Batch   1 - Loss: 46034.9180 Validation Accuracy: 0.039062
# Epoch  1, Batch   2 - Loss: 40038.8555 Validation Accuracy: 0.070312
# Epoch  1, Batch   3 - Loss: 36304.4609 Validation Accuracy: 0.078125
# Epoch  1, Batch   4 - Loss: 37764.7969 Validation Accuracy: 0.082031
# Epoch  1, Batch   5 - Loss: 31106.7773 Validation Accuracy: 0.097656
# Epoch  1, Batch   6 - Loss: 31976.8789 Validation Accuracy: 0.082031
# Epoch  1, Batch   7 - Loss: 28067.0625 Validation Accuracy: 0.117188
# Epoch  1, Batch   8 - Loss: 29678.0938 Validation Accuracy: 0.117188
# Epoch  1, Batch   9 - Loss: 28386.7930 Validation Accuracy: 0.125000
# Epoch  1, Batch  10 - Loss: 23891.8281 Validation Accuracy: 0.121094
# Epoch  1, Batch  11 - Loss: 23187.0469 Validation Accuracy: 0.117188
# Epoch  1, Batch  12 - Loss: 23650.0664 Validation Accuracy: 0.148438
# Epoch  1, Batch  13 - Loss: 20978.7480 Validation Accuracy: 0.156250
# Epoch  1, Batch  14 - Loss: 24865.6211 Validation Accuracy: 0.164062
# Epoch  1, Batch  15 - Loss: 21044.4375 Validation Accuracy: 0.187500
# Epoch  1, Batch  16 - Loss: 19268.0195 Validation Accuracy: 0.187500
# Epoch  1, Batch  17 - Loss: 20335.4570 Validation Accuracy: 0.183594
# Epoch  1, Batch  18 - Loss: 18751.5078 Validation Accuracy: 0.183594
# Epoch  1, Batch  19 - Loss: 16834.2461 Validation Accuracy: 0.203125
# Epoch  1, Batch  20 - Loss: 15504.5840 Validation Accuracy: 0.207031
# Epoch  1, Batch  21 - Loss: 15515.1387 Validation Accuracy: 0.226562
# Epoch  1, Batch  22 - Loss: 19687.6484 Validation Accuracy: 0.238281
# Epoch  1, Batch  23 - Loss: 16718.7266 Validation Accuracy: 0.226562
# Epoch  1, Batch  24 - Loss: 15100.6221 Validation Accuracy: 0.246094
# Epoch  1, Batch  25 - Loss: 14344.1260 Validation Accuracy: 0.269531
# Epoch  1, Batch  26 - Loss: 13909.3086 Validation Accuracy: 0.261719
# Epoch  1, Batch  27 - Loss: 14745.4893 Validation Accuracy: 0.246094
# Epoch  1, Batch  28 - Loss: 15052.7617 Validation Accuracy: 0.257812
# Epoch  1, Batch  29 - Loss: 15450.5742 Validation Accuracy: 0.269531
# Epoch  1, Batch  30 - Loss: 14108.4141 Validation Accuracy: 0.285156
# Epoch  1, Batch  31 - Loss: 10565.6621 Validation Accuracy: 0.292969
# Epoch  1, Batch  32 - Loss: 11052.0781 Validation Accuracy: 0.296875
# Epoch  1, Batch  33 - Loss: 13753.1777 Validation Accuracy: 0.304688
# Epoch  1, Batch  34 - Loss: 11070.8691 Validation Accuracy: 0.320312
# Epoch  1, Batch  35 - Loss: 11625.1104 Validation Accuracy: 0.335938
# Epoch  1, Batch  36 - Loss: 12083.7559 Validation Accuracy: 0.335938
# Epoch  1, Batch  37 - Loss:  9734.7715 Validation Accuracy: 0.339844
# Epoch  1, Batch  38 - Loss: 10414.5352 Validation Accuracy: 0.351562
# Epoch  1, Batch  39 - Loss: 12068.8164 Validation Accuracy: 0.355469
# Epoch  1, Batch  40 - Loss: 10033.6113 Validation Accuracy: 0.371094
# Epoch  1, Batch  41 - Loss:  9770.3184 Validation Accuracy: 0.382812
# Epoch  1, Batch  42 - Loss: 10959.6904 Validation Accuracy: 0.386719
# Epoch  1, Batch  43 - Loss: 10715.0586 Validation Accuracy: 0.394531
# Epoch  1, Batch  44 - Loss:  7627.1963 Validation Accuracy: 0.402344
# Epoch  1, Batch  45 - Loss:  8382.6719 Validation Accuracy: 0.445312
# Epoch  1, Batch  46 - Loss:  7037.4561 Validation Accuracy: 0.449219
# Epoch  1, Batch  47 - Loss:  9383.3779 Validation Accuracy: 0.437500
# Epoch  1, Batch  48 - Loss:  9667.1758 Validation Accuracy: 0.441406
# Epoch  1, Batch  49 - Loss:  8954.7422 Validation Accuracy: 0.460938
# Epoch  1, Batch  50 - Loss:  7558.0312 Validation Accuracy: 0.460938
# Epoch  1, Batch  51 - Loss:  8832.5381 Validation Accuracy: 0.457031
# Epoch  1, Batch  52 - Loss:  7048.9980 Validation Accuracy: 0.460938
# Epoch  1, Batch  53 - Loss:  6490.1768 Validation Accuracy: 0.476562
# Epoch  1, Batch  54 - Loss:  8894.3574 Validation Accuracy: 0.492188
# Epoch  1, Batch  55 - Loss:  7751.3379 Validation Accuracy: 0.484375
# Epoch  1, Batch  56 - Loss:  7528.1089 Validation Accuracy: 0.500000
# Epoch  1, Batch  57 - Loss:  8022.1978 Validation Accuracy: 0.488281
# Epoch  1, Batch  58 - Loss:  7286.6699 Validation Accuracy: 0.503906
# Epoch  1, Batch  59 - Loss:  6569.3955 Validation Accuracy: 0.496094
# Epoch  1, Batch  60 - Loss:  9190.2617 Validation Accuracy: 0.488281
# Epoch  1, Batch  61 - Loss:  7889.3804 Validation Accuracy: 0.484375
# Epoch  1, Batch  62 - Loss:  7819.5654 Validation Accuracy: 0.496094
# Epoch  1, Batch  63 - Loss:  5571.1299 Validation Accuracy: 0.507812
# Epoch  1, Batch  64 - Loss:  8134.8262 Validation Accuracy: 0.511719
# Epoch  1, Batch  65 - Loss:  7210.5586 Validation Accuracy: 0.523438
# Epoch  1, Batch  66 - Loss:  6650.4326 Validation Accuracy: 0.515625
# Epoch  1, Batch  67 - Loss:  7899.5044 Validation Accuracy: 0.515625
# Epoch  1, Batch  68 - Loss:  6782.9746 Validation Accuracy: 0.519531
# Epoch  1, Batch  69 - Loss:  5674.6714 Validation Accuracy: 0.519531
# Epoch  1, Batch  70 - Loss:  6267.4390 Validation Accuracy: 0.519531
# Epoch  1, Batch  71 - Loss:  5372.9653 Validation Accuracy: 0.515625
# Epoch  1, Batch  72 - Loss:  6978.0713 Validation Accuracy: 0.511719
# Epoch  1, Batch  73 - Loss:  5685.0962 Validation Accuracy: 0.519531
# Epoch  1, Batch  74 - Loss:  7902.5830 Validation Accuracy: 0.523438
# Epoch  1, Batch  75 - Loss:  6117.1787 Validation Accuracy: 0.519531
# Epoch  1, Batch  76 - Loss:  5486.5840 Validation Accuracy: 0.531250
# Epoch  1, Batch  77 - Loss:  5000.7939 Validation Accuracy: 0.539062
# Epoch  1, Batch  78 - Loss:  5577.2168 Validation Accuracy: 0.535156
# Epoch  1, Batch  79 - Loss:  6596.8066 Validation Accuracy: 0.527344
# Epoch  1, Batch  80 - Loss:  6216.9961 Validation Accuracy: 0.550781
# Epoch  1, Batch  81 - Loss:  6466.0317 Validation Accuracy: 0.550781
# Epoch  1, Batch  82 - Loss:  5964.1953 Validation Accuracy: 0.546875
# Epoch  1, Batch  83 - Loss:  4710.2456 Validation Accuracy: 0.562500
# Epoch  1, Batch  84 - Loss:  5754.1445 Validation Accuracy: 0.566406
# Epoch  1, Batch  85 - Loss:  5128.8809 Validation Accuracy: 0.566406
# Epoch  1, Batch  86 - Loss:  5872.8638 Validation Accuracy: 0.582031
# Epoch  1, Batch  87 - Loss:  5248.1182 Validation Accuracy: 0.578125
# Epoch  1, Batch  88 - Loss:  5253.3657 Validation Accuracy: 0.566406
# Epoch  1, Batch  89 - Loss:  4973.3184 Validation Accuracy: 0.562500
# Epoch  1, Batch  90 - Loss:  4578.1963 Validation Accuracy: 0.574219
# Epoch  1, Batch  91 - Loss:  7527.2896 Validation Accuracy: 0.578125
# Epoch  1, Batch  92 - Loss:  4805.4917 Validation Accuracy: 0.574219
# Epoch  1, Batch  93 - Loss:  4897.5479 Validation Accuracy: 0.593750
# Epoch  1, Batch  94 - Loss:  5417.6719 Validation Accuracy: 0.609375
# Epoch  1, Batch  95 - Loss:  6488.4473 Validation Accuracy: 0.609375
# Epoch  1, Batch  96 - Loss:  4826.0698 Validation Accuracy: 0.589844
# Epoch  1, Batch  97 - Loss:  4635.2598 Validation Accuracy: 0.605469
# Epoch  1, Batch  98 - Loss:  5289.1504 Validation Accuracy: 0.597656
# Epoch  1, Batch  99 - Loss:  4817.3193 Validation Accuracy: 0.585938
# Epoch  1, Batch 100 - Loss:  4399.1211 Validation Accuracy: 0.601562
# Epoch  1, Batch 101 - Loss:  4138.1157 Validation Accuracy: 0.609375
# Epoch  1, Batch 102 - Loss:  4560.2173 Validation Accuracy: 0.601562
# Epoch  1, Batch 103 - Loss:  4331.4668 Validation Accuracy: 0.609375
# Epoch  1, Batch 104 - Loss:  5181.8848 Validation Accuracy: 0.613281
# Epoch  1, Batch 105 - Loss:  3817.4177 Validation Accuracy: 0.609375
# Epoch  1, Batch 106 - Loss:  4041.7239 Validation Accuracy: 0.613281
# Epoch  1, Batch 107 - Loss:  3804.3762 Validation Accuracy: 0.621094
# Epoch  1, Batch 108 - Loss:  5065.9722 Validation Accuracy: 0.632812
# Epoch  1, Batch 109 - Loss:  4027.7451 Validation Accuracy: 0.640625
# Epoch  1, Batch 110 - Loss:  5375.2578 Validation Accuracy: 0.625000
# Epoch  1, Batch 111 - Loss:  4840.5161 Validation Accuracy: 0.632812
# Epoch  1, Batch 112 - Loss:  4975.8506 Validation Accuracy: 0.628906
# Epoch  1, Batch 113 - Loss:  4302.9399 Validation Accuracy: 0.628906
# Epoch  1, Batch 114 - Loss:  3816.6833 Validation Accuracy: 0.628906
# Epoch  1, Batch 115 - Loss:  4357.9829 Validation Accuracy: 0.625000
# Epoch  1, Batch 116 - Loss:  5035.1587 Validation Accuracy: 0.628906
# Epoch  1, Batch 117 - Loss:  4634.8037 Validation Accuracy: 0.640625
# Epoch  1, Batch 118 - Loss:  4918.1660 Validation Accuracy: 0.632812
# Epoch  1, Batch 119 - Loss:  2939.2935 Validation Accuracy: 0.644531
# Epoch  1, Batch 120 - Loss:  3656.0056 Validation Accuracy: 0.652344
# Epoch  1, Batch 121 - Loss:  4366.3057 Validation Accuracy: 0.652344
# Epoch  1, Batch 122 - Loss:  5072.8750 Validation Accuracy: 0.652344
# Epoch  1, Batch 123 - Loss:  3356.4531 Validation Accuracy: 0.652344
# Epoch  1, Batch 124 - Loss:  4002.2305 Validation Accuracy: 0.652344
# Epoch  1, Batch 125 - Loss:  3484.3008 Validation Accuracy: 0.656250
# Epoch  1, Batch 126 - Loss:  3241.3501 Validation Accuracy: 0.660156
# Epoch  1, Batch 127 - Loss:  4128.2236 Validation Accuracy: 0.660156
# Epoch  1, Batch 128 - Loss:  3710.9275 Validation Accuracy: 0.660156
# Epoch  1, Batch 129 - Loss:  4213.7271 Validation Accuracy: 0.664062
# Epoch  1, Batch 130 - Loss:  5445.9082 Validation Accuracy: 0.667969
# Epoch  1, Batch 131 - Loss:  3784.0750 Validation Accuracy: 0.671875
# Epoch  1, Batch 132 - Loss:  4231.2783 Validation Accuracy: 0.667969
# Epoch  1, Batch 133 - Loss:  3768.0781 Validation Accuracy: 0.671875
# Epoch  1, Batch 134 - Loss:  3484.8770 Validation Accuracy: 0.667969
# Epoch  1, Batch 135 - Loss:  3753.2090 Validation Accuracy: 0.664062
# Epoch  1, Batch 136 - Loss:  4040.0989 Validation Accuracy: 0.667969
# Epoch  1, Batch 137 - Loss:  3485.7546 Validation Accuracy: 0.667969
# Epoch  1, Batch 138 - Loss:  2926.2334 Validation Accuracy: 0.671875
# Epoch  1, Batch 139 - Loss:  2480.1941 Validation Accuracy: 0.679688
# Epoch  1, Batch 140 - Loss:  3354.7993 Validation Accuracy: 0.671875
# Epoch  1, Batch 141 - Loss:  3417.4248 Validation Accuracy: 0.664062
# Epoch  1, Batch 142 - Loss:  3290.1304 Validation Accuracy: 0.667969
# Epoch  1, Batch 143 - Loss:  3297.1265 Validation Accuracy: 0.679688
# Epoch  1, Batch 144 - Loss:  3929.9243 Validation Accuracy: 0.679688
# Epoch  1, Batch 145 - Loss:  2668.0618 Validation Accuracy: 0.679688
# Epoch  1, Batch 146 - Loss:  4883.9043 Validation Accuracy: 0.679688
# Epoch  1, Batch 147 - Loss:  3869.5298 Validation Accuracy: 0.679688
# Epoch  1, Batch 148 - Loss:  2925.5811 Validation Accuracy: 0.683594
# Epoch  1, Batch 149 - Loss:  3287.6597 Validation Accuracy: 0.683594
# Epoch  1, Batch 150 - Loss:  4486.7686 Validation Accuracy: 0.695312
# Epoch  1, Batch 151 - Loss:  3201.7810 Validation Accuracy: 0.683594
# Epoch  1, Batch 152 - Loss:  2902.0625 Validation Accuracy: 0.691406
# Epoch  1, Batch 153 - Loss:  3855.6592 Validation Accuracy: 0.687500
# Epoch  1, Batch 154 - Loss:  4202.2246 Validation Accuracy: 0.699219
# Epoch  1, Batch 155 - Loss:  3442.3511 Validation Accuracy: 0.687500
# Epoch  1, Batch 156 - Loss:  3460.5420 Validation Accuracy: 0.695312
# Epoch  1, Batch 157 - Loss:  3810.4033 Validation Accuracy: 0.695312
# Epoch  1, Batch 158 - Loss:  4223.1362 Validation Accuracy: 0.695312
# Epoch  1, Batch 159 - Loss:  3386.6238 Validation Accuracy: 0.695312
# Epoch  1, Batch 160 - Loss:  3526.6558 Validation Accuracy: 0.695312
# Epoch  1, Batch 161 - Loss:  2801.5845 Validation Accuracy: 0.695312
# Epoch  1, Batch 162 - Loss:  4060.7144 Validation Accuracy: 0.695312
# Epoch  1, Batch 163 - Loss:  3297.9731 Validation Accuracy: 0.699219
# Epoch  1, Batch 164 - Loss:  4315.8169 Validation Accuracy: 0.699219
# Epoch  1, Batch 165 - Loss:  3168.1521 Validation Accuracy: 0.699219
# Epoch  1, Batch 166 - Loss:  3380.0796 Validation Accuracy: 0.707031
# Epoch  1, Batch 167 - Loss:  2798.2476 Validation Accuracy: 0.703125
# Epoch  1, Batch 168 - Loss:  2073.6736 Validation Accuracy: 0.703125
# Epoch  1, Batch 169 - Loss:  4587.1245 Validation Accuracy: 0.703125
# Epoch  1, Batch 170 - Loss:  2965.3052 Validation Accuracy: 0.699219
# Epoch  1, Batch 171 - Loss:  3751.7529 Validation Accuracy: 0.710938
# Epoch  1, Batch 172 - Loss:  3375.6780 Validation Accuracy: 0.710938
# Epoch  1, Batch 173 - Loss:  3631.5906 Validation Accuracy: 0.707031
# Epoch  1, Batch 174 - Loss:  2805.1445 Validation Accuracy: 0.714844
# Epoch  1, Batch 175 - Loss:  2736.7502 Validation Accuracy: 0.707031
# Epoch  1, Batch 176 - Loss:  1885.6434 Validation Accuracy: 0.707031
# Epoch  1, Batch 177 - Loss:  2914.9517 Validation Accuracy: 0.695312
# Epoch  1, Batch 178 - Loss:  2636.4780 Validation Accuracy: 0.695312
# Epoch  1, Batch 179 - Loss:  3390.8042 Validation Accuracy: 0.703125
# Epoch  1, Batch 180 - Loss:  2886.7378 Validation Accuracy: 0.687500
# Epoch  1, Batch 181 - Loss:  2407.3562 Validation Accuracy: 0.691406
# Epoch  1, Batch 182 - Loss:  2496.4590 Validation Accuracy: 0.687500
# Epoch  1, Batch 183 - Loss:  2678.5334 Validation Accuracy: 0.699219
# Epoch  1, Batch 184 - Loss:  2767.7139 Validation Accuracy: 0.695312
# Epoch  1, Batch 185 - Loss:  3108.7146 Validation Accuracy: 0.695312
# Epoch  1, Batch 186 - Loss:  4187.7842 Validation Accuracy: 0.707031
# Epoch  1, Batch 187 - Loss:  3014.6338 Validation Accuracy: 0.703125
# Epoch  1, Batch 188 - Loss:  3176.5190 Validation Accuracy: 0.695312
# Epoch  1, Batch 189 - Loss:  3059.2607 Validation Accuracy: 0.703125
# Epoch  1, Batch 190 - Loss:  2655.0742 Validation Accuracy: 0.707031
# Epoch  1, Batch 191 - Loss:  3418.9907 Validation Accuracy: 0.703125
# Epoch  1, Batch 192 - Loss:  1812.7871 Validation Accuracy: 0.710938
# Epoch  1, Batch 193 - Loss:  2936.1973 Validation Accuracy: 0.710938
# Epoch  1, Batch 194 - Loss:  2459.9048 Validation Accuracy: 0.714844
# Epoch  1, Batch 195 - Loss:  3514.0193 Validation Accuracy: 0.710938
# Epoch  1, Batch 196 - Loss:  3465.1335 Validation Accuracy: 0.714844
# Epoch  1, Batch 197 - Loss:  2783.6667 Validation Accuracy: 0.710938
# Epoch  1, Batch 198 - Loss:  2703.9692 Validation Accuracy: 0.710938
# Epoch  1, Batch 199 - Loss:  2784.1299 Validation Accuracy: 0.714844
# Epoch  1, Batch 200 - Loss:  2586.6387 Validation Accuracy: 0.710938
# Epoch  1, Batch 201 - Loss:  2820.0176 Validation Accuracy: 0.710938
# Epoch  1, Batch 202 - Loss:  3149.6270 Validation Accuracy: 0.710938
# Epoch  1, Batch 203 - Loss:  2189.7305 Validation Accuracy: 0.707031
# Epoch  1, Batch 204 - Loss:  2549.9458 Validation Accuracy: 0.707031
# Epoch  1, Batch 205 - Loss:  2330.3821 Validation Accuracy: 0.707031
# Epoch  1, Batch 206 - Loss:  2131.8887 Validation Accuracy: 0.710938
# Epoch  1, Batch 207 - Loss:  2610.0417 Validation Accuracy: 0.703125
# Epoch  1, Batch 208 - Loss:  3653.8293 Validation Accuracy: 0.699219
# Epoch  1, Batch 209 - Loss:  2761.7051 Validation Accuracy: 0.707031
# Epoch  1, Batch 210 - Loss:  2703.3193 Validation Accuracy: 0.707031
# Epoch  1, Batch 211 - Loss:  2345.5330 Validation Accuracy: 0.710938
# Epoch  1, Batch 212 - Loss:  2521.4956 Validation Accuracy: 0.707031
# Epoch  1, Batch 213 - Loss:  1418.3318 Validation Accuracy: 0.703125
# Epoch  1, Batch 214 - Loss:  2367.4290 Validation Accuracy: 0.707031
# Epoch  1, Batch 215 - Loss:  3166.4272 Validation Accuracy: 0.707031
# Epoch  1, Batch 216 - Loss:  2629.6489 Validation Accuracy: 0.707031
# Epoch  1, Batch 217 - Loss:  1774.9647 Validation Accuracy: 0.703125
# Epoch  1, Batch 218 - Loss:  2508.4915 Validation Accuracy: 0.707031
# Epoch  1, Batch 219 - Loss:  2509.7852 Validation Accuracy: 0.707031
# Epoch  1, Batch 220 - Loss:  2556.3394 Validation Accuracy: 0.707031
# Epoch  1, Batch 221 - Loss:  2184.4412 Validation Accuracy: 0.710938
# Epoch  1, Batch 222 - Loss:  1961.3943 Validation Accuracy: 0.703125
# Epoch  1, Batch 223 - Loss:  2854.5435 Validation Accuracy: 0.710938
# Epoch  1, Batch 224 - Loss:  3129.0818 Validation Accuracy: 0.707031
# Epoch  1, Batch 225 - Loss:  3643.5513 Validation Accuracy: 0.710938
# Epoch  1, Batch 226 - Loss:  2095.2820 Validation Accuracy: 0.710938
# Epoch  1, Batch 227 - Loss:  2189.9995 Validation Accuracy: 0.707031
# Epoch  1, Batch 228 - Loss:  3109.9285 Validation Accuracy: 0.707031
# Epoch  1, Batch 229 - Loss:  2383.1946 Validation Accuracy: 0.710938
# Epoch  1, Batch 230 - Loss:  2567.6880 Validation Accuracy: 0.703125
# Epoch  1, Batch 231 - Loss:  1950.8468 Validation Accuracy: 0.710938
# Epoch  1, Batch 232 - Loss:  2406.8743 Validation Accuracy: 0.710938
# Epoch  1, Batch 233 - Loss:  2277.1504 Validation Accuracy: 0.710938
# Epoch  1, Batch 234 - Loss:  2798.4951 Validation Accuracy: 0.714844
# Epoch  1, Batch 235 - Loss:  2199.9424 Validation Accuracy: 0.710938
# Epoch  1, Batch 236 - Loss:  2189.3604 Validation Accuracy: 0.707031
# Epoch  1, Batch 237 - Loss:  2207.2080 Validation Accuracy: 0.714844
# Epoch  1, Batch 238 - Loss:  2217.6089 Validation Accuracy: 0.710938
# Epoch  1, Batch 239 - Loss:  1762.9729 Validation Accuracy: 0.714844
# Epoch  1, Batch 240 - Loss:  2432.2642 Validation Accuracy: 0.714844
# Epoch  1, Batch 241 - Loss:  1659.2363 Validation Accuracy: 0.710938
# Epoch  1, Batch 242 - Loss:  2814.0486 Validation Accuracy: 0.714844
# Epoch  1, Batch 243 - Loss:  2827.6643 Validation Accuracy: 0.714844
# Epoch  1, Batch 244 - Loss:  2093.5308 Validation Accuracy: 0.730469
# Epoch  1, Batch 245 - Loss:  2351.9351 Validation Accuracy: 0.722656
# Epoch  1, Batch 246 - Loss:  2002.2316 Validation Accuracy: 0.734375
# Epoch  1, Batch 247 - Loss:  2098.4917 Validation Accuracy: 0.730469
# Epoch  1, Batch 248 - Loss:  2161.9797 Validation Accuracy: 0.734375
# Epoch  1, Batch 249 - Loss:  2315.6470 Validation Accuracy: 0.734375
# Epoch  1, Batch 250 - Loss:  1886.4583 Validation Accuracy: 0.734375
# Epoch  1, Batch 251 - Loss:  2006.8148 Validation Accuracy: 0.734375
# Epoch  1, Batch 252 - Loss:  2152.6521 Validation Accuracy: 0.734375
# Epoch  1, Batch 253 - Loss:  2537.0371 Validation Accuracy: 0.742188
# Epoch  1, Batch 254 - Loss:  2458.8784 Validation Accuracy: 0.734375
# Epoch  1, Batch 255 - Loss:  2105.8193 Validation Accuracy: 0.742188
# Epoch  1, Batch 256 - Loss:  1563.4427 Validation Accuracy: 0.742188
# Epoch  1, Batch 257 - Loss:  2032.3474 Validation Accuracy: 0.734375
# Epoch  1, Batch 258 - Loss:  2551.4092 Validation Accuracy: 0.734375
# Epoch  1, Batch 259 - Loss:  2379.5283 Validation Accuracy: 0.738281
# Epoch  1, Batch 260 - Loss:  2266.4639 Validation Accuracy: 0.738281
# Epoch  1, Batch 261 - Loss:  2211.6355 Validation Accuracy: 0.734375
# Epoch  1, Batch 262 - Loss:  2442.9448 Validation Accuracy: 0.742188
# Epoch  1, Batch 263 - Loss:  2739.1719 Validation Accuracy: 0.742188
# Epoch  1, Batch 264 - Loss:  2150.9478 Validation Accuracy: 0.742188
# Epoch  1, Batch 265 - Loss:  2617.3940 Validation Accuracy: 0.742188
# Epoch  1, Batch 266 - Loss:  2593.9419 Validation Accuracy: 0.734375
# Epoch  1, Batch 267 - Loss:  2379.9719 Validation Accuracy: 0.742188
# Epoch  1, Batch 268 - Loss:  2343.1621 Validation Accuracy: 0.742188
# Epoch  1, Batch 269 - Loss:  1885.1658 Validation Accuracy: 0.750000
# Epoch  1, Batch 270 - Loss:  2108.4224 Validation Accuracy: 0.742188
# Epoch  1, Batch 271 - Loss:  2282.1111 Validation Accuracy: 0.750000
# Epoch  1, Batch 272 - Loss:  1764.3269 Validation Accuracy: 0.750000
# Epoch  1, Batch 273 - Loss:  2587.1372 Validation Accuracy: 0.746094
# Epoch  1, Batch 274 - Loss:  1883.8861 Validation Accuracy: 0.738281
# Epoch  1, Batch 275 - Loss:  2942.4287 Validation Accuracy: 0.734375
# Epoch  1, Batch 276 - Loss:  2150.1177 Validation Accuracy: 0.722656
# Epoch  1, Batch 277 - Loss:  2103.7085 Validation Accuracy: 0.722656
# Epoch  1, Batch 278 - Loss:  2304.6404 Validation Accuracy: 0.722656
# Epoch  1, Batch 279 - Loss:  1682.7528 Validation Accuracy: 0.718750
# Epoch  1, Batch 280 - Loss:  2325.8442 Validation Accuracy: 0.718750
# Epoch  1, Batch 281 - Loss:  2523.0723 Validation Accuracy: 0.718750
# Epoch  1, Batch 282 - Loss:  2224.8835 Validation Accuracy: 0.726562
# Epoch  1, Batch 283 - Loss:  1899.4434 Validation Accuracy: 0.718750
# Epoch  1, Batch 284 - Loss:  2561.4888 Validation Accuracy: 0.718750
# Epoch  1, Batch 285 - Loss:  2473.6455 Validation Accuracy: 0.730469
# Epoch  1, Batch 286 - Loss:  1857.3811 Validation Accuracy: 0.726562
# Epoch  1, Batch 287 - Loss:  2246.6860 Validation Accuracy: 0.730469
# Epoch  1, Batch 288 - Loss:  2289.3564 Validation Accuracy: 0.726562
# Epoch  1, Batch 289 - Loss:  2436.1497 Validation Accuracy: 0.726562
# Epoch  1, Batch 290 - Loss:  1959.1759 Validation Accuracy: 0.718750
# Epoch  1, Batch 291 - Loss:  2016.9692 Validation Accuracy: 0.730469
# Epoch  1, Batch 292 - Loss:  1434.9785 Validation Accuracy: 0.722656
# Epoch  1, Batch 293 - Loss:  2126.0498 Validation Accuracy: 0.726562
# Epoch  1, Batch 294 - Loss:  1687.2927 Validation Accuracy: 0.738281
# Epoch  1, Batch 295 - Loss:  2262.2441 Validation Accuracy: 0.726562
# Epoch  1, Batch 296 - Loss:  1637.6196 Validation Accuracy: 0.730469
# Epoch  1, Batch 297 - Loss:  2907.1934 Validation Accuracy: 0.730469
# Epoch  1, Batch 298 - Loss:  1363.3226 Validation Accuracy: 0.726562
# Epoch  1, Batch 299 - Loss:  2086.8657 Validation Accuracy: 0.726562
# Epoch  1, Batch 300 - Loss:  2367.3914 Validation Accuracy: 0.730469
# Epoch  1, Batch 301 - Loss:  1869.0420 Validation Accuracy: 0.726562
# Epoch  1, Batch 302 - Loss:  1991.4495 Validation Accuracy: 0.722656
# Epoch  1, Batch 303 - Loss:  1387.3124 Validation Accuracy: 0.722656
# Epoch  1, Batch 304 - Loss:  1748.6322 Validation Accuracy: 0.726562
# Epoch  1, Batch 305 - Loss:  1510.6932 Validation Accuracy: 0.734375
# Epoch  1, Batch 306 - Loss:  2058.5374 Validation Accuracy: 0.734375
# Epoch  1, Batch 307 - Loss:  1520.2461 Validation Accuracy: 0.734375
# Epoch  1, Batch 308 - Loss:  2040.2974 Validation Accuracy: 0.730469
# Epoch  1, Batch 309 - Loss:  1671.1091 Validation Accuracy: 0.746094
# Epoch  1, Batch 310 - Loss:  1682.7710 Validation Accuracy: 0.742188
# Epoch  1, Batch 311 - Loss:  1595.0049 Validation Accuracy: 0.742188
# Epoch  1, Batch 312 - Loss:  2075.9734 Validation Accuracy: 0.742188
# Epoch  1, Batch 313 - Loss:  1931.0262 Validation Accuracy: 0.738281
# Epoch  1, Batch 314 - Loss:  1421.7979 Validation Accuracy: 0.742188
# Epoch  1, Batch 315 - Loss:  1088.2904 Validation Accuracy: 0.746094
# Epoch  1, Batch 316 - Loss:  1608.2552 Validation Accuracy: 0.742188
# Epoch  1, Batch 317 - Loss:  1617.2266 Validation Accuracy: 0.746094
# Epoch  1, Batch 318 - Loss:  1495.6498 Validation Accuracy: 0.742188
# Epoch  1, Batch 319 - Loss:  1799.6010 Validation Accuracy: 0.746094
# Epoch  1, Batch 320 - Loss:  2275.7417 Validation Accuracy: 0.753906
# Epoch  1, Batch 321 - Loss:  2656.1150 Validation Accuracy: 0.757812
# Epoch  1, Batch 322 - Loss:  2213.2559 Validation Accuracy: 0.750000
# Epoch  1, Batch 323 - Loss:  1087.3350 Validation Accuracy: 0.746094
# Epoch  1, Batch 324 - Loss:  2089.3191 Validation Accuracy: 0.750000
# Epoch  1, Batch 325 - Loss:  2014.6736 Validation Accuracy: 0.753906
# Epoch  1, Batch 326 - Loss:  2395.9070 Validation Accuracy: 0.757812
# Epoch  1, Batch 327 - Loss:  2259.5063 Validation Accuracy: 0.761719
# Epoch  1, Batch 328 - Loss:  2351.5435 Validation Accuracy: 0.757812
# Epoch  1, Batch 329 - Loss:  1345.4200 Validation Accuracy: 0.761719
# Epoch  1, Batch 330 - Loss:  2078.9182 Validation Accuracy: 0.757812
# Epoch  1, Batch 331 - Loss:  1917.8295 Validation Accuracy: 0.757812
# Epoch  1, Batch 332 - Loss:  2256.0486 Validation Accuracy: 0.753906
# Epoch  1, Batch 333 - Loss:  1350.4707 Validation Accuracy: 0.742188
# Epoch  1, Batch 334 - Loss:  1691.4697 Validation Accuracy: 0.746094
# Epoch  1, Batch 335 - Loss:  1553.3420 Validation Accuracy: 0.753906
# Epoch  1, Batch 336 - Loss:  2386.6367 Validation Accuracy: 0.750000
# Epoch  1, Batch 337 - Loss:  1889.6510 Validation Accuracy: 0.750000
# Epoch  1, Batch 338 - Loss:  1304.8582 Validation Accuracy: 0.753906
# Epoch  1, Batch 339 - Loss:  1375.8413 Validation Accuracy: 0.746094
# Epoch  1, Batch 340 - Loss:  2242.8696 Validation Accuracy: 0.746094
# Epoch  1, Batch 341 - Loss:  1049.2340 Validation Accuracy: 0.746094
# Epoch  1, Batch 342 - Loss:  1739.8518 Validation Accuracy: 0.750000
# Epoch  1, Batch 343 - Loss:  1829.3782 Validation Accuracy: 0.750000
# Epoch  1, Batch 344 - Loss:  2188.1814 Validation Accuracy: 0.750000
# Epoch  1, Batch 345 - Loss:  1418.0162 Validation Accuracy: 0.746094
# Epoch  1, Batch 346 - Loss:  1663.4165 Validation Accuracy: 0.750000
# Epoch  1, Batch 347 - Loss:  1303.2086 Validation Accuracy: 0.750000
# Epoch  1, Batch 348 - Loss:  1136.6368 Validation Accuracy: 0.750000
# Epoch  1, Batch 349 - Loss:  2125.4656 Validation Accuracy: 0.750000
# Epoch  1, Batch 350 - Loss:  1297.3289 Validation Accuracy: 0.753906
# Epoch  1, Batch 351 - Loss:  1902.3041 Validation Accuracy: 0.753906
# Epoch  1, Batch 352 - Loss:  1503.7581 Validation Accuracy: 0.753906
# Epoch  1, Batch 353 - Loss:  2230.0244 Validation Accuracy: 0.753906
# Epoch  1, Batch 354 - Loss:  1880.2991 Validation Accuracy: 0.753906
# Epoch  1, Batch 355 - Loss:  2706.2070 Validation Accuracy: 0.757812
# Epoch  1, Batch 356 - Loss:  2020.7505 Validation Accuracy: 0.757812
# Epoch  1, Batch 357 - Loss:  1622.5137 Validation Accuracy: 0.765625
# Epoch  1, Batch 358 - Loss:  1891.2097 Validation Accuracy: 0.761719
# Epoch  1, Batch 359 - Loss:  1406.1089 Validation Accuracy: 0.757812
# Epoch  1, Batch 360 - Loss:   860.8077 Validation Accuracy: 0.765625
# Epoch  1, Batch 361 - Loss:  1857.5747 Validation Accuracy: 0.761719
# Epoch  1, Batch 362 - Loss:  2417.6929 Validation Accuracy: 0.757812
# Epoch  1, Batch 363 - Loss:  1407.5007 Validation Accuracy: 0.757812
# Epoch  1, Batch 364 - Loss:  1895.1926 Validation Accuracy: 0.761719
# Epoch  1, Batch 365 - Loss:  1412.7247 Validation Accuracy: 0.761719
# Epoch  1, Batch 366 - Loss:  2485.0317 Validation Accuracy: 0.757812
# Epoch  1, Batch 367 - Loss:  1865.8013 Validation Accuracy: 0.757812
# Epoch  1, Batch 368 - Loss:  1897.9683 Validation Accuracy: 0.757812
# Epoch  1, Batch 369 - Loss:  1630.1680 Validation Accuracy: 0.761719
# Epoch  1, Batch 370 - Loss:  2449.1191 Validation Accuracy: 0.765625
# Epoch  1, Batch 371 - Loss:  2218.5356 Validation Accuracy: 0.765625
# Epoch  1, Batch 372 - Loss:  2557.1387 Validation Accuracy: 0.757812
# Epoch  1, Batch 373 - Loss:  1247.9410 Validation Accuracy: 0.769531
# Epoch  1, Batch 374 - Loss:   910.2620 Validation Accuracy: 0.765625
# Epoch  1, Batch 375 - Loss:  1466.1404 Validation Accuracy: 0.761719
# Epoch  1, Batch 376 - Loss:  2007.4568 Validation Accuracy: 0.757812
# Epoch  1, Batch 377 - Loss:  1752.4669 Validation Accuracy: 0.761719
# Epoch  1, Batch 378 - Loss:  1045.7197 Validation Accuracy: 0.757812
# Epoch  1, Batch 379 - Loss:  1871.3658 Validation Accuracy: 0.757812
# Epoch  1, Batch 380 - Loss:  1444.1104 Validation Accuracy: 0.761719
# Epoch  1, Batch 381 - Loss:  1996.1233 Validation Accuracy: 0.750000
# Epoch  1, Batch 382 - Loss:   998.0148 Validation Accuracy: 0.761719
# Epoch  1, Batch 383 - Loss:  1202.1497 Validation Accuracy: 0.753906
# Epoch  1, Batch 384 - Loss:  2503.5684 Validation Accuracy: 0.757812
# Epoch  1, Batch 385 - Loss:  1399.6046 Validation Accuracy: 0.753906
# Epoch  1, Batch 386 - Loss:  1854.5010 Validation Accuracy: 0.765625
# Epoch  1, Batch 387 - Loss:  2144.5991 Validation Accuracy: 0.761719
# Epoch  1, Batch 388 - Loss:  2456.0161 Validation Accuracy: 0.765625
# Epoch  1, Batch 389 - Loss:  1489.2317 Validation Accuracy: 0.757812
# Epoch  1, Batch 390 - Loss:  1370.5618 Validation Accuracy: 0.761719
# Epoch  1, Batch 391 - Loss:  1238.4420 Validation Accuracy: 0.757812
# Epoch  1, Batch 392 - Loss:  1748.1921 Validation Accuracy: 0.765625
# Epoch  1, Batch 393 - Loss:  2026.7112 Validation Accuracy: 0.761719
# Epoch  1, Batch 394 - Loss:  1859.7504 Validation Accuracy: 0.757812
# Epoch  1, Batch 395 - Loss:  1510.1272 Validation Accuracy: 0.757812
# Epoch  1, Batch 396 - Loss:  1789.3199 Validation Accuracy: 0.765625
# Epoch  1, Batch 397 - Loss:  1035.2385 Validation Accuracy: 0.757812
# Epoch  1, Batch 398 - Loss:  1495.7830 Validation Accuracy: 0.769531
# Epoch  1, Batch 399 - Loss:  1325.4067 Validation Accuracy: 0.761719
# Epoch  1, Batch 400 - Loss:  2167.8350 Validation Accuracy: 0.753906
# Epoch  1, Batch 401 - Loss:  1185.8003 Validation Accuracy: 0.757812
# Epoch  1, Batch 402 - Loss:  2259.8167 Validation Accuracy: 0.761719
# Epoch  1, Batch 403 - Loss:  1809.6033 Validation Accuracy: 0.765625
# Epoch  1, Batch 404 - Loss:  1726.5090 Validation Accuracy: 0.765625
# Epoch  1, Batch 405 - Loss:  1423.5337 Validation Accuracy: 0.761719
# Epoch  1, Batch 406 - Loss:  1595.3943 Validation Accuracy: 0.765625
# Epoch  1, Batch 407 - Loss:  1806.5674 Validation Accuracy: 0.765625
# Epoch  1, Batch 408 - Loss:  2038.8081 Validation Accuracy: 0.769531
# Epoch  1, Batch 409 - Loss:  1214.6036 Validation Accuracy: 0.765625
# Epoch  1, Batch 410 - Loss:  1213.5769 Validation Accuracy: 0.761719
# Epoch  1, Batch 411 - Loss:  1399.5076 Validation Accuracy: 0.757812
# Epoch  1, Batch 412 - Loss:   934.2814 Validation Accuracy: 0.761719
# Epoch  1, Batch 413 - Loss:  1771.6733 Validation Accuracy: 0.757812
# Epoch  1, Batch 414 - Loss:  1589.2104 Validation Accuracy: 0.761719
# Epoch  1, Batch 415 - Loss:   787.5106 Validation Accuracy: 0.761719
# Epoch  1, Batch 416 - Loss:   787.1456 Validation Accuracy: 0.761719
# Epoch  1, Batch 417 - Loss:  1343.2600 Validation Accuracy: 0.757812
# Epoch  1, Batch 418 - Loss:  2004.9631 Validation Accuracy: 0.757812
# Epoch  1, Batch 419 - Loss:  1678.8418 Validation Accuracy: 0.765625
# Epoch  1, Batch 420 - Loss:  1498.9236 Validation Accuracy: 0.761719
# Epoch  1, Batch 421 - Loss:  1636.8367 Validation Accuracy: 0.761719
# Epoch  1, Batch 422 - Loss:  1387.1956 Validation Accuracy: 0.757812
# Epoch  1, Batch 423 - Loss:  1363.0594 Validation Accuracy: 0.761719
# Epoch  1, Batch 424 - Loss:  1659.6472 Validation Accuracy: 0.765625
# Epoch  1, Batch 425 - Loss:  1062.1382 Validation Accuracy: 0.761719
# Epoch  1, Batch 426 - Loss:  1264.8096 Validation Accuracy: 0.757812
# Epoch  1, Batch 427 - Loss:  1464.2902 Validation Accuracy: 0.761719
# Epoch  1, Batch 428 - Loss:  1189.3435 Validation Accuracy: 0.765625
# Epoch  1, Batch 429 - Loss:  1150.3469 Validation Accuracy: 0.769531
# Epoch  2, Batch   1 - Loss:  1362.8325 Validation Accuracy: 0.769531
# Epoch  2, Batch   2 - Loss:  1394.8094 Validation Accuracy: 0.765625
# Epoch  2, Batch   3 - Loss:  1224.7531 Validation Accuracy: 0.765625
# Epoch  2, Batch   4 - Loss:  1932.3025 Validation Accuracy: 0.769531
# Epoch  2, Batch   5 - Loss:   802.5532 Validation Accuracy: 0.769531
# Epoch  2, Batch   6 - Loss:  1381.4761 Validation Accuracy: 0.769531
# Epoch  2, Batch   7 - Loss:  1966.0549 Validation Accuracy: 0.769531
# Epoch  2, Batch   8 - Loss:  2047.1222 Validation Accuracy: 0.773438
# Epoch  2, Batch   9 - Loss:  1415.4452 Validation Accuracy: 0.769531
# Epoch  2, Batch  10 - Loss:  1665.9669 Validation Accuracy: 0.769531
# Epoch  2, Batch  11 - Loss:  1528.7819 Validation Accuracy: 0.769531
# Epoch  2, Batch  12 - Loss:  1116.9879 Validation Accuracy: 0.773438
# Epoch  2, Batch  13 - Loss:  1362.4265 Validation Accuracy: 0.765625
# Epoch  2, Batch  14 - Loss:  1349.1321 Validation Accuracy: 0.765625
# Epoch  2, Batch  15 - Loss:  1238.8210 Validation Accuracy: 0.765625
# Epoch  2, Batch  16 - Loss:  1446.4702 Validation Accuracy: 0.765625
# Epoch  2, Batch  17 - Loss:  1700.1599 Validation Accuracy: 0.765625
# Epoch  2, Batch  18 - Loss:  1348.9473 Validation Accuracy: 0.765625
# Epoch  2, Batch  19 - Loss:  2615.9458 Validation Accuracy: 0.765625
# Epoch  2, Batch  20 - Loss:   762.2608 Validation Accuracy: 0.781250
# Epoch  2, Batch  21 - Loss:  2065.2620 Validation Accuracy: 0.777344
# Epoch  2, Batch  22 - Loss:  1508.1731 Validation Accuracy: 0.769531
# Epoch  2, Batch  23 - Loss:  1247.3256 Validation Accuracy: 0.761719
# Epoch  2, Batch  24 - Loss:  1454.2102 Validation Accuracy: 0.761719
# Epoch  2, Batch  25 - Loss:  1691.4425 Validation Accuracy: 0.757812
# Epoch  2, Batch  26 - Loss:  1815.0187 Validation Accuracy: 0.761719
# Epoch  2, Batch  27 - Loss:  1051.3887 Validation Accuracy: 0.773438
# Epoch  2, Batch  28 - Loss:  1683.7672 Validation Accuracy: 0.777344
# Epoch  2, Batch  29 - Loss:  1487.6721 Validation Accuracy: 0.781250
# Epoch  2, Batch  30 - Loss:  1615.3003 Validation Accuracy: 0.777344
# Epoch  2, Batch  31 - Loss:  1196.6938 Validation Accuracy: 0.777344
# Epoch  2, Batch  32 - Loss:   923.5963 Validation Accuracy: 0.777344
# Epoch  2, Batch  33 - Loss:  1024.6152 Validation Accuracy: 0.777344
# Epoch  2, Batch  34 - Loss:  1358.8331 Validation Accuracy: 0.781250
# Epoch  2, Batch  35 - Loss:  2582.9734 Validation Accuracy: 0.781250
# Epoch  2, Batch  36 - Loss:  1458.4897 Validation Accuracy: 0.781250
# Epoch  2, Batch  37 - Loss:  1663.4749 Validation Accuracy: 0.785156
# Epoch  2, Batch  38 - Loss:  1223.6244 Validation Accuracy: 0.769531
# Epoch  2, Batch  39 - Loss:  1376.5682 Validation Accuracy: 0.777344
# Epoch  2, Batch  40 - Loss:   916.1446 Validation Accuracy: 0.773438
# Epoch  2, Batch  41 - Loss:  1598.9377 Validation Accuracy: 0.777344
# Epoch  2, Batch  42 - Loss:  1800.6178 Validation Accuracy: 0.781250
# Epoch  2, Batch  43 - Loss:  1375.3323 Validation Accuracy: 0.777344
# Epoch  2, Batch  44 - Loss:  1403.4027 Validation Accuracy: 0.773438
# Epoch  2, Batch  45 - Loss:  1556.3177 Validation Accuracy: 0.769531
# Epoch  2, Batch  46 - Loss:  1236.6857 Validation Accuracy: 0.769531
# Epoch  2, Batch  47 - Loss:  1160.2603 Validation Accuracy: 0.773438
# Epoch  2, Batch  48 - Loss:  1569.1415 Validation Accuracy: 0.773438
# Epoch  2, Batch  49 - Loss:  1671.2161 Validation Accuracy: 0.765625
# Epoch  2, Batch  50 - Loss:  1968.5972 Validation Accuracy: 0.757812
# Epoch  2, Batch  51 - Loss:  1671.8591 Validation Accuracy: 0.757812
# Epoch  2, Batch  52 - Loss:  1463.0405 Validation Accuracy: 0.761719
# Epoch  2, Batch  53 - Loss:  1457.5510 Validation Accuracy: 0.761719
# Epoch  2, Batch  54 - Loss:  1144.7487 Validation Accuracy: 0.765625
# Epoch  2, Batch  55 - Loss:  1508.3198 Validation Accuracy: 0.761719
# Epoch  2, Batch  56 - Loss:  1534.1035 Validation Accuracy: 0.761719
# Epoch  2, Batch  57 - Loss:  1605.0902 Validation Accuracy: 0.761719
# Epoch  2, Batch  58 - Loss:  1723.4741 Validation Accuracy: 0.765625
# Epoch  2, Batch  59 - Loss:  1198.7642 Validation Accuracy: 0.761719
# Epoch  2, Batch  60 - Loss:  1352.1228 Validation Accuracy: 0.761719
# Epoch  2, Batch  61 - Loss:  1322.7776 Validation Accuracy: 0.761719
# Epoch  2, Batch  62 - Loss:  1058.0529 Validation Accuracy: 0.761719
# Epoch  2, Batch  63 - Loss:  1400.2368 Validation Accuracy: 0.761719
# Epoch  2, Batch  64 - Loss:  1271.8914 Validation Accuracy: 0.757812
# Epoch  2, Batch  65 - Loss:  1090.1539 Validation Accuracy: 0.757812
# Epoch  2, Batch  66 - Loss:  1322.9659 Validation Accuracy: 0.761719
# Epoch  2, Batch  67 - Loss:  1438.2855 Validation Accuracy: 0.757812
# Epoch  2, Batch  68 - Loss:   998.2501 Validation Accuracy: 0.757812
# Epoch  2, Batch  69 - Loss:  1076.1453 Validation Accuracy: 0.757812
# Epoch  2, Batch  70 - Loss:  1409.5494 Validation Accuracy: 0.769531
# Epoch  2, Batch  71 - Loss:   811.6855 Validation Accuracy: 0.765625
# Epoch  2, Batch  72 - Loss:  1766.3835 Validation Accuracy: 0.765625
# Epoch  2, Batch  73 - Loss:  1005.1500 Validation Accuracy: 0.765625
# Epoch  2, Batch  74 - Loss:  1001.9844 Validation Accuracy: 0.769531
# Epoch  2, Batch  75 - Loss:  1011.1393 Validation Accuracy: 0.765625
# Epoch  2, Batch  76 - Loss:   995.0198 Validation Accuracy: 0.773438
# Epoch  2, Batch  77 - Loss:  1422.9739 Validation Accuracy: 0.765625
# Epoch  2, Batch  78 - Loss:  1073.5227 Validation Accuracy: 0.769531
# Epoch  2, Batch  79 - Loss:   928.7151 Validation Accuracy: 0.777344
# Epoch  2, Batch  80 - Loss:  1038.4135 Validation Accuracy: 0.785156
# Epoch  2, Batch  81 - Loss:   733.4775 Validation Accuracy: 0.785156
# Epoch  2, Batch  82 - Loss:  2130.0176 Validation Accuracy: 0.785156
# Epoch  2, Batch  83 - Loss:  1554.6742 Validation Accuracy: 0.777344
# Epoch  2, Batch  84 - Loss:  1244.1921 Validation Accuracy: 0.777344
# Epoch  2, Batch  85 - Loss:  1608.3112 Validation Accuracy: 0.777344
# Epoch  2, Batch  86 - Loss:  1148.2714 Validation Accuracy: 0.777344
# Epoch  2, Batch  87 - Loss:  1796.0962 Validation Accuracy: 0.769531
# Epoch  2, Batch  88 - Loss:  1285.1989 Validation Accuracy: 0.773438
# Epoch  2, Batch  89 - Loss:  1355.7039 Validation Accuracy: 0.773438
# Epoch  2, Batch  90 - Loss:  1672.0872 Validation Accuracy: 0.769531
# Epoch  2, Batch  91 - Loss:   760.1776 Validation Accuracy: 0.773438
# Epoch  2, Batch  92 - Loss:  1208.7827 Validation Accuracy: 0.765625
# Epoch  2, Batch  93 - Loss:  1041.3353 Validation Accuracy: 0.761719
# Epoch  2, Batch  94 - Loss:  1515.2852 Validation Accuracy: 0.761719
# Epoch  2, Batch  95 - Loss:  1579.2765 Validation Accuracy: 0.761719
# Epoch  2, Batch  96 - Loss:  1107.3523 Validation Accuracy: 0.761719
# Epoch  2, Batch  97 - Loss:  1082.0253 Validation Accuracy: 0.769531
# Epoch  2, Batch  98 - Loss:  1622.3368 Validation Accuracy: 0.765625
# Epoch  2, Batch  99 - Loss:  1642.7400 Validation Accuracy: 0.769531
# Epoch  2, Batch 100 - Loss:   753.0074 Validation Accuracy: 0.781250
# Epoch  2, Batch 101 - Loss:  1621.7806 Validation Accuracy: 0.769531
# Epoch  2, Batch 102 - Loss:  1033.6057 Validation Accuracy: 0.757812
# Epoch  2, Batch 103 - Loss:   973.8620 Validation Accuracy: 0.761719
# Epoch  2, Batch 104 - Loss:  1217.7079 Validation Accuracy: 0.769531
# Epoch  2, Batch 105 - Loss:   843.8896 Validation Accuracy: 0.757812
# Epoch  2, Batch 106 - Loss:   800.7903 Validation Accuracy: 0.757812
# Epoch  2, Batch 107 - Loss:  1266.4342 Validation Accuracy: 0.769531
# Epoch  2, Batch 108 - Loss:  1416.9565 Validation Accuracy: 0.761719
# Epoch  2, Batch 109 - Loss:  1855.1971 Validation Accuracy: 0.757812
# Epoch  2, Batch 110 - Loss:  1814.3450 Validation Accuracy: 0.761719
# Epoch  2, Batch 111 - Loss:  1447.3473 Validation Accuracy: 0.769531
# Epoch  2, Batch 112 - Loss:  1137.3413 Validation Accuracy: 0.773438
# Epoch  2, Batch 113 - Loss:  1486.4344 Validation Accuracy: 0.781250
# Epoch  2, Batch 114 - Loss:   927.4335 Validation Accuracy: 0.781250
# Epoch  2, Batch 115 - Loss:  1043.3330 Validation Accuracy: 0.781250
# Epoch  2, Batch 116 - Loss:  1458.6760 Validation Accuracy: 0.785156
# Epoch  2, Batch 117 - Loss:  1691.2983 Validation Accuracy: 0.781250
# Epoch  2, Batch 118 - Loss:   928.4524 Validation Accuracy: 0.785156
# Epoch  2, Batch 119 - Loss:  1349.7527 Validation Accuracy: 0.785156
# Epoch  2, Batch 120 - Loss:   903.0283 Validation Accuracy: 0.777344
# Epoch  2, Batch 121 - Loss:  1500.0452 Validation Accuracy: 0.781250
# Epoch  2, Batch 122 - Loss:  1261.7897 Validation Accuracy: 0.785156
# Epoch  2, Batch 123 - Loss:  1483.0446 Validation Accuracy: 0.777344
# Epoch  2, Batch 124 - Loss:  1052.9462 Validation Accuracy: 0.781250
# Epoch  2, Batch 125 - Loss:  1523.3535 Validation Accuracy: 0.785156
# Epoch  2, Batch 126 - Loss:   702.8251 Validation Accuracy: 0.777344
# Epoch  2, Batch 127 - Loss:  1356.9828 Validation Accuracy: 0.785156
# Epoch  2, Batch 128 - Loss:  1312.9613 Validation Accuracy: 0.781250
# Epoch  2, Batch 129 - Loss:  1154.1322 Validation Accuracy: 0.785156
# Epoch  2, Batch 130 - Loss:  1054.2700 Validation Accuracy: 0.777344
# Epoch  2, Batch 131 - Loss:  1013.2694 Validation Accuracy: 0.781250
# Epoch  2, Batch 132 - Loss:  1733.4258 Validation Accuracy: 0.785156
# Epoch  2, Batch 133 - Loss:   699.9123 Validation Accuracy: 0.781250
# Epoch  2, Batch 134 - Loss:  1001.3854 Validation Accuracy: 0.785156
# Epoch  2, Batch 135 - Loss:  1685.9906 Validation Accuracy: 0.777344
# Epoch  2, Batch 136 - Loss:   785.7992 Validation Accuracy: 0.785156
# Epoch  2, Batch 137 - Loss:  1193.1061 Validation Accuracy: 0.789062
# Epoch  2, Batch 138 - Loss:  1418.9973 Validation Accuracy: 0.792969
# Epoch  2, Batch 139 - Loss:  1005.4683 Validation Accuracy: 0.789062
# Epoch  2, Batch 140 - Loss:  1138.0579 Validation Accuracy: 0.789062
# Epoch  2, Batch 141 - Loss:  1069.2330 Validation Accuracy: 0.785156
# Epoch  2, Batch 142 - Loss:  1138.5558 Validation Accuracy: 0.785156
# Epoch  2, Batch 143 - Loss:  1394.5688 Validation Accuracy: 0.785156
# Epoch  2, Batch 144 - Loss:   959.6677 Validation Accuracy: 0.781250
# Epoch  2, Batch 145 - Loss:  1498.3872 Validation Accuracy: 0.785156
# Epoch  2, Batch 146 - Loss:  1360.9177 Validation Accuracy: 0.781250
# Epoch  2, Batch 147 - Loss:  1697.7415 Validation Accuracy: 0.781250
# Epoch  2, Batch 148 - Loss:  1258.9987 Validation Accuracy: 0.785156
# Epoch  2, Batch 149 - Loss:  1414.0186 Validation Accuracy: 0.789062
# Epoch  2, Batch 150 - Loss:  1159.7720 Validation Accuracy: 0.789062
# Epoch  2, Batch 151 - Loss:  1314.9697 Validation Accuracy: 0.792969
# Epoch  2, Batch 152 - Loss:   470.5625 Validation Accuracy: 0.785156
# Epoch  2, Batch 153 - Loss:  1025.4355 Validation Accuracy: 0.785156
# Epoch  2, Batch 154 - Loss:  1722.1326 Validation Accuracy: 0.785156
# Epoch  2, Batch 155 - Loss:  1016.0398 Validation Accuracy: 0.796875
# Epoch  2, Batch 156 - Loss:  1109.0759 Validation Accuracy: 0.789062
# Epoch  2, Batch 157 - Loss:  1341.7253 Validation Accuracy: 0.785156
# Epoch  2, Batch 158 - Loss:  1322.9822 Validation Accuracy: 0.781250
# Epoch  2, Batch 159 - Loss:  1339.4572 Validation Accuracy: 0.781250
# Epoch  2, Batch 160 - Loss:  1267.9707 Validation Accuracy: 0.777344
# Epoch  2, Batch 161 - Loss:   837.6501 Validation Accuracy: 0.781250
# Epoch  2, Batch 162 - Loss:  1645.0571 Validation Accuracy: 0.789062
# Epoch  2, Batch 163 - Loss:  1037.1963 Validation Accuracy: 0.789062
# Epoch  2, Batch 164 - Loss:   887.9528 Validation Accuracy: 0.781250
# Epoch  2, Batch 165 - Loss:  1067.9053 Validation Accuracy: 0.785156
# Epoch  2, Batch 166 - Loss:  1005.7717 Validation Accuracy: 0.789062
# Epoch  2, Batch 167 - Loss:  1461.8105 Validation Accuracy: 0.785156
# Epoch  2, Batch 168 - Loss:  1241.4814 Validation Accuracy: 0.785156
# Epoch  2, Batch 169 - Loss:   933.9497 Validation Accuracy: 0.789062
# Epoch  2, Batch 170 - Loss:  1294.4297 Validation Accuracy: 0.777344
# Epoch  2, Batch 171 - Loss:   776.6683 Validation Accuracy: 0.789062
# Epoch  2, Batch 172 - Loss:  1107.8101 Validation Accuracy: 0.789062
# Epoch  2, Batch 173 - Loss:   684.2832 Validation Accuracy: 0.789062
# Epoch  2, Batch 174 - Loss:  1010.6154 Validation Accuracy: 0.781250
# Epoch  2, Batch 175 - Loss:  1178.1355 Validation Accuracy: 0.777344
# Epoch  2, Batch 176 - Loss:  1756.6730 Validation Accuracy: 0.773438
# Epoch  2, Batch 177 - Loss:  1042.0388 Validation Accuracy: 0.773438
# Epoch  2, Batch 178 - Loss:  1201.5793 Validation Accuracy: 0.781250
# Epoch  2, Batch 179 - Loss:  1075.9381 Validation Accuracy: 0.785156
# Epoch  2, Batch 180 - Loss:   761.2826 Validation Accuracy: 0.781250
# Epoch  2, Batch 181 - Loss:  1304.3152 Validation Accuracy: 0.781250
# Epoch  2, Batch 182 - Loss:  1375.5031 Validation Accuracy: 0.777344
# Epoch  2, Batch 183 - Loss:   968.8202 Validation Accuracy: 0.785156
# Epoch  2, Batch 184 - Loss:   685.1586 Validation Accuracy: 0.781250
# Epoch  2, Batch 185 - Loss:  1658.3779 Validation Accuracy: 0.781250
# Epoch  2, Batch 186 - Loss:   625.9477 Validation Accuracy: 0.785156
# Epoch  2, Batch 187 - Loss:   739.3077 Validation Accuracy: 0.785156
# Epoch  2, Batch 188 - Loss:   764.2635 Validation Accuracy: 0.785156
# Epoch  2, Batch 189 - Loss:   948.4296 Validation Accuracy: 0.789062
# Epoch  2, Batch 190 - Loss:  1322.7440 Validation Accuracy: 0.785156
# Epoch  2, Batch 191 - Loss:  1086.0989 Validation Accuracy: 0.781250
# Epoch  2, Batch 192 - Loss:  1057.4236 Validation Accuracy: 0.785156
# Epoch  2, Batch 193 - Loss:  1211.0173 Validation Accuracy: 0.781250
# Epoch  2, Batch 194 - Loss:  1012.4827 Validation Accuracy: 0.781250
# Epoch  2, Batch 195 - Loss:   790.6034 Validation Accuracy: 0.785156
# Epoch  2, Batch 196 - Loss:   702.8762 Validation Accuracy: 0.781250
# Epoch  2, Batch 197 - Loss:  1378.2725 Validation Accuracy: 0.785156
# Epoch  2, Batch 198 - Loss:  1417.4392 Validation Accuracy: 0.785156
# Epoch  2, Batch 199 - Loss:   779.4088 Validation Accuracy: 0.789062
# Epoch  2, Batch 200 - Loss:  1274.1270 Validation Accuracy: 0.785156
# Epoch  2, Batch 201 - Loss:   972.2099 Validation Accuracy: 0.781250
# Epoch  2, Batch 202 - Loss:  1065.8019 Validation Accuracy: 0.781250
# Epoch  2, Batch 203 - Loss:  1031.7765 Validation Accuracy: 0.781250
# Epoch  2, Batch 204 - Loss:  1011.8743 Validation Accuracy: 0.773438
# Epoch  2, Batch 205 - Loss:  1027.4517 Validation Accuracy: 0.781250
# Epoch  2, Batch 206 - Loss:  1331.4109 Validation Accuracy: 0.785156
# Epoch  2, Batch 207 - Loss:   753.2124 Validation Accuracy: 0.781250
# Epoch  2, Batch 208 - Loss:   896.5421 Validation Accuracy: 0.789062
# Epoch  2, Batch 209 - Loss:  1031.0304 Validation Accuracy: 0.781250
# Epoch  2, Batch 210 - Loss:   924.7466 Validation Accuracy: 0.789062
# Epoch  2, Batch 211 - Loss:  1413.3872 Validation Accuracy: 0.792969
# Epoch  2, Batch 212 - Loss:  1409.1589 Validation Accuracy: 0.792969
# Epoch  2, Batch 213 - Loss:  1388.1591 Validation Accuracy: 0.796875
# Epoch  2, Batch 214 - Loss:  1140.5037 Validation Accuracy: 0.796875
# Epoch  2, Batch 215 - Loss:  1411.8351 Validation Accuracy: 0.800781
# Epoch  2, Batch 216 - Loss:  1083.3815 Validation Accuracy: 0.796875
# Epoch  2, Batch 217 - Loss:  1414.5266 Validation Accuracy: 0.792969
# Epoch  2, Batch 218 - Loss:  1033.5211 Validation Accuracy: 0.789062
# Epoch  2, Batch 219 - Loss:  1175.8230 Validation Accuracy: 0.792969
# Epoch  2, Batch 220 - Loss:  1289.2898 Validation Accuracy: 0.792969
# Epoch  2, Batch 221 - Loss:   673.3613 Validation Accuracy: 0.792969
# Epoch  2, Batch 222 - Loss:  1082.0535 Validation Accuracy: 0.792969
# Epoch  2, Batch 223 - Loss:  1334.8491 Validation Accuracy: 0.796875
# Epoch  2, Batch 224 - Loss:  1286.7769 Validation Accuracy: 0.789062
# Epoch  2, Batch 225 - Loss:   891.2341 Validation Accuracy: 0.796875
# Epoch  2, Batch 226 - Loss:   797.6890 Validation Accuracy: 0.796875
# Epoch  2, Batch 227 - Loss:   975.8387 Validation Accuracy: 0.785156
# Epoch  2, Batch 228 - Loss:  1208.8254 Validation Accuracy: 0.792969
# Epoch  2, Batch 229 - Loss:  1472.7899 Validation Accuracy: 0.792969
# Epoch  2, Batch 230 - Loss:  1108.8337 Validation Accuracy: 0.792969
# Epoch  2, Batch 231 - Loss:  1212.9768 Validation Accuracy: 0.792969
# Epoch  2, Batch 232 - Loss:  1067.3285 Validation Accuracy: 0.789062
# Epoch  2, Batch 233 - Loss:  1120.6162 Validation Accuracy: 0.796875
# Epoch  2, Batch 234 - Loss:   914.8044 Validation Accuracy: 0.796875
# Epoch  2, Batch 235 - Loss:  1257.9552 Validation Accuracy: 0.796875
# Epoch  2, Batch 236 - Loss:  1115.0325 Validation Accuracy: 0.789062
# Epoch  2, Batch 237 - Loss:  1460.5637 Validation Accuracy: 0.789062
# Epoch  2, Batch 238 - Loss:   784.8796 Validation Accuracy: 0.781250
# Epoch  2, Batch 239 - Loss:  1020.6390 Validation Accuracy: 0.789062
# Epoch  2, Batch 240 - Loss:   884.1288 Validation Accuracy: 0.781250
# Epoch  2, Batch 241 - Loss:  1036.2449 Validation Accuracy: 0.792969
# Epoch  2, Batch 242 - Loss:  1054.8027 Validation Accuracy: 0.781250
# Epoch  2, Batch 243 - Loss:  1084.8081 Validation Accuracy: 0.789062
# Epoch  2, Batch 244 - Loss:  1298.9226 Validation Accuracy: 0.789062
# Epoch  2, Batch 245 - Loss:   902.0637 Validation Accuracy: 0.789062
# Epoch  2, Batch 246 - Loss:  1218.9688 Validation Accuracy: 0.789062
# Epoch  2, Batch 247 - Loss:   742.1041 Validation Accuracy: 0.785156
# Epoch  2, Batch 248 - Loss:   955.4879 Validation Accuracy: 0.781250
# Epoch  2, Batch 249 - Loss:  1079.4659 Validation Accuracy: 0.785156
# Epoch  2, Batch 250 - Loss:   452.5275 Validation Accuracy: 0.785156
# Epoch  2, Batch 251 - Loss:  1390.1429 Validation Accuracy: 0.792969
# Epoch  2, Batch 252 - Loss:   843.1553 Validation Accuracy: 0.792969
# Epoch  2, Batch 253 - Loss:  1023.0540 Validation Accuracy: 0.789062
# Epoch  2, Batch 254 - Loss:  1136.0775 Validation Accuracy: 0.785156
# Epoch  2, Batch 255 - Loss:   771.1963 Validation Accuracy: 0.792969
# Epoch  2, Batch 256 - Loss:   915.1765 Validation Accuracy: 0.792969
# Epoch  2, Batch 257 - Loss:  1130.7197 Validation Accuracy: 0.792969
# Epoch  2, Batch 258 - Loss:  1167.8032 Validation Accuracy: 0.785156
# Epoch  2, Batch 259 - Loss:   861.8234 Validation Accuracy: 0.800781
# Epoch  2, Batch 260 - Loss:  1312.5337 Validation Accuracy: 0.796875
# Epoch  2, Batch 261 - Loss:   650.4329 Validation Accuracy: 0.792969
# Epoch  2, Batch 262 - Loss:  1142.5481 Validation Accuracy: 0.792969
# Epoch  2, Batch 263 - Loss:   672.2025 Validation Accuracy: 0.792969
# Epoch  2, Batch 264 - Loss:   993.9834 Validation Accuracy: 0.785156
# Epoch  2, Batch 265 - Loss:  1174.4166 Validation Accuracy: 0.781250
# Epoch  2, Batch 266 - Loss:  1121.1393 Validation Accuracy: 0.785156
# ...
# Epoch 10, Batch 199 - Loss:   321.2767 Validation Accuracy: 0.875000
# Epoch 10, Batch 200 - Loss:   173.7793 Validation Accuracy: 0.875000
# Epoch 10, Batch 201 - Loss:   239.0776 Validation Accuracy: 0.871094
# Epoch 10, Batch 202 - Loss:   147.9446 Validation Accuracy: 0.871094
# Epoch 10, Batch 203 - Loss:   218.5234 Validation Accuracy: 0.871094
# Epoch 10, Batch 204 - Loss:   187.7124 Validation Accuracy: 0.871094
# Epoch 10, Batch 205 - Loss:   281.0553 Validation Accuracy: 0.871094
# Epoch 10, Batch 206 - Loss:   243.8486 Validation Accuracy: 0.871094
# Epoch 10, Batch 207 - Loss:   406.9049 Validation Accuracy: 0.878906
# Epoch 10, Batch 208 - Loss:   335.7026 Validation Accuracy: 0.875000
# Epoch 10, Batch 209 - Loss:   174.1811 Validation Accuracy: 0.878906
# Epoch 10, Batch 210 - Loss:   271.4542 Validation Accuracy: 0.875000
# Epoch 10, Batch 211 - Loss:   428.1201 Validation Accuracy: 0.875000
# Epoch 10, Batch 212 - Loss:   282.1290 Validation Accuracy: 0.875000
# Epoch 10, Batch 213 - Loss:   189.1196 Validation Accuracy: 0.875000
# Epoch 10, Batch 214 - Loss:   317.6776 Validation Accuracy: 0.875000
# Epoch 10, Batch 215 - Loss:   348.5956 Validation Accuracy: 0.878906
# Epoch 10, Batch 216 - Loss:   363.8913 Validation Accuracy: 0.878906
# Epoch 10, Batch 217 - Loss:   298.1798 Validation Accuracy: 0.882812
# Epoch 10, Batch 218 - Loss:   203.1618 Validation Accuracy: 0.882812
# Epoch 10, Batch 219 - Loss:   263.2588 Validation Accuracy: 0.875000
# Epoch 10, Batch 220 - Loss:   214.6387 Validation Accuracy: 0.875000
# Epoch 10, Batch 221 - Loss:   328.1426 Validation Accuracy: 0.878906
# Epoch 10, Batch 222 - Loss:   245.2221 Validation Accuracy: 0.878906
# Epoch 10, Batch 223 - Loss:   295.2766 Validation Accuracy: 0.875000
# Epoch 10, Batch 224 - Loss:   296.3117 Validation Accuracy: 0.871094
# Epoch 10, Batch 225 - Loss:   391.3676 Validation Accuracy: 0.871094
# Epoch 10, Batch 226 - Loss:   304.7200 Validation Accuracy: 0.871094
# Epoch 10, Batch 227 - Loss:   309.5463 Validation Accuracy: 0.875000
# Epoch 10, Batch 228 - Loss:   176.2933 Validation Accuracy: 0.875000
# Epoch 10, Batch 229 - Loss:   284.6737 Validation Accuracy: 0.875000
# Epoch 10, Batch 230 - Loss:   344.7118 Validation Accuracy: 0.878906
# Epoch 10, Batch 231 - Loss:   125.4073 Validation Accuracy: 0.875000
# Epoch 10, Batch 232 - Loss:   155.5967 Validation Accuracy: 0.875000
# Epoch 10, Batch 233 - Loss:   300.8868 Validation Accuracy: 0.878906
# Epoch 10, Batch 234 - Loss:   179.8097 Validation Accuracy: 0.875000
# Epoch 10, Batch 235 - Loss:   309.8116 Validation Accuracy: 0.878906
# Epoch 10, Batch 236 - Loss:   260.4602 Validation Accuracy: 0.882812
# Epoch 10, Batch 237 - Loss:   174.9247 Validation Accuracy: 0.882812
# Epoch 10, Batch 238 - Loss:   283.9776 Validation Accuracy: 0.878906
# Epoch 10, Batch 239 - Loss:   291.8478 Validation Accuracy: 0.878906
# Epoch 10, Batch 240 - Loss:   301.9463 Validation Accuracy: 0.878906
# Epoch 10, Batch 241 - Loss:   302.1668 Validation Accuracy: 0.878906
# Epoch 10, Batch 242 - Loss:   356.1926 Validation Accuracy: 0.878906
# Epoch 10, Batch 243 - Loss:   485.3472 Validation Accuracy: 0.878906
# Epoch 10, Batch 244 - Loss:   202.5554 Validation Accuracy: 0.882812
# Epoch 10, Batch 245 - Loss:   289.4886 Validation Accuracy: 0.882812
# Epoch 10, Batch 246 - Loss:   220.7048 Validation Accuracy: 0.882812
# Epoch 10, Batch 247 - Loss:   209.9193 Validation Accuracy: 0.882812
# Epoch 10, Batch 248 - Loss:   349.3186 Validation Accuracy: 0.882812
# Epoch 10, Batch 249 - Loss:   275.2625 Validation Accuracy: 0.882812
# Epoch 10, Batch 250 - Loss:   450.7772 Validation Accuracy: 0.882812
# Epoch 10, Batch 251 - Loss:   359.1401 Validation Accuracy: 0.875000
# Epoch 10, Batch 252 - Loss:   207.9821 Validation Accuracy: 0.875000
# Epoch 10, Batch 253 - Loss:    77.3317 Validation Accuracy: 0.875000
# Epoch 10, Batch 254 - Loss:   398.2148 Validation Accuracy: 0.878906
# Epoch 10, Batch 255 - Loss:   194.8218 Validation Accuracy: 0.878906
# Epoch 10, Batch 256 - Loss:   342.4586 Validation Accuracy: 0.878906
# Epoch 10, Batch 257 - Loss:   613.8031 Validation Accuracy: 0.878906
# Epoch 10, Batch 258 - Loss:   220.1112 Validation Accuracy: 0.878906
# Epoch 10, Batch 259 - Loss:   184.2099 Validation Accuracy: 0.878906
# Epoch 10, Batch 260 - Loss:   123.2488 Validation Accuracy: 0.878906
# Epoch 10, Batch 261 - Loss:   365.2649 Validation Accuracy: 0.882812
# Epoch 10, Batch 262 - Loss:   191.7961 Validation Accuracy: 0.878906
# Epoch 10, Batch 263 - Loss:   225.8979 Validation Accuracy: 0.878906
# Epoch 10, Batch 264 - Loss:   117.5705 Validation Accuracy: 0.878906
# Epoch 10, Batch 265 - Loss:   353.5362 Validation Accuracy: 0.878906
# Epoch 10, Batch 266 - Loss:   241.5426 Validation Accuracy: 0.875000
# Epoch 10, Batch 267 - Loss:   307.8441 Validation Accuracy: 0.882812
# Epoch 10, Batch 268 - Loss:   293.0516 Validation Accuracy: 0.882812
# Epoch 10, Batch 269 - Loss:   293.9263 Validation Accuracy: 0.878906
# Epoch 10, Batch 270 - Loss:   216.9495 Validation Accuracy: 0.882812
# Epoch 10, Batch 271 - Loss:   230.5133 Validation Accuracy: 0.882812
# Epoch 10, Batch 272 - Loss:   344.0378 Validation Accuracy: 0.878906
# Epoch 10, Batch 273 - Loss:   295.2599 Validation Accuracy: 0.878906
# Epoch 10, Batch 274 - Loss:   209.1459 Validation Accuracy: 0.878906
# Epoch 10, Batch 275 - Loss:   286.0218 Validation Accuracy: 0.878906
# Epoch 10, Batch 276 - Loss:   275.5101 Validation Accuracy: 0.882812
# Epoch 10, Batch 277 - Loss:   170.9329 Validation Accuracy: 0.882812
# Epoch 10, Batch 278 - Loss:   321.7123 Validation Accuracy: 0.882812
# Epoch 10, Batch 279 - Loss:   258.3224 Validation Accuracy: 0.882812
# Epoch 10, Batch 280 - Loss:   153.4068 Validation Accuracy: 0.878906
# Epoch 10, Batch 281 - Loss:   148.0448 Validation Accuracy: 0.875000
# Epoch 10, Batch 282 - Loss:   104.6909 Validation Accuracy: 0.875000
# Epoch 10, Batch 283 - Loss:   262.0367 Validation Accuracy: 0.875000
# Epoch 10, Batch 284 - Loss:   396.6481 Validation Accuracy: 0.878906
# Epoch 10, Batch 285 - Loss:   372.8450 Validation Accuracy: 0.875000
# Epoch 10, Batch 286 - Loss:   308.2590 Validation Accuracy: 0.875000
# Epoch 10, Batch 287 - Loss:   357.5066 Validation Accuracy: 0.875000
# Epoch 10, Batch 288 - Loss:   359.9733 Validation Accuracy: 0.875000
# Epoch 10, Batch 289 - Loss:   267.3610 Validation Accuracy: 0.875000
# Epoch 10, Batch 290 - Loss:   255.9411 Validation Accuracy: 0.875000
# Epoch 10, Batch 291 - Loss:   218.7363 Validation Accuracy: 0.875000
# Epoch 10, Batch 292 - Loss:   287.5331 Validation Accuracy: 0.875000
# Epoch 10, Batch 293 - Loss:   228.6006 Validation Accuracy: 0.875000
# Epoch 10, Batch 294 - Loss:   287.2031 Validation Accuracy: 0.875000
# Epoch 10, Batch 295 - Loss:   421.3357 Validation Accuracy: 0.875000
# Epoch 10, Batch 296 - Loss:   165.1765 Validation Accuracy: 0.875000
# Epoch 10, Batch 297 - Loss:   212.0626 Validation Accuracy: 0.875000
# Epoch 10, Batch 298 - Loss:   291.0326 Validation Accuracy: 0.875000
# Epoch 10, Batch 299 - Loss:   150.3490 Validation Accuracy: 0.875000
# Epoch 10, Batch 300 - Loss:   214.7664 Validation Accuracy: 0.878906
# Epoch 10, Batch 301 - Loss:   299.9096 Validation Accuracy: 0.882812
# Epoch 10, Batch 302 - Loss:   148.9260 Validation Accuracy: 0.882812
# Epoch 10, Batch 303 - Loss:   220.7983 Validation Accuracy: 0.882812
# Epoch 10, Batch 304 - Loss:   100.9083 Validation Accuracy: 0.882812
# Epoch 10, Batch 305 - Loss:   262.5280 Validation Accuracy: 0.878906
# Epoch 10, Batch 306 - Loss:   254.1494 Validation Accuracy: 0.875000
# Epoch 10, Batch 307 - Loss:   296.3698 Validation Accuracy: 0.878906
# Epoch 10, Batch 308 - Loss:   322.1735 Validation Accuracy: 0.878906
# Epoch 10, Batch 309 - Loss:   228.2536 Validation Accuracy: 0.878906
# Epoch 10, Batch 310 - Loss:   225.1440 Validation Accuracy: 0.878906
# Epoch 10, Batch 311 - Loss:   372.5031 Validation Accuracy: 0.878906
# Epoch 10, Batch 312 - Loss:   244.0405 Validation Accuracy: 0.878906
# Epoch 10, Batch 313 - Loss:   261.6147 Validation Accuracy: 0.875000
# Epoch 10, Batch 314 - Loss:   334.4716 Validation Accuracy: 0.875000
# Epoch 10, Batch 315 - Loss:   235.8839 Validation Accuracy: 0.875000
# Epoch 10, Batch 316 - Loss:   199.2065 Validation Accuracy: 0.878906
# Epoch 10, Batch 317 - Loss:   283.0274 Validation Accuracy: 0.875000
# Epoch 10, Batch 318 - Loss:   152.7902 Validation Accuracy: 0.875000
# Epoch 10, Batch 319 - Loss:   312.2078 Validation Accuracy: 0.875000
# Epoch 10, Batch 320 - Loss:   322.3852 Validation Accuracy: 0.878906
# Epoch 10, Batch 321 - Loss:   351.1911 Validation Accuracy: 0.875000
# Epoch 10, Batch 322 - Loss:   307.7719 Validation Accuracy: 0.878906
# Epoch 10, Batch 323 - Loss:   298.3345 Validation Accuracy: 0.878906
# Epoch 10, Batch 324 - Loss:   194.7592 Validation Accuracy: 0.875000
# Epoch 10, Batch 325 - Loss:   124.7754 Validation Accuracy: 0.871094
# Epoch 10, Batch 326 - Loss:   139.4981 Validation Accuracy: 0.875000
# Epoch 10, Batch 327 - Loss:   128.6815 Validation Accuracy: 0.875000
# Epoch 10, Batch 328 - Loss:   284.9405 Validation Accuracy: 0.875000
# Epoch 10, Batch 329 - Loss:   255.5670 Validation Accuracy: 0.878906
# Epoch 10, Batch 330 - Loss:   157.5300 Validation Accuracy: 0.878906
# Epoch 10, Batch 331 - Loss:   191.7250 Validation Accuracy: 0.878906
# Epoch 10, Batch 332 - Loss:   201.2935 Validation Accuracy: 0.878906
# Epoch 10, Batch 333 - Loss:   236.9975 Validation Accuracy: 0.878906
# Epoch 10, Batch 334 - Loss:   159.1493 Validation Accuracy: 0.875000
# Epoch 10, Batch 335 - Loss:   195.4108 Validation Accuracy: 0.875000
# Epoch 10, Batch 336 - Loss:   248.2018 Validation Accuracy: 0.875000
# Epoch 10, Batch 337 - Loss:   255.0600 Validation Accuracy: 0.875000
# Epoch 10, Batch 338 - Loss:   228.2499 Validation Accuracy: 0.871094
# Epoch 10, Batch 339 - Loss:   160.1499 Validation Accuracy: 0.871094
# Epoch 10, Batch 340 - Loss:   259.4020 Validation Accuracy: 0.875000
# Epoch 10, Batch 341 - Loss:   239.7366 Validation Accuracy: 0.875000
# Epoch 10, Batch 342 - Loss:   351.3377 Validation Accuracy: 0.882812
# Epoch 10, Batch 343 - Loss:   221.7757 Validation Accuracy: 0.878906
# Epoch 10, Batch 344 - Loss:   218.4774 Validation Accuracy: 0.878906
# Epoch 10, Batch 345 - Loss:   232.9858 Validation Accuracy: 0.878906
# Epoch 10, Batch 346 - Loss:   218.6620 Validation Accuracy: 0.882812
# Epoch 10, Batch 347 - Loss:   247.2338 Validation Accuracy: 0.882812
# Epoch 10, Batch 348 - Loss:   153.1759 Validation Accuracy: 0.882812
# Epoch 10, Batch 349 - Loss:   273.8654 Validation Accuracy: 0.882812
# Epoch 10, Batch 350 - Loss:   143.8770 Validation Accuracy: 0.882812
# Epoch 10, Batch 351 - Loss:   130.9301 Validation Accuracy: 0.882812
# Epoch 10, Batch 352 - Loss:   406.9926 Validation Accuracy: 0.882812
# Epoch 10, Batch 353 - Loss:   164.9906 Validation Accuracy: 0.882812
# Epoch 10, Batch 354 - Loss:   268.2174 Validation Accuracy: 0.878906
# Epoch 10, Batch 355 - Loss:   267.6923 Validation Accuracy: 0.882812
# Epoch 10, Batch 356 - Loss:   222.5782 Validation Accuracy: 0.882812
# Epoch 10, Batch 357 - Loss:   355.8932 Validation Accuracy: 0.882812
# Epoch 10, Batch 358 - Loss:   301.3283 Validation Accuracy: 0.878906
# Epoch 10, Batch 359 - Loss:   411.9860 Validation Accuracy: 0.878906
# Epoch 10, Batch 360 - Loss:   299.5679 Validation Accuracy: 0.878906
# Epoch 10, Batch 361 - Loss:   126.4492 Validation Accuracy: 0.882812
# Epoch 10, Batch 362 - Loss:   159.3051 Validation Accuracy: 0.878906
# Epoch 10, Batch 363 - Loss:   332.1344 Validation Accuracy: 0.878906
# Epoch 10, Batch 364 - Loss:   220.9886 Validation Accuracy: 0.875000
# Epoch 10, Batch 365 - Loss:   360.3621 Validation Accuracy: 0.875000
# Epoch 10, Batch 366 - Loss:   247.2323 Validation Accuracy: 0.878906
# Epoch 10, Batch 367 - Loss:   295.7972 Validation Accuracy: 0.875000
# Epoch 10, Batch 368 - Loss:   281.1169 Validation Accuracy: 0.875000
# Epoch 10, Batch 369 - Loss:   279.1512 Validation Accuracy: 0.878906
# Epoch 10, Batch 370 - Loss:   457.3445 Validation Accuracy: 0.875000
# Epoch 10, Batch 371 - Loss:   323.7607 Validation Accuracy: 0.875000
# Epoch 10, Batch 372 - Loss:   278.1057 Validation Accuracy: 0.878906
# Epoch 10, Batch 373 - Loss:   426.1588 Validation Accuracy: 0.875000
# Epoch 10, Batch 374 - Loss:   344.2050 Validation Accuracy: 0.878906
# Epoch 10, Batch 375 - Loss:   278.4707 Validation Accuracy: 0.878906
# Epoch 10, Batch 376 - Loss:   232.0225 Validation Accuracy: 0.878906
# Epoch 10, Batch 377 - Loss:   245.9091 Validation Accuracy: 0.878906
# Epoch 10, Batch 378 - Loss:   214.6927 Validation Accuracy: 0.878906
# Epoch 10, Batch 379 - Loss:   225.1679 Validation Accuracy: 0.878906
# Epoch 10, Batch 380 - Loss:   230.3458 Validation Accuracy: 0.878906
# Epoch 10, Batch 381 - Loss:   199.8683 Validation Accuracy: 0.878906
# Epoch 10, Batch 382 - Loss:   251.9321 Validation Accuracy: 0.878906
# Epoch 10, Batch 383 - Loss:   306.6731 Validation Accuracy: 0.878906
# Epoch 10, Batch 384 - Loss:   361.7120 Validation Accuracy: 0.878906
# Epoch 10, Batch 385 - Loss:   161.3349 Validation Accuracy: 0.878906
# Epoch 10, Batch 386 - Loss:   109.9921 Validation Accuracy: 0.878906
# Epoch 10, Batch 387 - Loss:   280.5062 Validation Accuracy: 0.878906
# Epoch 10, Batch 388 - Loss:   275.1654 Validation Accuracy: 0.878906
# Epoch 10, Batch 389 - Loss:   253.0666 Validation Accuracy: 0.878906
# Epoch 10, Batch 390 - Loss:   151.3568 Validation Accuracy: 0.878906
# Epoch 10, Batch 391 - Loss:   205.1407 Validation Accuracy: 0.878906
# Epoch 10, Batch 392 - Loss:   267.1972 Validation Accuracy: 0.875000
# Epoch 10, Batch 393 - Loss:   276.3151 Validation Accuracy: 0.875000
# Epoch 10, Batch 394 - Loss:   240.9898 Validation Accuracy: 0.875000
# Epoch 10, Batch 395 - Loss:   325.8594 Validation Accuracy: 0.875000
# Epoch 10, Batch 396 - Loss:   345.4329 Validation Accuracy: 0.875000
# Epoch 10, Batch 397 - Loss:   296.3015 Validation Accuracy: 0.875000
# Epoch 10, Batch 398 - Loss:   265.4403 Validation Accuracy: 0.882812
# Epoch 10, Batch 399 - Loss:   364.7859 Validation Accuracy: 0.882812
# Epoch 10, Batch 400 - Loss:   227.9099 Validation Accuracy: 0.882812
# Epoch 10, Batch 401 - Loss:   291.9108 Validation Accuracy: 0.878906
# Epoch 10, Batch 402 - Loss:   236.8568 Validation Accuracy: 0.875000
# Epoch 10, Batch 403 - Loss:   178.0896 Validation Accuracy: 0.875000
# Epoch 10, Batch 404 - Loss:   177.6629 Validation Accuracy: 0.878906
# Epoch 10, Batch 405 - Loss:   111.9476 Validation Accuracy: 0.875000
# Epoch 10, Batch 406 - Loss:   195.0801 Validation Accuracy: 0.875000
# Epoch 10, Batch 407 - Loss:   222.9901 Validation Accuracy: 0.875000
# Epoch 10, Batch 408 - Loss:   167.3997 Validation Accuracy: 0.875000
# Epoch 10, Batch 409 - Loss:   366.9933 Validation Accuracy: 0.875000
# Epoch 10, Batch 410 - Loss:   120.4869 Validation Accuracy: 0.875000
# Epoch 10, Batch 411 - Loss:   303.8811 Validation Accuracy: 0.875000
# Epoch 10, Batch 412 - Loss:   182.2478 Validation Accuracy: 0.875000
# Epoch 10, Batch 413 - Loss:   179.2709 Validation Accuracy: 0.878906
# Epoch 10, Batch 414 - Loss:   320.1567 Validation Accuracy: 0.878906
# Epoch 10, Batch 415 - Loss:   275.7445 Validation Accuracy: 0.882812
# Epoch 10, Batch 416 - Loss:   124.5942 Validation Accuracy: 0.882812
# Epoch 10, Batch 417 - Loss:   200.4881 Validation Accuracy: 0.882812
# Epoch 10, Batch 418 - Loss:   360.0959 Validation Accuracy: 0.882812
# Epoch 10, Batch 419 - Loss:   227.4165 Validation Accuracy: 0.882812
# Epoch 10, Batch 420 - Loss:   255.8064 Validation Accuracy: 0.882812
# Epoch 10, Batch 421 - Loss:   167.1089 Validation Accuracy: 0.878906
# Epoch 10, Batch 422 - Loss:   300.0807 Validation Accuracy: 0.882812
# Epoch 10, Batch 423 - Loss:   250.5944 Validation Accuracy: 0.878906
# Epoch 10, Batch 424 - Loss:   216.9382 Validation Accuracy: 0.878906
# Epoch 10, Batch 425 - Loss:   274.3071 Validation Accuracy: 0.878906
# Epoch 10, Batch 426 - Loss:   203.4363 Validation Accuracy: 0.878906
# Epoch 10, Batch 427 - Loss:   218.9312 Validation Accuracy: 0.878906
# Epoch 10, Batch 428 - Loss:   287.3615 Validation Accuracy: 0.878906
# Epoch 10, Batch 429 - Loss:   199.9969 Validation Accuracy: 0.878906
# Testing Accuracy: 0.859375

# %% [markdown]
# ## FilterShapeCalculator

# %%
class FilterShapeCalculator:
    
    def compute_filter_shape(self, input_shape, output_shape, strides):
        filter_height = None
        filter_width = None
        
        for f_h in range(input_shape[1], 1, -1):
            # out_height = ceil(float(in_height - filter_height + 1) / float(strides[1]))
            out_h = math.ceil(float(input_shape[1] - f_h + 1) / float(strides[1]))

            if out_h == output_shape[1]:
                filter_height = f_h
                break
                
        for f_w in range(input_shape[2], 1, -1):
            # out_width = ceil(float(in_width - filter_width + 1) / float(strides[2]))
            out_w = math.ceil(float(input_shape[2] - f_w + 1) / float(strides[2]))
            
            if out_w == output_shape[2]:
                filter_width = f_w
                break
                
        return (filter_height, filter_width)

# %%
input_shape = (1, 4, 4, 1)
output_shape = (1, 2, 2, 3)
strides = (1, 2, 2, 1)

calculator = FilterShapeCalculator()
filter_shape = calculator.compute_filter_shape(input_shape, output_shape, strides)
print(filter_shape)
# Out:
# (2, 2)

# %% [markdown]
# ## TensorflowConvLayer

# %%
class TensorflowConvLayer:
    
    def conv2d(self, input, input_shape, output_shape):
        """
        Setup the strides, padding and filter weight/bias such that
        the output shape is (1, 2, 2, 3).
        """
        
        # Set the stride for each dimension (batch_size, height, width, depth)
        strides = [1, 2, 2, 1]
        
        calculator = FilterShapeCalculator()
        filter_shape = calculator.compute_filter_shape(input_shape, output_shape, strides)
        
        # Filter (weights and bias)
        # The shape of the filter weight is (height, width, input_depth, output_depth)
        # The shape of the filter bias is (output_depth,)
        filter_weights = tf.Variable(tf.truncated_normal((filter_shape[0], 
                                                          filter_shape[1], 
                                                          input_shape[3], 
                                                          output_shape[3])))
        filter_biases = tf.Variable(tf.zeros(output_shape[3]))

        # Set the padding, either 'VALID' or 'SAME'
        padding = 'VALID'
        
        return tf.add(tf.nn.conv2d(input, filter_weights, strides, padding), filter_biases)

# %%
# tf.nn.conv2d() requires the input be 4D (batch_size, height, width, depth)
# (1, 4, 4, 1)
x = np.array([
    [0, 1, 0.5, 10],
    [2, 2.5, 1, -8],
    [4, 0, 5, 6],
    [15, 1, 2, 3]], dtype=np.float32).reshape(input_shape)

X = tf.constant(x)

convLayer = TensorflowConvLayer()
conv_output = convLayer.conv2d(X, input_shape, output_shape)

print(conv_output.shape)
# Out:
# (1, 2, 2, 3)

# %% [markdown]
# ## TensorflowPoolingLayer

# %%
class TensorflowPoolingLayer:
    
    def maxpool2d(self, input, input_shape, output_shape):
        """
        Set the values to `strides` and `ksize` such that
        the output shape after pooling is (1, 2, 2, 1).
        """
        
        # Set the stride for each dimension (batch_size, height, width, depth)
        strides = [1, 2, 2, 1]
        
        # Set the ksize (filter size) for each dimension (batch_size, height, width, depth)
        calculator = FilterShapeCalculator()
        filter_shape = calculator.compute_filter_shape(input_shape, output_shape, strides)
        ksize = [1, filter_shape[0], filter_shape[1], 1]
        
        # Set the padding, either 'VALID' or 'SAME'.
        padding = 'VALID'
        
        return tf.nn.max_pool(input, ksize, strides, padding)

# %%
output_shape = (1, 2, 2, 1)

poolLayer = TensorflowPoolingLayer()
pool_output = poolLayer.maxpool2d(X, input_shape, output_shape)

print(pool_output.shape)
# Out:
# (1, 2, 2, 1)
