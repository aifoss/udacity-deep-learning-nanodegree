# %%
from __future__ import print_function

from keras import utils
from keras import backend as K
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Reshape
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import UpSampling2D
from keras.layers.convolutional import Convolution2D, AveragePooling2D
from keras.optimizers import SGD, Adam

import numpy as np

from PIL import Image, ImageOps

import argparse
import math
import os
import os.path
import glob

K.set_image_dim_ordering('th') # ensure our dimension notation matches
# Out:
# Using TensorFlow backend.

# %%
G_WGTS_FILE = 'goodgenerator.h5'
D_WGTS_FILE = 'gooddiscriminator.h5'

ENTROPY = 'binary_crossentropy'
SGD_OPT = 'SGD'

EPOCHS = 400
BATCH_SIZE = 10

# %%
# !mkdir logo-generated-images
# Out:
# mkdir: cannot create directory ‘logo-generated-images’: File exists

# %% [markdown]
# ## Loading Data

# %%
class DataLoader:
    
    def get_train_image_set(self):
        '''
        Return formatted train image set from loaded dataset.
        '''
        X_train = self.load_train_image_data()
        X_train = (X_train.astype(np.float32)-127.5)/127.5
        X_train = X_train.reshape((X_train.shape[0], 1) + X_train.shape[1:])
        print('X_train.shape: {}'.format(X_train.shape))
        return X_train
    
    
    def load_train_image_data(self, pixels=128, verbose=False):
        '''
        Load image dataset from directory.
        '''
        print("Loading data...")
        
        X_train = []
        paths = glob.glob(os.path.normpath(os.getcwd()+'/logos/*.jpg'))
        
        for path in paths:
            if verbose: print(path)
            
            im = Image.open(path)
            im = ImageOps.fit(im, (pixels, pixels), Image.ANTIALIAS)
            im = ImageOps.grayscale(im)
            im = np.asarray(im)
            
            X_train.append(im)
            
        print("Finished loading data")
        
        return np.array(X_train)

# %%
dataLoader = DataLoader()

X_train = dataLoader.get_train_image_set()
# Out:
# Loading data...
# Finished loading data
# X_train.shape: (38, 1, 128, 128)

# %% [markdown]
# ## Creating Models

# %%
class ModelCreator:
    
    def generator_model(self):
        '''
        Build generator model.
        '''
        model = Sequential()
        model.add(Dense(input_dim=100, units=1024))
        model.add(Activation('tanh'))
        model.add(Dense(128*8*8))
        model.add(BatchNormalization())
        model.add(Activation('tanh'))
        model.add(Reshape((128, 8, 8), input_shape=(128*8*8,)))
        model.add(UpSampling2D(size=(4, 4)))
        model.add(Convolution2D(64, (5, 5), padding='same'))
        model.add(Activation('tanh'))
        model.add(UpSampling2D(size=(4, 4)))
        model.add(Convolution2D(1, (5, 5), padding='same'))
        model.add(Activation('tanh'))
        return model
    
    
    def discriminator_model(self):
        '''
        Build discriminator model.
        '''
        model = Sequential()
        model.add(Convolution2D(64, (5, 5), padding='same', input_shape=(1, 128, 128)))
        model.add(Activation('tanh'))
        model.add(AveragePooling2D(pool_size=(4, 4)))
        model.add(Convolution2D(128, (5, 5)))
        model.add(Activation('tanh'))
        model.add(AveragePooling2D(pool_size=(2, 2)))
        model.add(Flatten())
        model.add(Dense(256))
        model.add(Activation('tanh'))
        model.add(Dense(1))
        model.add(Activation('sigmoid'))
        return model
    
    
    def generator_containing_discriminator(self, generator, discriminator):
        '''
        Build generator model containing discriminator.
        '''
        model = Sequential()
        model.add(generator)
        discriminator.trainable = False
        model.add(discriminator)
        return model

# %%
class ModelCompiler:
    
    def compile_models(self, load_weights=False):
        '''
        Build and compile models.
        
        :param load_weights: Indicates whether or not to load weights from files.
        '''
        
        modelCreator = ModelCreator()
        
        # Create models
        generator = modelCreator.generator_model()
        discriminator = modelCreator.discriminator_model()
        
        # Load weights
        if load_weights:
            self.load_weights(generator, discriminator)
  
        # Create generator containing discriminator
        discriminator_on_generator = \
            modelCreator.generator_containing_discriminator(generator, discriminator)

        # Add losses and optimizers
        g_opt = SGD(lr=0.0005, momentum=0.9, nesterov=True)
        d_opt = SGD(lr=0.0005, momentum=0.9, nesterov=True)
        
        generator.compile(loss=ENTROPY, optimizer=SGD_OPT)
        discriminator_on_generator.compile(loss=ENTROPY, optimizer=g_opt)
        discriminator.trainable = True
        discriminator.compile(loss=ENTROPY, optimizer=d_opt)
        
        return (generator, discriminator, discriminator_on_generator)
    
        
    def load_weights(self, generator, discriminator):
        '''
        Load weights from files.
        '''
        generator.load_weights(G_WGTS_FILE, True)
        discriminator.load_weights(D_WGTS_FILE, True)
        
        
    def print_models(self, generator, discriminator, discriminator_on_generator):
        print('\ngenerator:')
        generator.summary()
        print('\n\ndiscriminator:')
        discriminator.summary()
        print('\n\ndiscriminator_on_generator:')
        discriminator_on_generator.summary()
        print('')

# %%
modelCompiler = ModelCompiler()

models = modelCompiler.compile_models()

modelCompiler.print_models(*models)
# Out:
# generator:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              103424
# _________________________________________________________________
# activation_1 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8192)              8396800
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 8192)              32768
# _________________________________________________________________
# activation_2 (Activation)    (None, 8192)              0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 128, 8, 8)         0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 128, 32, 32)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 32, 32)        204864
# _________________________________________________________________
# activation_3 (Activation)    (None, 64, 32, 32)        0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 64, 128, 128)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 1, 128, 128)       1601
# _________________________________________________________________
# activation_4 (Activation)    (None, 1, 128, 128)       0
# =================================================================
# Total params: 8,739,457
# Trainable params: 8,723,073
# Non-trainable params: 16,384
# _________________________________________________________________
#
#
# discriminator:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 64, 128, 128)      1664
# _________________________________________________________________
# activation_5 (Activation)    (None, 64, 128, 128)      0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 64, 32, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 128, 28, 28)       204928
# _________________________________________________________________
# activation_6 (Activation)    (None, 128, 28, 28)       0
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 128, 14, 14)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               6422784
# _________________________________________________________________
# activation_7 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 257
# _________________________________________________________________
# activation_8 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 6,629,633
# Trainable params: 6,629,633
# Non-trainable params: 0
# _________________________________________________________________
#
#
# discriminator_on_generator:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_1 (Sequential)    (None, 1, 128, 128)       8739457
# _________________________________________________________________
# sequential_2 (Sequential)    (None, 1)                 6629633
# =================================================================
# Total params: 15,369,090
# Trainable params: 15,352,706
# Non-trainable params: 16,384
# _________________________________________________________________

# %%
class ModelTrainer:
    
    def train_models(self, models, X_train, load_weights=False):
        '''
        Train models.
        
        :param models: Models to train
        :param X_train: Training image dataset
        :param load_weights: Whether or not to create models with weights loaded from files
        '''
        
        # Load models with saved weights
        if load_weights:
            models = ModelCompiler().compile_models(True)
        
        generator = models[0]
        discriminator = models[1]
        discriminator_on_generator = models[2]
        
        imageProcessor = ImageProcessor()
        
        # Initialize noise
        noise = np.zeros((BATCH_SIZE, 100))
        
        for epoch in range(EPOCHS):
            print('\nEpoch: {}'.format(epoch+1))
            
            n_batches = int(X_train.shape[0]/BATCH_SIZE)
            
            for idx in range(n_batches):
                # Randomize noise
                Util().randomize_noise(noise, BATCH_SIZE)
                    
                image_batch = X_train[idx*BATCH_SIZE:(idx+1)*BATCH_SIZE]
                generated_images = generator.predict(noise, verbose=0)
                
                # Save image
                if idx % 20 == 0 and epoch % 10 == 0:
                    imageProcessor.save_image(epoch, idx, generated_images)
                
                # Compute and log discriminator loss
                self.compute_d_loss(idx, discriminator, image_batch, generated_images)        
               
                # Randomize noise
                Util().randomize_noise(noise, BATCH_SIZE)
            
                # Compute and log generator loss
                self.compute_g_loss(idx, discriminator, discriminator_on_generator, noise)
            
                if epoch % 10 == 9:
                    self.save_weights(generator, discriminator)

        print('\nTraining complete\n')
        

    def compute_d_loss(self, idx, discriminator, image_batch, generated_images):
        '''
        Compute discriminator loss.
        '''
        X = np.concatenate((image_batch, generated_images))
        y = [1]*BATCH_SIZE + [0]*BATCH_SIZE
        d_loss = discriminator.train_on_batch(X, y)
        print("batch %d d_loss : %f" % (idx+1, d_loss))

        
    def compute_g_loss(self, idx, discriminator, discriminator_on_generator, noise):
        '''
        Compute generator loss.
        '''
        discriminator.trainable = False
        g_loss = discriminator_on_generator.train_on_batch(noise, [1]*BATCH_SIZE)
        discriminator.trainable = True
        print("batch %d g_loss : %f" % (idx+1, g_loss))
    
    
    def save_weights(self, generator, discriminator):
        '''
        Save trained weights to files.
        '''
        generator.save_weights(G_WGTS_FILE)
        discriminator.save_weights(D_WGTS_FILE)

# %%
class Util:
    
    def randomize_noise(self, noise, batch_size):
        '''
        Randomize noise matrix.
        '''
        for i in range(batch_size):
            noise[i, :] = np.random.uniform(-1, 1, 100)

# %%
class ImageProcessor:
    
    def save_image(self, epoch, idx, images):
        '''
        Save generated images.
        '''
        image = self.combine_images(images)
        image = image * 127.5 + 127.5

        path_str = os.getcwd() + '/logo-generated-images/'\
                               + str(epoch+1)+'_'+str(idx)+'.png'
        dst_path = os.path.normpath(path_str)
        
        Image.fromarray(image.astype(np.uint8)).save(dst_path)

        
    def combine_images(self, images):
        '''
        Combine generated images.
        '''
        num = images.shape[0]
        width = int(math.sqrt(num))
        height = int(math.ceil(float(num)/width))
        shape = images.shape[2:]
        
        image = np.zeros((height*shape[0], width*shape[1]),
                          dtype=images.dtype)
        
        for idx, img in enumerate(images):
            i = int(idx/width)
            j = idx % width
            
            image[i*shape[0]:(i+1)*shape[0], j*shape[1]:(j+1)*shape[1]] = img[0, :, :]
        
        return image
    
    
    def clean(self, image):
        '''
        Clean image.
        '''
        for i in range(1, image.shape[0]-1):
            for j in range(1, image.shape[1]-1):
                if image[i][j] \
                        + image[i+1][j] + image[i][j+1] \
                        + image[i-1][j] + image[i][j-1] > 127 * 5:
                    image[i][j] = 255

# %%
modelTrainer = ModelTrainer()

modelTrainer.train_models(models, X_train, False)
# Out:
# Epoch: 1
# batch 1 d_loss : 0.698320
# batch 1 g_loss : 0.690590
# batch 2 d_loss : 0.666958
# batch 2 g_loss : 0.693864
# batch 3 d_loss : 0.618211
# batch 3 g_loss : 0.686351
#
# Epoch: 2
# batch 1 d_loss : 0.576769
# batch 1 g_loss : 0.692502
# batch 2 d_loss : 0.530379
# batch 2 g_loss : 0.692041
# batch 3 d_loss : 0.492321
# batch 3 g_loss : 0.697117
#
# Epoch: 3
# batch 1 d_loss : 0.459148
# batch 1 g_loss : 0.715395
# batch 2 d_loss : 0.425645
# batch 2 g_loss : 0.695003
# batch 3 d_loss : 0.412032
# batch 3 g_loss : 0.711067
#
# Epoch: 4
# batch 1 d_loss : 0.403215
# batch 1 g_loss : 0.694587
# batch 2 d_loss : 0.391371
# batch 2 g_loss : 0.707660
# batch 3 d_loss : 0.400309
# batch 3 g_loss : 0.675526
#
# Epoch: 5
# batch 1 d_loss : 0.413974
# batch 1 g_loss : 0.691071
# batch 2 d_loss : 0.390900
# batch 2 g_loss : 0.681379
# batch 3 d_loss : 0.395451
# batch 3 g_loss : 0.657195
#
# Epoch: 6
# batch 1 d_loss : 0.419178
# batch 1 g_loss : 0.690335
# batch 2 d_loss : 0.426305
# batch 2 g_loss : 0.660186
# batch 3 d_loss : 0.440412
# batch 3 g_loss : 0.663432
#
# Epoch: 7
# batch 1 d_loss : 0.446460
# batch 1 g_loss : 0.677208
# batch 2 d_loss : 0.471565
# batch 2 g_loss : 0.688734
# batch 3 d_loss : 0.461146
# batch 3 g_loss : 0.656703
#
# Epoch: 8
# batch 1 d_loss : 0.485888
# batch 1 g_loss : 0.629986
# batch 2 d_loss : 0.487975
# batch 2 g_loss : 0.614511
# batch 3 d_loss : 0.507698
# batch 3 g_loss : 0.659101
#
# Epoch: 9
# batch 1 d_loss : 0.494865
# batch 1 g_loss : 0.643693
# batch 2 d_loss : 0.499511
# batch 2 g_loss : 0.657629
# batch 3 d_loss : 0.518317
# batch 3 g_loss : 0.673337
#
# Epoch: 10
# batch 1 d_loss : 0.503776
# batch 1 g_loss : 0.669147
# batch 2 d_loss : 0.504499
# batch 2 g_loss : 0.678022
# batch 3 d_loss : 0.519461
# batch 3 g_loss : 0.717610
#
# Epoch: 11
# batch 1 d_loss : 0.494865
# batch 1 g_loss : 0.724583
# batch 2 d_loss : 0.493151
# batch 2 g_loss : 0.732785
# batch 3 d_loss : 0.481711
# batch 3 g_loss : 0.764711
#
# Epoch: 12
# batch 1 d_loss : 0.468351
# batch 1 g_loss : 0.786354
# batch 2 d_loss : 0.467666
# batch 2 g_loss : 0.800177
# batch 3 d_loss : 0.464239
# batch 3 g_loss : 0.828845
#
# Epoch: 13
# batch 1 d_loss : 0.459606
# batch 1 g_loss : 0.857072
# batch 2 d_loss : 0.454511
# batch 2 g_loss : 0.853351
# batch 3 d_loss : 0.452814
# batch 3 g_loss : 0.915228
#
# Epoch: 14
# batch 1 d_loss : 0.442375
# batch 1 g_loss : 0.942025
# batch 2 d_loss : 0.450061
# batch 2 g_loss : 0.972639
# batch 3 d_loss : 0.444840
# batch 3 g_loss : 0.974831
#
# Epoch: 15
# batch 1 d_loss : 0.434769
# batch 1 g_loss : 1.008569
# batch 2 d_loss : 0.445063
# batch 2 g_loss : 1.014609
# batch 3 d_loss : 0.450431
# batch 3 g_loss : 1.067472
#
# Epoch: 16
# batch 1 d_loss : 0.424635
# batch 1 g_loss : 1.073490
# batch 2 d_loss : 0.436740
# batch 2 g_loss : 1.053286
# batch 3 d_loss : 0.431865
# batch 3 g_loss : 1.067916
#
# Epoch: 17
# batch 1 d_loss : 0.411069
# batch 1 g_loss : 1.078257
# batch 2 d_loss : 0.424796
# batch 2 g_loss : 1.120751
# batch 3 d_loss : 0.415549
# batch 3 g_loss : 1.120842
#
# Epoch: 18
# batch 1 d_loss : 0.400159
# batch 1 g_loss : 1.120550
# batch 2 d_loss : 0.414981
# batch 2 g_loss : 1.128372
# batch 3 d_loss : 0.398974
# batch 3 g_loss : 1.158781
#
# Epoch: 19
# batch 1 d_loss : 0.388801
# batch 1 g_loss : 1.185899
# batch 2 d_loss : 0.389034
# batch 2 g_loss : 1.165470
# batch 3 d_loss : 0.383397
# batch 3 g_loss : 1.187252
#
# Epoch: 20
# batch 1 d_loss : 0.363588
# batch 1 g_loss : 1.186875
# batch 2 d_loss : 0.381972
# batch 2 g_loss : 1.199083
# batch 3 d_loss : 0.368270
# batch 3 g_loss : 1.195173
#
# Epoch: 21
# batch 1 d_loss : 0.346595
# batch 1 g_loss : 1.219260
# batch 2 d_loss : 0.362476
# batch 2 g_loss : 1.247260
# batch 3 d_loss : 0.346312
# batch 3 g_loss : 1.296864
#
# Epoch: 22
# batch 1 d_loss : 0.323106
# batch 1 g_loss : 1.325248
# batch 2 d_loss : 0.345609
# batch 2 g_loss : 1.311976
# batch 3 d_loss : 0.333438
# batch 3 g_loss : 1.376238
#
# Epoch: 23
# batch 1 d_loss : 0.310377
# batch 1 g_loss : 1.412852
# batch 2 d_loss : 0.330658
# batch 2 g_loss : 1.371561
# batch 3 d_loss : 0.306486
# batch 3 g_loss : 1.476468
#
# Epoch: 24
# batch 1 d_loss : 0.282062
# batch 1 g_loss : 1.448887
# batch 2 d_loss : 0.309501
# batch 2 g_loss : 1.507425
# batch 3 d_loss : 0.288578
# batch 3 g_loss : 1.498717
#
# Epoch: 25
# batch 1 d_loss : 0.264999
# batch 1 g_loss : 1.546631
# batch 2 d_loss : 0.293791
# batch 2 g_loss : 1.566753
# batch 3 d_loss : 0.274724
# batch 3 g_loss : 1.570898
#
# Epoch: 26
# batch 1 d_loss : 0.244398
# batch 1 g_loss : 1.626438
# batch 2 d_loss : 0.279968
# batch 2 g_loss : 1.599302
# batch 3 d_loss : 0.252730
# batch 3 g_loss : 1.622374
#
# Epoch: 27
# batch 1 d_loss : 0.222475
# batch 1 g_loss : 1.729014
# batch 2 d_loss : 0.259156
# batch 2 g_loss : 1.579236
# batch 3 d_loss : 0.225896
# batch 3 g_loss : 1.658510
#
# Epoch: 28
# batch 1 d_loss : 0.200123
# batch 1 g_loss : 1.606785
# batch 2 d_loss : 0.244157
# batch 2 g_loss : 1.687187
# batch 3 d_loss : 0.202369
# batch 3 g_loss : 1.710054
#
# Epoch: 29
# batch 1 d_loss : 0.180647
# batch 1 g_loss : 1.799073
# batch 2 d_loss : 0.224334
# batch 2 g_loss : 1.651588
# batch 3 d_loss : 0.189201
# batch 3 g_loss : 1.830572
#
# Epoch: 30
# batch 1 d_loss : 0.171091
# batch 1 g_loss : 1.775723
# batch 2 d_loss : 0.205239
# batch 2 g_loss : 1.686818
# batch 3 d_loss : 0.168986
# batch 3 g_loss : 1.881157
#
# Epoch: 31
# batch 1 d_loss : 0.160626
# batch 1 g_loss : 1.961668
# batch 2 d_loss : 0.193125
# batch 2 g_loss : 1.886815
# batch 3 d_loss : 0.159608
# batch 3 g_loss : 1.920663
#
# Epoch: 32
# batch 1 d_loss : 0.140342
# batch 1 g_loss : 1.881282
# batch 2 d_loss : 0.175967
# batch 2 g_loss : 1.762000
# batch 3 d_loss : 0.135568
# batch 3 g_loss : 1.970916
#
# Epoch: 33
# batch 1 d_loss : 0.129955
# batch 1 g_loss : 1.903256
# batch 2 d_loss : 0.164666
# batch 2 g_loss : 1.820159
# batch 3 d_loss : 0.126060
# batch 3 g_loss : 1.750133
#
# Epoch: 34
# batch 1 d_loss : 0.115994
# batch 1 g_loss : 1.643413
# batch 2 d_loss : 0.147231
# batch 2 g_loss : 1.906483
# batch 3 d_loss : 0.110677
# batch 3 g_loss : 1.971266
#
# Epoch: 35
# batch 1 d_loss : 0.109250
# batch 1 g_loss : 2.036559
# batch 2 d_loss : 0.144546
# batch 2 g_loss : 1.878320
# batch 3 d_loss : 0.101552
# batch 3 g_loss : 1.809891
#
# Epoch: 36
# batch 1 d_loss : 0.113940
# batch 1 g_loss : 1.850609
# batch 2 d_loss : 0.137662
# batch 2 g_loss : 1.942544
# batch 3 d_loss : 0.092482
# batch 3 g_loss : 1.790111
#
# Epoch: 37
# batch 1 d_loss : 0.094484
# batch 1 g_loss : 1.438786
# batch 2 d_loss : 0.135197
# batch 2 g_loss : 1.727519
# batch 3 d_loss : 0.099785
# batch 3 g_loss : 1.611357
#
# Epoch: 38
# batch 1 d_loss : 0.093222
# batch 1 g_loss : 1.696887
# batch 2 d_loss : 0.120715
# batch 2 g_loss : 1.625983
# batch 3 d_loss : 0.087609
# batch 3 g_loss : 1.797038
#
# Epoch: 39
# batch 1 d_loss : 0.096265
# batch 1 g_loss : 1.754028
# batch 2 d_loss : 0.127813
# batch 2 g_loss : 1.585850
# batch 3 d_loss : 0.090765
# batch 3 g_loss : 1.476922
#
# Epoch: 40
# batch 1 d_loss : 0.101066
# batch 1 g_loss : 1.707903
# batch 2 d_loss : 0.135970
# batch 2 g_loss : 1.467474
# batch 3 d_loss : 0.085784
# batch 3 g_loss : 1.622605
#
# Epoch: 41
# batch 1 d_loss : 0.088721
# batch 1 g_loss : 1.335177
# batch 2 d_loss : 0.127046
# batch 2 g_loss : 1.464940
# batch 3 d_loss : 0.127885
# batch 3 g_loss : 1.433470
#
# Epoch: 42
# batch 1 d_loss : 0.134344
# batch 1 g_loss : 1.334319
# batch 2 d_loss : 0.131470
# batch 2 g_loss : 1.468029
# batch 3 d_loss : 0.089505
# batch 3 g_loss : 1.520681
#
# Epoch: 43
# batch 1 d_loss : 0.154516
# batch 1 g_loss : 1.823761
# batch 2 d_loss : 0.143576
# batch 2 g_loss : 1.538909
# batch 3 d_loss : 0.129012
# batch 3 g_loss : 1.238460
#
# Epoch: 44
# batch 1 d_loss : 0.139535
# batch 1 g_loss : 1.448436
# batch 2 d_loss : 0.169800
# batch 2 g_loss : 1.666665
# batch 3 d_loss : 0.085144
# batch 3 g_loss : 1.193651
#
# Epoch: 45
# batch 1 d_loss : 0.096847
# batch 1 g_loss : 1.869051
# batch 2 d_loss : 0.230238
# batch 2 g_loss : 1.352901
# batch 3 d_loss : 0.140336
# batch 3 g_loss : 1.715618
#
# Epoch: 46
# batch 1 d_loss : 0.187854
# batch 1 g_loss : 0.829413
# batch 2 d_loss : 0.188819
# batch 2 g_loss : 1.028146
# batch 3 d_loss : 0.127646
# batch 3 g_loss : 1.239860
#
# Epoch: 47
# batch 1 d_loss : 0.178642
# batch 1 g_loss : 1.040272
# batch 2 d_loss : 0.198047
# batch 2 g_loss : 0.969410
# batch 3 d_loss : 0.161731
# batch 3 g_loss : 1.234323
#
# Epoch: 48
# batch 1 d_loss : 0.191244
# batch 1 g_loss : 1.462872
# batch 2 d_loss : 0.275998
# batch 2 g_loss : 1.276553
# batch 3 d_loss : 0.107456
# batch 3 g_loss : 1.372639
#
# Epoch: 49
# batch 1 d_loss : 0.219551
# batch 1 g_loss : 1.132846
# batch 2 d_loss : 0.364248
# batch 2 g_loss : 1.104725
# batch 3 d_loss : 0.191422
# batch 3 g_loss : 1.491933
#
# Epoch: 50
# batch 1 d_loss : 0.301246
# batch 1 g_loss : 1.282089
# batch 2 d_loss : 0.280430
# batch 2 g_loss : 1.067245
# batch 3 d_loss : 0.179315
# batch 3 g_loss : 1.250688
#
# Epoch: 51
# batch 1 d_loss : 0.278445
# batch 1 g_loss : 1.364216
# batch 2 d_loss : 0.332016
# batch 2 g_loss : 1.187241
# batch 3 d_loss : 0.159855
# batch 3 g_loss : 1.151769
#
# Epoch: 52
# batch 1 d_loss : 0.271874
# batch 1 g_loss : 0.803803
# batch 2 d_loss : 0.376958
# batch 2 g_loss : 0.751530
# batch 3 d_loss : 0.226965
# batch 3 g_loss : 1.003902
#
# Epoch: 53
# batch 1 d_loss : 0.341675
# batch 1 g_loss : 1.175690
# batch 2 d_loss : 0.439579
# batch 2 g_loss : 1.436688
# batch 3 d_loss : 0.531231
# batch 3 g_loss : 0.996105
#
# Epoch: 54
# batch 1 d_loss : 0.347825
# batch 1 g_loss : 1.253635
# batch 2 d_loss : 0.425741
# batch 2 g_loss : 0.776099
# batch 3 d_loss : 0.263948
# batch 3 g_loss : 0.949561
#
# Epoch: 55
# batch 1 d_loss : 0.327786
# batch 1 g_loss : 1.097824
# batch 2 d_loss : 0.612590
# batch 2 g_loss : 0.879674
# batch 3 d_loss : 0.322797
# batch 3 g_loss : 1.037448
#
# Epoch: 56
# batch 1 d_loss : 0.329610
# batch 1 g_loss : 1.084094
# batch 2 d_loss : 0.562374
# batch 2 g_loss : 1.119043
# batch 3 d_loss : 0.253475
# batch 3 g_loss : 1.468134
#
# Epoch: 57
# batch 1 d_loss : 0.392798
# batch 1 g_loss : 1.194630
# batch 2 d_loss : 0.532754
# batch 2 g_loss : 1.111464
# batch 3 d_loss : 0.251141
# batch 3 g_loss : 1.371808
#
# Epoch: 58
# batch 1 d_loss : 0.302498
# batch 1 g_loss : 0.921560
# batch 2 d_loss : 0.498444
# batch 2 g_loss : 1.521143
# batch 3 d_loss : 0.348259
# batch 3 g_loss : 0.912631
#
# Epoch: 59
# batch 1 d_loss : 0.498435
# batch 1 g_loss : 1.219423
# batch 2 d_loss : 0.534305
# batch 2 g_loss : 0.818653
# batch 3 d_loss : 0.337562
# batch 3 g_loss : 1.230019
#
# Epoch: 60
# batch 1 d_loss : 0.358344
# batch 1 g_loss : 0.758930
# batch 2 d_loss : 0.535383
# batch 2 g_loss : 1.074852
# batch 3 d_loss : 0.292470
# batch 3 g_loss : 1.086024
#
# Epoch: 61
# batch 1 d_loss : 0.393997
# batch 1 g_loss : 1.336663
# batch 2 d_loss : 0.571680
# batch 2 g_loss : 0.934211
# batch 3 d_loss : 0.520127
# batch 3 g_loss : 1.200655
#
# Epoch: 62
# batch 1 d_loss : 0.484908
# batch 1 g_loss : 1.020276
# batch 2 d_loss : 0.453842
# batch 2 g_loss : 0.786805
# batch 3 d_loss : 0.365650
# batch 3 g_loss : 1.320572
#
# Epoch: 63
# batch 1 d_loss : 0.488136
# batch 1 g_loss : 1.098349
# batch 2 d_loss : 0.550233
# batch 2 g_loss : 1.181217
# batch 3 d_loss : 0.467104
# batch 3 g_loss : 1.182602
#
# Epoch: 64
# batch 1 d_loss : 0.364477
# batch 1 g_loss : 1.383086
# batch 2 d_loss : 0.661305
# batch 2 g_loss : 1.133333
# batch 3 d_loss : 0.314723
# batch 3 g_loss : 1.013803
#
# Epoch: 65
# batch 1 d_loss : 0.428507
# batch 1 g_loss : 1.380715
# batch 2 d_loss : 0.634631
# batch 2 g_loss : 1.355085
# batch 3 d_loss : 0.451422
# batch 3 g_loss : 1.071077
#
# Epoch: 66
# batch 1 d_loss : 0.421305
# batch 1 g_loss : 1.288443
# batch 2 d_loss : 0.468389
# batch 2 g_loss : 0.833841
# batch 3 d_loss : 0.368894
# batch 3 g_loss : 1.125207
#
# Epoch: 67
# batch 1 d_loss : 0.564639
# batch 1 g_loss : 1.250336
# batch 2 d_loss : 0.458776
# batch 2 g_loss : 0.993248
# batch 3 d_loss : 0.429690
# batch 3 g_loss : 1.341415
#
# Epoch: 68
# batch 1 d_loss : 0.371479
# batch 1 g_loss : 1.349998
# batch 2 d_loss : 0.569571
# batch 2 g_loss : 1.220202
# batch 3 d_loss : 0.409357
# batch 3 g_loss : 1.106836
#
# Epoch: 69
# batch 1 d_loss : 0.396307
# batch 1 g_loss : 1.420303
# batch 2 d_loss : 0.479351
# batch 2 g_loss : 1.220919
# batch 3 d_loss : 0.364145
# batch 3 g_loss : 1.231655
#
# Epoch: 70
# batch 1 d_loss : 0.388295
# batch 1 g_loss : 1.507925
# batch 2 d_loss : 0.626685
# batch 2 g_loss : 1.219338
# batch 3 d_loss : 0.451770
# batch 3 g_loss : 2.027321
#
# Epoch: 71
# batch 1 d_loss : 0.371599
# batch 1 g_loss : 1.783875
# batch 2 d_loss : 0.610821
# batch 2 g_loss : 1.072322
# batch 3 d_loss : 0.355613
# batch 3 g_loss : 1.183950
#
# Epoch: 72
# batch 1 d_loss : 0.332121
# batch 1 g_loss : 1.313382
# batch 2 d_loss : 0.439715
# batch 2 g_loss : 1.353808
# batch 3 d_loss : 0.390831
# batch 3 g_loss : 1.091900
#
# Epoch: 73
# batch 1 d_loss : 0.469465
# batch 1 g_loss : 1.313047
# batch 2 d_loss : 0.568255
# batch 2 g_loss : 1.312611
# batch 3 d_loss : 0.302833
# batch 3 g_loss : 1.299221
#
# Epoch: 74
# batch 1 d_loss : 0.368109
# batch 1 g_loss : 1.518431
# batch 2 d_loss : 0.518963
# batch 2 g_loss : 1.278820
# batch 3 d_loss : 0.357329
# batch 3 g_loss : 1.413605
#
# Epoch: 75
# batch 1 d_loss : 0.433250
# batch 1 g_loss : 1.774163
# batch 2 d_loss : 0.424282
# batch 2 g_loss : 1.366903
# batch 3 d_loss : 0.395011
# batch 3 g_loss : 1.662725
#
# Epoch: 76
# batch 1 d_loss : 0.376153
# batch 1 g_loss : 1.398301
# batch 2 d_loss : 0.402504
# batch 2 g_loss : 1.587359
# batch 3 d_loss : 0.315581
# batch 3 g_loss : 1.358930
#
# Epoch: 77
# batch 1 d_loss : 0.426550
# batch 1 g_loss : 1.550842
# batch 2 d_loss : 0.551348
# batch 2 g_loss : 2.010465
# batch 3 d_loss : 0.325882
# batch 3 g_loss : 1.755743
#
# Epoch: 78
# batch 1 d_loss : 0.317420
# batch 1 g_loss : 1.486270
# batch 2 d_loss : 0.388335
# batch 2 g_loss : 1.269177
# batch 3 d_loss : 0.423131
# batch 3 g_loss : 1.389072
#
# Epoch: 79
# batch 1 d_loss : 0.342130
# batch 1 g_loss : 1.637346
# batch 2 d_loss : 0.500855
# batch 2 g_loss : 1.418107
# batch 3 d_loss : 0.348453
# batch 3 g_loss : 1.488329
#
# Epoch: 80
# batch 1 d_loss : 0.413668
# batch 1 g_loss : 1.721031
# batch 2 d_loss : 0.479180
# batch 2 g_loss : 1.511752
# batch 3 d_loss : 0.352999
# batch 3 g_loss : 1.282079
#
# Epoch: 81
# batch 1 d_loss : 0.370056
# batch 1 g_loss : 1.713476
# batch 2 d_loss : 0.440440
# batch 2 g_loss : 1.563571
# batch 3 d_loss : 0.412320
# batch 3 g_loss : 1.604539
#
# Epoch: 82
# batch 1 d_loss : 0.285003
# batch 1 g_loss : 1.295822
# batch 2 d_loss : 0.404484
# batch 2 g_loss : 1.524069
# batch 3 d_loss : 0.363934
# batch 3 g_loss : 1.307362
#
# Epoch: 83
# batch 1 d_loss : 0.357619
# batch 1 g_loss : 1.412151
# batch 2 d_loss : 0.402668
# batch 2 g_loss : 1.188658
# batch 3 d_loss : 0.386213
# batch 3 g_loss : 1.370648
#
# Epoch: 84
# batch 1 d_loss : 0.329941
# batch 1 g_loss : 1.713811
# batch 2 d_loss : 0.465185
# batch 2 g_loss : 1.261435
# batch 3 d_loss : 0.372231
# batch 3 g_loss : 1.338233
#
# Epoch: 85
# batch 1 d_loss : 0.450872
# batch 1 g_loss : 1.552049
# batch 2 d_loss : 0.433256
# batch 2 g_loss : 1.514580
# batch 3 d_loss : 0.294373
# batch 3 g_loss : 1.673061
#
# Epoch: 86
# batch 1 d_loss : 0.409718
# batch 1 g_loss : 1.480124
# batch 2 d_loss : 0.502171
# batch 2 g_loss : 1.595696
# batch 3 d_loss : 0.400390
# batch 3 g_loss : 1.481648
#
# Epoch: 87
# batch 1 d_loss : 0.355128
# batch 1 g_loss : 1.827453
# batch 2 d_loss : 0.574556
# batch 2 g_loss : 1.598234
# batch 3 d_loss : 0.334769
# batch 3 g_loss : 1.182344
#
# Epoch: 88
# batch 1 d_loss : 0.402431
# batch 1 g_loss : 1.594931
# batch 2 d_loss : 0.446418
# batch 2 g_loss : 1.366304
# batch 3 d_loss : 0.337064
# batch 3 g_loss : 1.219950
#
# Epoch: 89
# batch 1 d_loss : 0.323803
# batch 1 g_loss : 1.358433
# batch 2 d_loss : 0.504578
# batch 2 g_loss : 1.181890
# batch 3 d_loss : 0.344863
# batch 3 g_loss : 1.280065
#
# Epoch: 90
# batch 1 d_loss : 0.318981
# batch 1 g_loss : 1.487048
# batch 2 d_loss : 0.370946
# batch 2 g_loss : 1.190560
# batch 3 d_loss : 0.337650
# batch 3 g_loss : 1.292996
#
# Epoch: 91
# batch 1 d_loss : 0.432531
# batch 1 g_loss : 1.175154
# batch 2 d_loss : 0.431233
# batch 2 g_loss : 1.355062
# batch 3 d_loss : 0.330553
# batch 3 g_loss : 1.294298
#
# Epoch: 92
# batch 1 d_loss : 0.309655
# batch 1 g_loss : 1.234048
# batch 2 d_loss : 0.439354
# batch 2 g_loss : 1.538899
# batch 3 d_loss : 0.317197
# batch 3 g_loss : 1.247759
#
# Epoch: 93
# batch 1 d_loss : 0.342415
# batch 1 g_loss : 1.506787
# batch 2 d_loss : 0.468506
# batch 2 g_loss : 1.173527
# batch 3 d_loss : 0.364166
# batch 3 g_loss : 1.613988
#
# Epoch: 94
# batch 1 d_loss : 0.332903
# batch 1 g_loss : 1.379879
# batch 2 d_loss : 0.500222
# batch 2 g_loss : 1.300916
# batch 3 d_loss : 0.331374
# batch 3 g_loss : 1.275952
#
# Epoch: 95
# batch 1 d_loss : 0.394602
# batch 1 g_loss : 1.733974
# batch 2 d_loss : 0.447822
# batch 2 g_loss : 1.327797
# batch 3 d_loss : 0.310241
# batch 3 g_loss : 1.323366
#
# Epoch: 96
# batch 1 d_loss : 0.343832
# batch 1 g_loss : 1.208500
# batch 2 d_loss : 0.378275
# batch 2 g_loss : 1.406488
# batch 3 d_loss : 0.402586
# batch 3 g_loss : 1.258740
#
# Epoch: 97
# batch 1 d_loss : 0.334777
# batch 1 g_loss : 1.349955
# batch 2 d_loss : 0.643644
# batch 2 g_loss : 1.939574
# batch 3 d_loss : 0.417633
# batch 3 g_loss : 1.603186
#
# Epoch: 98
# batch 1 d_loss : 0.399601
# batch 1 g_loss : 1.799289
# batch 2 d_loss : 0.505942
# batch 2 g_loss : 1.105494
# batch 3 d_loss : 0.351884
# batch 3 g_loss : 1.100586
#
# Epoch: 99
# batch 1 d_loss : 0.401406
# batch 1 g_loss : 1.118111
# batch 2 d_loss : 0.541857
# batch 2 g_loss : 1.541419
# batch 3 d_loss : 0.451809
# batch 3 g_loss : 1.515083
#
# Epoch: 100
# batch 1 d_loss : 0.367593
# batch 1 g_loss : 1.343374
# batch 2 d_loss : 0.398831
# batch 2 g_loss : 1.318534
# batch 3 d_loss : 0.378277
# batch 3 g_loss : 1.523880
#
# Epoch: 101
# batch 1 d_loss : 0.355144
# batch 1 g_loss : 1.186979
# batch 2 d_loss : 0.488370
# batch 2 g_loss : 1.720814
# batch 3 d_loss : 0.357058
# batch 3 g_loss : 1.242857
#
# Epoch: 102
# batch 1 d_loss : 0.386844
# batch 1 g_loss : 1.488705
# batch 2 d_loss : 0.499869
# batch 2 g_loss : 1.346705
# batch 3 d_loss : 0.401208
# batch 3 g_loss : 1.243160
#
# Epoch: 103
# batch 1 d_loss : 0.345867
# batch 1 g_loss : 1.154295
# batch 2 d_loss : 0.393371
# batch 2 g_loss : 1.049075
# batch 3 d_loss : 0.525353
# batch 3 g_loss : 1.814197
#
# Epoch: 104
# batch 1 d_loss : 0.362194
# batch 1 g_loss : 1.589800
# batch 2 d_loss : 0.402925
# batch 2 g_loss : 1.220644
# batch 3 d_loss : 0.445722
# batch 3 g_loss : 1.434245
#
# Epoch: 105
# batch 1 d_loss : 0.443304
# batch 1 g_loss : 1.275227
# batch 2 d_loss : 0.501465
# batch 2 g_loss : 1.471564
# batch 3 d_loss : 0.383575
# batch 3 g_loss : 1.477612
#
# Epoch: 106
# batch 1 d_loss : 0.422464
# batch 1 g_loss : 1.387468
# batch 2 d_loss : 0.478067
# batch 2 g_loss : 1.542731
# batch 3 d_loss : 0.433086
# batch 3 g_loss : 1.420094
#
# Epoch: 107
# batch 1 d_loss : 0.346568
# batch 1 g_loss : 1.611391
# batch 2 d_loss : 0.658362
# batch 2 g_loss : 1.577799
# batch 3 d_loss : 0.379165
# batch 3 g_loss : 1.251905
#
# Epoch: 108
# batch 1 d_loss : 0.445116
# batch 1 g_loss : 1.511422
# batch 2 d_loss : 0.452081
# batch 2 g_loss : 1.625499
# batch 3 d_loss : 0.433774
# batch 3 g_loss : 1.451887
#
# Epoch: 109
# batch 1 d_loss : 0.410140
# batch 1 g_loss : 1.562949
# batch 2 d_loss : 0.441068
# batch 2 g_loss : 1.509477
# batch 3 d_loss : 0.391638
# batch 3 g_loss : 1.610872
#
# Epoch: 110
# batch 1 d_loss : 0.348422
# batch 1 g_loss : 1.446737
# batch 2 d_loss : 0.429216
# batch 2 g_loss : 1.012154
# batch 3 d_loss : 0.344359
# batch 3 g_loss : 1.223060
#
# Epoch: 111
# batch 1 d_loss : 0.482219
# batch 1 g_loss : 1.520138
# batch 2 d_loss : 0.405814
# batch 2 g_loss : 1.137248
# batch 3 d_loss : 0.376958
# batch 3 g_loss : 1.057976
#
# Epoch: 112
# batch 1 d_loss : 0.312821
# batch 1 g_loss : 1.182560
# batch 2 d_loss : 0.478244
# batch 2 g_loss : 1.567763
# batch 3 d_loss : 0.331475
# batch 3 g_loss : 1.252315
#
# Epoch: 113
# batch 1 d_loss : 0.494865
# batch 1 g_loss : 1.493096
# batch 2 d_loss : 0.441726
# batch 2 g_loss : 1.289674
# batch 3 d_loss : 0.391347
# batch 3 g_loss : 1.166038
#
# Epoch: 114
# batch 1 d_loss : 0.346523
# batch 1 g_loss : 1.731578
# batch 2 d_loss : 0.459322
# batch 2 g_loss : 1.485468
# batch 3 d_loss : 0.464088
# batch 3 g_loss : 1.381100
#
# Epoch: 115
# batch 1 d_loss : 0.387122
# batch 1 g_loss : 1.992295
# batch 2 d_loss : 0.438879
# batch 2 g_loss : 1.383969
# batch 3 d_loss : 0.433128
# batch 3 g_loss : 1.881154
#
# Epoch: 116
# batch 1 d_loss : 0.367004
# batch 1 g_loss : 1.680198
# batch 2 d_loss : 0.453997
# batch 2 g_loss : 1.614646
# batch 3 d_loss : 0.418624
# batch 3 g_loss : 2.023255
#
# Epoch: 117
# batch 1 d_loss : 0.309356
# batch 1 g_loss : 1.580771
# batch 2 d_loss : 0.427013
# batch 2 g_loss : 1.333136
# batch 3 d_loss : 0.348958
# batch 3 g_loss : 1.375916
#
# Epoch: 118
# batch 1 d_loss : 0.396597
# batch 1 g_loss : 1.776392
# batch 2 d_loss : 0.424107
# batch 2 g_loss : 1.758458
# batch 3 d_loss : 0.447309
# batch 3 g_loss : 1.518586
#
# Epoch: 119
# batch 1 d_loss : 0.332456
# batch 1 g_loss : 1.212473
# batch 2 d_loss : 0.486858
# batch 2 g_loss : 1.484667
# batch 3 d_loss : 0.381795
# batch 3 g_loss : 1.831250
#
# Epoch: 120
# batch 1 d_loss : 0.314088
# batch 1 g_loss : 1.541991
# batch 2 d_loss : 0.327235
# batch 2 g_loss : 1.024964
# batch 3 d_loss : 0.371801
# batch 3 g_loss : 1.219065
#
# Epoch: 121
# batch 1 d_loss : 0.427740
# batch 1 g_loss : 1.780654
# batch 2 d_loss : 0.446163
# batch 2 g_loss : 1.885058
# batch 3 d_loss : 0.376486
# batch 3 g_loss : 1.481261
#
# Epoch: 122
# batch 1 d_loss : 0.341503
# batch 1 g_loss : 1.801178
# batch 2 d_loss : 0.380346
# batch 2 g_loss : 1.453535
# batch 3 d_loss : 0.408782
# batch 3 g_loss : 1.372676
#
# Epoch: 123
# batch 1 d_loss : 0.413376
# batch 1 g_loss : 1.728473
# batch 2 d_loss : 0.451014
# batch 2 g_loss : 1.529167
# batch 3 d_loss : 0.368974
# batch 3 g_loss : 1.446897
#
# Epoch: 124
# batch 1 d_loss : 0.447888
# batch 1 g_loss : 1.706854
# batch 2 d_loss : 0.423605
# batch 2 g_loss : 1.176296
# batch 3 d_loss : 0.406474
# batch 3 g_loss : 1.281531
#
# Epoch: 125
# batch 1 d_loss : 0.368315
# batch 1 g_loss : 1.454810
# batch 2 d_loss : 0.486115
# batch 2 g_loss : 1.386296
# batch 3 d_loss : 0.423628
# batch 3 g_loss : 1.555826
#
# Epoch: 126
# batch 1 d_loss : 0.348034
# batch 1 g_loss : 1.318856
# batch 2 d_loss : 0.529544
# batch 2 g_loss : 1.503049
# batch 3 d_loss : 0.435152
# batch 3 g_loss : 1.720530
#
# Epoch: 127
# batch 1 d_loss : 0.406294
# batch 1 g_loss : 1.874690
# batch 2 d_loss : 0.541087
# batch 2 g_loss : 1.239658
# batch 3 d_loss : 0.373082
# batch 3 g_loss : 1.358934
#
# Epoch: 128
# batch 1 d_loss : 0.390875
# batch 1 g_loss : 1.953502
# batch 2 d_loss : 0.435674
# batch 2 g_loss : 1.589265
# batch 3 d_loss : 0.361171
# batch 3 g_loss : 1.373183
#
# Epoch: 129
# batch 1 d_loss : 0.458263
# batch 1 g_loss : 2.161987
# batch 2 d_loss : 0.427218
# batch 2 g_loss : 1.539406
# batch 3 d_loss : 0.414372
# batch 3 g_loss : 1.434587
#
# Epoch: 130
# batch 1 d_loss : 0.301637
# batch 1 g_loss : 1.502010
# batch 2 d_loss : 0.419855
# batch 2 g_loss : 1.232138
# batch 3 d_loss : 0.455915
# batch 3 g_loss : 1.400202
#
# Epoch: 131
# batch 1 d_loss : 0.327114
# batch 1 g_loss : 1.482598
# batch 2 d_loss : 0.453969
# batch 2 g_loss : 1.617204
# batch 3 d_loss : 0.508380
# batch 3 g_loss : 1.943154
#
# Epoch: 132
# batch 1 d_loss : 0.354018
# batch 1 g_loss : 1.257253
# batch 2 d_loss : 0.433514
# batch 2 g_loss : 1.737419
# batch 3 d_loss : 0.440360
# batch 3 g_loss : 1.246556
#
# Epoch: 133
# batch 1 d_loss : 0.375586
# batch 1 g_loss : 1.668038
# batch 2 d_loss : 0.367508
# batch 2 g_loss : 1.223120
# batch 3 d_loss : 0.489079
# batch 3 g_loss : 1.614661
#
# Epoch: 134
# batch 1 d_loss : 0.335461
# batch 1 g_loss : 1.526046
# batch 2 d_loss : 0.432137
# batch 2 g_loss : 1.597360
# batch 3 d_loss : 0.404783
# batch 3 g_loss : 1.754153
#
# Epoch: 135
# batch 1 d_loss : 0.407219
# batch 1 g_loss : 1.274311
# batch 2 d_loss : 0.405199
# batch 2 g_loss : 1.289087
# batch 3 d_loss : 0.450569
# batch 3 g_loss : 1.507081
#
# Epoch: 136
# batch 1 d_loss : 0.323659
# batch 1 g_loss : 1.238470
# batch 2 d_loss : 0.454587
# batch 2 g_loss : 1.539783
# batch 3 d_loss : 0.358463
# batch 3 g_loss : 1.364462
#
# Epoch: 137
# batch 1 d_loss : 0.371738
# batch 1 g_loss : 1.466997
# batch 2 d_loss : 0.436268
# batch 2 g_loss : 1.748528
# batch 3 d_loss : 0.409483
# batch 3 g_loss : 1.864969
#
# Epoch: 138
# batch 1 d_loss : 0.362732
# batch 1 g_loss : 1.581552
# batch 2 d_loss : 0.440241
# batch 2 g_loss : 1.577275
# batch 3 d_loss : 0.385191
# batch 3 g_loss : 1.261790
#
# Epoch: 139
# batch 1 d_loss : 0.397689
# batch 1 g_loss : 1.993060
# batch 2 d_loss : 0.458296
# batch 2 g_loss : 1.402698
# batch 3 d_loss : 0.499299
# batch 3 g_loss : 1.721346
#
# Epoch: 140
# batch 1 d_loss : 0.344940
# batch 1 g_loss : 1.380710
# batch 2 d_loss : 0.390674
# batch 2 g_loss : 1.406669
# batch 3 d_loss : 0.613806
# batch 3 g_loss : 1.786995
#
# Epoch: 141
# batch 1 d_loss : 0.369668
# batch 1 g_loss : 1.661558
# batch 2 d_loss : 0.431696
# batch 2 g_loss : 1.051213
# batch 3 d_loss : 0.392189
# batch 3 g_loss : 1.122098
#
# Epoch: 142
# batch 1 d_loss : 0.318434
# batch 1 g_loss : 1.340318
# batch 2 d_loss : 0.453809
# batch 2 g_loss : 1.449401
# batch 3 d_loss : 0.480091
# batch 3 g_loss : 1.944928
#
# Epoch: 143
# batch 1 d_loss : 0.364370
# batch 1 g_loss : 1.951959
# batch 2 d_loss : 0.483007
# batch 2 g_loss : 1.798909
# batch 3 d_loss : 0.465970
# batch 3 g_loss : 1.397647
#
# Epoch: 144
# batch 1 d_loss : 0.337756
# batch 1 g_loss : 1.400838
# batch 2 d_loss : 0.436410
# batch 2 g_loss : 1.383646
# batch 3 d_loss : 0.421593
# batch 3 g_loss : 1.388299
#
# Epoch: 145
# batch 1 d_loss : 0.330458
# batch 1 g_loss : 1.326678
# batch 2 d_loss : 0.469700
# batch 2 g_loss : 1.674278
# batch 3 d_loss : 0.429671
# batch 3 g_loss : 1.527041
#
# Epoch: 146
# batch 1 d_loss : 0.314569
# batch 1 g_loss : 1.683105
# batch 2 d_loss : 0.443050
# batch 2 g_loss : 0.984277
# batch 3 d_loss : 0.511703
# batch 3 g_loss : 1.742544
#
# Epoch: 147
# batch 1 d_loss : 0.336452
# batch 1 g_loss : 1.225618
# batch 2 d_loss : 0.452983
# batch 2 g_loss : 1.467396
# batch 3 d_loss : 0.502373
# batch 3 g_loss : 1.508715
#
# Epoch: 148
# batch 1 d_loss : 0.418701
# batch 1 g_loss : 1.868392
# batch 2 d_loss : 0.445654
# batch 2 g_loss : 1.624586
# batch 3 d_loss : 0.428766
# batch 3 g_loss : 1.447939
#
# Epoch: 149
# batch 1 d_loss : 0.342884
# batch 1 g_loss : 1.752414
# batch 2 d_loss : 0.477634
# batch 2 g_loss : 1.593410
# batch 3 d_loss : 0.397671
# batch 3 g_loss : 1.747224
#
# Epoch: 150
# batch 1 d_loss : 0.317331
# batch 1 g_loss : 1.714910
# batch 2 d_loss : 0.374779
# batch 2 g_loss : 1.337041
# batch 3 d_loss : 0.451159
# batch 3 g_loss : 1.546246
#
# Epoch: 151
# batch 1 d_loss : 0.379576
# batch 1 g_loss : 1.832867
# batch 2 d_loss : 0.455636
# batch 2 g_loss : 0.896191
# batch 3 d_loss : 0.409353
# batch 3 g_loss : 1.279328
#
# Epoch: 152
# batch 1 d_loss : 0.355198
# batch 1 g_loss : 1.648393
# batch 2 d_loss : 0.419709
# batch 2 g_loss : 1.475408
# batch 3 d_loss : 0.363895
# batch 3 g_loss : 1.471596
#
# Epoch: 153
# batch 1 d_loss : 0.419628
# batch 1 g_loss : 1.580718
# batch 2 d_loss : 0.492294
# batch 2 g_loss : 1.400119
# batch 3 d_loss : 0.351757
# batch 3 g_loss : 1.413004
#
# Epoch: 154
# batch 1 d_loss : 0.410887
# batch 1 g_loss : 1.687140
# batch 2 d_loss : 0.526860
# batch 2 g_loss : 1.657149
# batch 3 d_loss : 0.444050
# batch 3 g_loss : 1.674264
#
# Epoch: 155
# batch 1 d_loss : 0.396172
# batch 1 g_loss : 1.993215
# batch 2 d_loss : 0.445027
# batch 2 g_loss : 1.177948
# batch 3 d_loss : 0.392220
# batch 3 g_loss : 1.269036
#
# Epoch: 156
# batch 1 d_loss : 0.311125
# batch 1 g_loss : 1.363274
# batch 2 d_loss : 0.500217
# batch 2 g_loss : 1.764199
# batch 3 d_loss : 0.399304
# batch 3 g_loss : 1.893397
#
# Epoch: 157
# batch 1 d_loss : 0.340979
# batch 1 g_loss : 2.060812
# batch 2 d_loss : 0.466848
# batch 2 g_loss : 1.498185
# batch 3 d_loss : 0.294167
# batch 3 g_loss : 1.338809
#
# Epoch: 158
# batch 1 d_loss : 0.338353
# batch 1 g_loss : 1.543203
# batch 2 d_loss : 0.484213
# batch 2 g_loss : 1.543026
# batch 3 d_loss : 0.396687
# batch 3 g_loss : 1.771063
#
# Epoch: 159
# batch 1 d_loss : 0.291092
# batch 1 g_loss : 1.151257
# batch 2 d_loss : 0.413366
# batch 2 g_loss : 1.617028
# batch 3 d_loss : 0.384074
# batch 3 g_loss : 1.375579
#
# Epoch: 160
# batch 1 d_loss : 0.332536
# batch 1 g_loss : 1.773835
# batch 2 d_loss : 0.370811
# batch 2 g_loss : 1.163780
# batch 3 d_loss : 0.388831
# batch 3 g_loss : 1.543965
#
# Epoch: 161
# batch 1 d_loss : 0.335928
# batch 1 g_loss : 1.856489
# batch 2 d_loss : 0.416496
# batch 2 g_loss : 1.293310
# batch 3 d_loss : 0.459510
# batch 3 g_loss : 1.806649
#
# Epoch: 162
# batch 1 d_loss : 0.353258
# batch 1 g_loss : 1.680259
# batch 2 d_loss : 0.454831
# batch 2 g_loss : 1.436964
# batch 3 d_loss : 0.343095
# batch 3 g_loss : 1.262408
#
# Epoch: 163
# batch 1 d_loss : 0.476881
# batch 1 g_loss : 2.019549
# batch 2 d_loss : 0.510598
# batch 2 g_loss : 1.581357
# batch 3 d_loss : 0.377349
# batch 3 g_loss : 1.606688
#
# Epoch: 164
# batch 1 d_loss : 0.391153
# batch 1 g_loss : 1.638697
# batch 2 d_loss : 0.460945
# batch 2 g_loss : 1.539801
# batch 3 d_loss : 0.344513
# batch 3 g_loss : 1.397712
#
# Epoch: 165
# batch 1 d_loss : 0.263148
# batch 1 g_loss : 0.932259
# batch 2 d_loss : 0.531006
# batch 2 g_loss : 1.641657
# batch 3 d_loss : 0.358061
# batch 3 g_loss : 1.491093
#
# Epoch: 166
# batch 1 d_loss : 0.380151
# batch 1 g_loss : 1.700534
# batch 2 d_loss : 0.420976
# batch 2 g_loss : 1.312155
# batch 3 d_loss : 0.387267
# batch 3 g_loss : 1.492369
#
# Epoch: 167
# batch 1 d_loss : 0.413414
# batch 1 g_loss : 2.071713
# batch 2 d_loss : 0.432053
# batch 2 g_loss : 1.136402
# batch 3 d_loss : 0.425590
# batch 3 g_loss : 1.640197
#
# Epoch: 168
# batch 1 d_loss : 0.364875
# batch 1 g_loss : 1.333273
# batch 2 d_loss : 0.434719
# batch 2 g_loss : 1.462242
# batch 3 d_loss : 0.401121
# batch 3 g_loss : 1.380865
#
# Epoch: 169
# batch 1 d_loss : 0.375757
# batch 1 g_loss : 1.936296
# batch 2 d_loss : 0.393017
# batch 2 g_loss : 1.075764
# batch 3 d_loss : 0.457293
# batch 3 g_loss : 1.528129
#
# Epoch: 170
# batch 1 d_loss : 0.471480
# batch 1 g_loss : 2.006212
# batch 2 d_loss : 0.526380
# batch 2 g_loss : 1.675911
# batch 3 d_loss : 0.357637
# batch 3 g_loss : 1.527347
#
# Epoch: 171
# batch 1 d_loss : 0.373896
# batch 1 g_loss : 1.374922
# batch 2 d_loss : 0.441922
# batch 2 g_loss : 1.610754
# batch 3 d_loss : 0.349941
# batch 3 g_loss : 1.731756
#
# Epoch: 172
# batch 1 d_loss : 0.454611
# batch 1 g_loss : 1.978931
# batch 2 d_loss : 0.443189
# batch 2 g_loss : 1.450681
# batch 3 d_loss : 0.454644
# batch 3 g_loss : 1.540212
#
# Epoch: 173
# batch 1 d_loss : 0.364421
# batch 1 g_loss : 1.335955
# batch 2 d_loss : 0.468533
# batch 2 g_loss : 1.547871
# batch 3 d_loss : 0.303290
# batch 3 g_loss : 1.015531
#
# Epoch: 174
# batch 1 d_loss : 0.393596
# batch 1 g_loss : 1.733281
# batch 2 d_loss : 0.406599
# batch 2 g_loss : 1.519097
# batch 3 d_loss : 0.435593
# batch 3 g_loss : 1.954011
#
# Epoch: 175
# batch 1 d_loss : 0.366035
# batch 1 g_loss : 1.600692
# batch 2 d_loss : 0.424987
# batch 2 g_loss : 1.185320
# batch 3 d_loss : 0.333598
# batch 3 g_loss : 1.321200
#
# Epoch: 176
# batch 1 d_loss : 0.339081
# batch 1 g_loss : 1.743909
# batch 2 d_loss : 0.430879
# batch 2 g_loss : 1.882262
# batch 3 d_loss : 0.383459
# batch 3 g_loss : 2.008862
#
# Epoch: 177
# batch 1 d_loss : 0.294511
# batch 1 g_loss : 1.299838
# batch 2 d_loss : 0.538933
# batch 2 g_loss : 1.515016
# batch 3 d_loss : 0.395217
# batch 3 g_loss : 1.706280
#
# Epoch: 178
# batch 1 d_loss : 0.329903
# batch 1 g_loss : 1.662325
# batch 2 d_loss : 0.496122
# batch 2 g_loss : 1.828022
# batch 3 d_loss : 0.420835
# batch 3 g_loss : 1.386385
#
# Epoch: 179
# batch 1 d_loss : 0.321596
# batch 1 g_loss : 1.137244
# batch 2 d_loss : 0.372924
# batch 2 g_loss : 0.988039
# batch 3 d_loss : 0.386633
# batch 3 g_loss : 1.485490
#
# Epoch: 180
# batch 1 d_loss : 0.293681
# batch 1 g_loss : 1.079528
# batch 2 d_loss : 0.434567
# batch 2 g_loss : 1.762559
# batch 3 d_loss : 0.340721
# batch 3 g_loss : 1.483634
#
# Epoch: 181
# batch 1 d_loss : 0.371113
# batch 1 g_loss : 1.477291
# batch 2 d_loss : 0.423948
# batch 2 g_loss : 1.407358
# batch 3 d_loss : 0.374635
# batch 3 g_loss : 1.704208
#
# Epoch: 182
# batch 1 d_loss : 0.516525
# batch 1 g_loss : 1.952940
# batch 2 d_loss : 0.542770
# batch 2 g_loss : 1.123334
# batch 3 d_loss : 0.323531
# batch 3 g_loss : 0.919550
#
# Epoch: 183
# batch 1 d_loss : 0.315715
# batch 1 g_loss : 1.440859
# batch 2 d_loss : 0.428869
# batch 2 g_loss : 1.462441
# batch 3 d_loss : 0.398322
# batch 3 g_loss : 1.290746
#
# Epoch: 184
# batch 1 d_loss : 0.313119
# batch 1 g_loss : 1.137121
# batch 2 d_loss : 0.463025
# batch 2 g_loss : 1.779551
# batch 3 d_loss : 0.424869
# batch 3 g_loss : 1.752614
#
# Epoch: 185
# batch 1 d_loss : 0.397415
# batch 1 g_loss : 1.831831
# batch 2 d_loss : 0.431706
# batch 2 g_loss : 1.117115
# batch 3 d_loss : 0.342991
# batch 3 g_loss : 1.924190
#
# Epoch: 186
# batch 1 d_loss : 0.293725
# batch 1 g_loss : 1.369544
# batch 2 d_loss : 0.429154
# batch 2 g_loss : 1.434433
# batch 3 d_loss : 0.364963
# batch 3 g_loss : 1.289152
#
# Epoch: 187
# batch 1 d_loss : 0.289526
# batch 1 g_loss : 1.351167
# batch 2 d_loss : 0.421931
# batch 2 g_loss : 1.947376
# batch 3 d_loss : 0.361654
# batch 3 g_loss : 1.612092
#
# Epoch: 188
# batch 1 d_loss : 0.505298
# batch 1 g_loss : 2.666477
# batch 2 d_loss : 0.462878
# batch 2 g_loss : 0.900872
# batch 3 d_loss : 0.380820
# batch 3 g_loss : 1.559412
#
# Epoch: 189
# batch 1 d_loss : 0.311903
# batch 1 g_loss : 1.110128
# batch 2 d_loss : 0.411973
# batch 2 g_loss : 1.564254
# batch 3 d_loss : 0.432342
# batch 3 g_loss : 1.947016
#
# Epoch: 190
# batch 1 d_loss : 0.359918
# batch 1 g_loss : 1.324389
# batch 2 d_loss : 0.548406
# batch 2 g_loss : 1.989152
# batch 3 d_loss : 0.431129
# batch 3 g_loss : 1.650309
#
# Epoch: 191
# batch 1 d_loss : 0.334877
# batch 1 g_loss : 1.484687
# batch 2 d_loss : 0.387010
# batch 2 g_loss : 1.351249
# batch 3 d_loss : 0.346665
# batch 3 g_loss : 1.834485
#
# Epoch: 192
# batch 1 d_loss : 0.489179
# batch 1 g_loss : 2.026802
# batch 2 d_loss : 0.480569
# batch 2 g_loss : 1.532001
# batch 3 d_loss : 0.342253
# batch 3 g_loss : 1.617568
#
# Epoch: 193
# batch 1 d_loss : 0.333944
# batch 1 g_loss : 1.769076
# batch 2 d_loss : 0.418351
# batch 2 g_loss : 1.463008
# batch 3 d_loss : 0.376858
# batch 3 g_loss : 1.672946
#
# Epoch: 194
# batch 1 d_loss : 0.382154
# batch 1 g_loss : 1.384206
# batch 2 d_loss : 0.342498
# batch 2 g_loss : 1.217763
# batch 3 d_loss : 0.412437
# batch 3 g_loss : 1.913629
#
# Epoch: 195
# batch 1 d_loss : 0.332976
# batch 1 g_loss : 1.888125
# batch 2 d_loss : 0.369028
# batch 2 g_loss : 1.339699
# batch 3 d_loss : 0.305194
# batch 3 g_loss : 1.570984
#
# Epoch: 196
# batch 1 d_loss : 0.426834
# batch 1 g_loss : 2.317581
# batch 2 d_loss : 0.427629
# batch 2 g_loss : 0.931386
# batch 3 d_loss : 0.369542
# batch 3 g_loss : 2.023204
#
# Epoch: 197
# batch 1 d_loss : 0.313753
# batch 1 g_loss : 1.562056
# batch 2 d_loss : 0.311917
# batch 2 g_loss : 1.092499
# batch 3 d_loss : 0.311923
# batch 3 g_loss : 1.654936
#
# Epoch: 198
# batch 1 d_loss : 0.364367
# batch 1 g_loss : 2.039125
# batch 2 d_loss : 0.381228
# batch 2 g_loss : 1.232374
# batch 3 d_loss : 0.499251
# batch 3 g_loss : 2.690666
#
# Epoch: 199
# batch 1 d_loss : 0.421916
# batch 1 g_loss : 1.723269
# batch 2 d_loss : 0.361628
# batch 2 g_loss : 1.399784
# batch 3 d_loss : 0.362412
# batch 3 g_loss : 1.280125
#
# Epoch: 200
# batch 1 d_loss : 0.276365
# batch 1 g_loss : 1.336357
# batch 2 d_loss : 0.390178
# batch 2 g_loss : 1.586495
# batch 3 d_loss : 0.344642
# batch 3 g_loss : 1.803816
#
# Epoch: 201
# batch 1 d_loss : 0.343666
# batch 1 g_loss : 1.558639
# batch 2 d_loss : 0.342773
# batch 2 g_loss : 1.276795
# batch 3 d_loss : 0.317666
# batch 3 g_loss : 1.548097
#
# Epoch: 202
# batch 1 d_loss : 0.363348
# batch 1 g_loss : 1.905674
# batch 2 d_loss : 0.455573
# batch 2 g_loss : 1.714123
# batch 3 d_loss : 0.331285
# batch 3 g_loss : 1.718641
#
# Epoch: 203
# batch 1 d_loss : 0.273349
# batch 1 g_loss : 1.427203
# batch 2 d_loss : 0.345316
# batch 2 g_loss : 1.101419
# batch 3 d_loss : 0.352777
# batch 3 g_loss : 1.355307
#
# Epoch: 204
# batch 1 d_loss : 0.247160
# batch 1 g_loss : 1.488636
# batch 2 d_loss : 0.425947
# batch 2 g_loss : 1.264353
# batch 3 d_loss : 0.382745
# batch 3 g_loss : 1.619574
#
# Epoch: 205
# batch 1 d_loss : 0.213014
# batch 1 g_loss : 0.955205
# batch 2 d_loss : 0.302572
# batch 2 g_loss : 1.137359
# batch 3 d_loss : 0.396633
# batch 3 g_loss : 2.086149
#
# Epoch: 206
# batch 1 d_loss : 0.294330
# batch 1 g_loss : 1.380976
# batch 2 d_loss : 0.435474
# batch 2 g_loss : 2.295448
# batch 3 d_loss : 0.298613
# batch 3 g_loss : 1.329617
#
# Epoch: 207
# batch 1 d_loss : 0.426598
# batch 1 g_loss : 2.537448
# batch 2 d_loss : 0.452351
# batch 2 g_loss : 1.186270
# batch 3 d_loss : 0.496375
# batch 3 g_loss : 2.141786
#
# Epoch: 208
# batch 1 d_loss : 0.312978
# batch 1 g_loss : 1.563529
# batch 2 d_loss : 0.397888
# batch 2 g_loss : 1.525957
# batch 3 d_loss : 0.369368
# batch 3 g_loss : 1.977528
#
# Epoch: 209
# batch 1 d_loss : 0.232627
# batch 1 g_loss : 1.238384
# batch 2 d_loss : 0.355342
# batch 2 g_loss : 1.379926
# batch 3 d_loss : 0.381767
# batch 3 g_loss : 1.716508
#
# Epoch: 210
# batch 1 d_loss : 0.357138
# batch 1 g_loss : 2.492831
# batch 2 d_loss : 0.421399
# batch 2 g_loss : 1.703188
# batch 3 d_loss : 0.307826
# batch 3 g_loss : 1.644108
#
# Epoch: 211
# batch 1 d_loss : 0.290401
# batch 1 g_loss : 1.940225
# batch 2 d_loss : 0.409294
# batch 2 g_loss : 1.689268
# batch 3 d_loss : 0.456787
# batch 3 g_loss : 2.344358
#
# Epoch: 212
# batch 1 d_loss : 0.316979
# batch 1 g_loss : 1.565623
# batch 2 d_loss : 0.442198
# batch 2 g_loss : 1.567888
# batch 3 d_loss : 0.375112
# batch 3 g_loss : 1.666120
#
# Epoch: 213
# batch 1 d_loss : 0.286547
# batch 1 g_loss : 1.157799
# batch 2 d_loss : 0.426964
# batch 2 g_loss : 2.039660
# batch 3 d_loss : 0.306852
# batch 3 g_loss : 1.605498
#
# Epoch: 214
# batch 1 d_loss : 0.294250
# batch 1 g_loss : 1.638285
# batch 2 d_loss : 0.395395
# batch 2 g_loss : 1.989807
# batch 3 d_loss : 0.309161
# batch 3 g_loss : 1.657957
#
# Epoch: 215
# batch 1 d_loss : 0.291795
# batch 1 g_loss : 1.963361
# batch 2 d_loss : 0.405068
# batch 2 g_loss : 1.926058
# batch 3 d_loss : 0.437333
# batch 3 g_loss : 1.699451
#
# Epoch: 216
# batch 1 d_loss : 0.310781
# batch 1 g_loss : 1.833311
# batch 2 d_loss : 0.390500
# batch 2 g_loss : 1.349653
# batch 3 d_loss : 0.308549
# batch 3 g_loss : 2.043122
#
# Epoch: 217
# batch 1 d_loss : 0.271576
# batch 1 g_loss : 1.772669
# batch 2 d_loss : 0.397651
# batch 2 g_loss : 1.742371
# batch 3 d_loss : 0.311208
# batch 3 g_loss : 1.729068
#
# Epoch: 218
# batch 1 d_loss : 0.276949
# batch 1 g_loss : 1.879835
# batch 2 d_loss : 0.292571
# batch 2 g_loss : 0.869749
# batch 3 d_loss : 0.384260
# batch 3 g_loss : 1.781365
#
# Epoch: 219
# batch 1 d_loss : 0.300080
# batch 1 g_loss : 2.187518
# batch 2 d_loss : 0.331129
# batch 2 g_loss : 0.983033
# batch 3 d_loss : 0.386851
# batch 3 g_loss : 2.009729
#
# Epoch: 220
# batch 1 d_loss : 0.239712
# batch 1 g_loss : 1.406760
# batch 2 d_loss : 0.329850
# batch 2 g_loss : 1.663028
# batch 3 d_loss : 0.296785
# batch 3 g_loss : 1.720902
#
# Epoch: 221
# batch 1 d_loss : 0.203017
# batch 1 g_loss : 1.411281
# batch 2 d_loss : 0.427283
# batch 2 g_loss : 2.120798
# batch 3 d_loss : 0.294153
# batch 3 g_loss : 1.958327
#
# Epoch: 222
# batch 1 d_loss : 0.337443
# batch 1 g_loss : 2.424711
# batch 2 d_loss : 0.412995
# batch 2 g_loss : 1.597640
# batch 3 d_loss : 0.237333
# batch 3 g_loss : 1.626551
#
# Epoch: 223
# batch 1 d_loss : 0.325088
# batch 1 g_loss : 2.329792
# batch 2 d_loss : 0.378130
# batch 2 g_loss : 1.553842
# batch 3 d_loss : 0.221570
# batch 3 g_loss : 1.176530
#
# Epoch: 224
# batch 1 d_loss : 0.269235
# batch 1 g_loss : 2.117973
# batch 2 d_loss : 0.379784
# batch 2 g_loss : 1.897200
# batch 3 d_loss : 0.310798
# batch 3 g_loss : 2.416770
#
# Epoch: 225
# batch 1 d_loss : 0.251898
# batch 1 g_loss : 2.127926
# batch 2 d_loss : 0.399188
# batch 2 g_loss : 1.676985
# batch 3 d_loss : 0.235617
# batch 3 g_loss : 1.381493
#
# Epoch: 226
# batch 1 d_loss : 0.369281
# batch 1 g_loss : 1.945259
# batch 2 d_loss : 0.388407
# batch 2 g_loss : 1.043735
# batch 3 d_loss : 0.306860
# batch 3 g_loss : 1.476156
#
# Epoch: 227
# batch 1 d_loss : 0.229426
# batch 1 g_loss : 1.820341
# batch 2 d_loss : 0.285115
# batch 2 g_loss : 1.208907
# batch 3 d_loss : 0.278223
# batch 3 g_loss : 1.604665
#
# Epoch: 228
# batch 1 d_loss : 0.262395
# batch 1 g_loss : 2.110151
# batch 2 d_loss : 0.478583
# batch 2 g_loss : 2.692131
# batch 3 d_loss : 0.299762
# batch 3 g_loss : 1.740218
#
# Epoch: 229
# batch 1 d_loss : 0.271913
# batch 1 g_loss : 2.516245
# batch 2 d_loss : 0.328544
# batch 2 g_loss : 1.062742
# batch 3 d_loss : 0.316396
# batch 3 g_loss : 1.922779
#
# Epoch: 230
# batch 1 d_loss : 0.317225
# batch 1 g_loss : 2.586462
# batch 2 d_loss : 0.310136
# batch 2 g_loss : 1.049564
# batch 3 d_loss : 0.216673
# batch 3 g_loss : 1.525203
#
# Epoch: 231
# batch 1 d_loss : 0.237002
# batch 1 g_loss : 1.938912
# batch 2 d_loss : 0.371170
# batch 2 g_loss : 2.385786
# batch 3 d_loss : 0.338680
# batch 3 g_loss : 2.182723
#
# Epoch: 232
# batch 1 d_loss : 0.294903
# batch 1 g_loss : 1.773416
# batch 2 d_loss : 0.248807
# batch 2 g_loss : 1.528374
# batch 3 d_loss : 0.338796
# batch 3 g_loss : 2.360494
#
# Epoch: 233
# batch 1 d_loss : 0.335727
# batch 1 g_loss : 2.000267
# batch 2 d_loss : 0.306586
# batch 2 g_loss : 1.435846
# batch 3 d_loss : 0.351266
# batch 3 g_loss : 2.307777
#
# Epoch: 234
# batch 1 d_loss : 0.319382
# batch 1 g_loss : 1.924013
# batch 2 d_loss : 0.318379
# batch 2 g_loss : 1.678324
# batch 3 d_loss : 0.250769
# batch 3 g_loss : 2.071956
#
# Epoch: 235
# batch 1 d_loss : 0.288981
# batch 1 g_loss : 2.512814
# batch 2 d_loss : 0.314359
# batch 2 g_loss : 1.699214
# batch 3 d_loss : 0.245329
# batch 3 g_loss : 1.767056
#
# Epoch: 236
# batch 1 d_loss : 0.319559
# batch 1 g_loss : 2.327374
# batch 2 d_loss : 0.317058
# batch 2 g_loss : 1.911702
# batch 3 d_loss : 0.392095
# batch 3 g_loss : 2.844612
#
# Epoch: 237
# batch 1 d_loss : 0.317129
# batch 1 g_loss : 1.289078
# batch 2 d_loss : 0.352619
# batch 2 g_loss : 2.288718
# batch 3 d_loss : 0.254101
# batch 3 g_loss : 2.123466
#
# Epoch: 238
# batch 1 d_loss : 0.222729
# batch 1 g_loss : 1.776793
# batch 2 d_loss : 0.303691
# batch 2 g_loss : 1.843393
# batch 3 d_loss : 0.349186
# batch 3 g_loss : 3.158464
#
# Epoch: 239
# batch 1 d_loss : 0.294261
# batch 1 g_loss : 1.737575
# batch 2 d_loss : 0.302016
# batch 2 g_loss : 1.459633
# batch 3 d_loss : 0.214896
# batch 3 g_loss : 2.099630
#
# Epoch: 240
# batch 1 d_loss : 0.229403
# batch 1 g_loss : 1.833678
# batch 2 d_loss : 0.235100
# batch 2 g_loss : 1.336824
# batch 3 d_loss : 0.335089
# batch 3 g_loss : 2.733913
#
# Epoch: 241
# batch 1 d_loss : 0.286388
# batch 1 g_loss : 2.039499
# batch 2 d_loss : 0.348210
# batch 2 g_loss : 1.667018
# batch 3 d_loss : 0.289367
# batch 3 g_loss : 2.168895
#
# Epoch: 242
# batch 1 d_loss : 0.258491
# batch 1 g_loss : 2.062075
# batch 2 d_loss : 0.251612
# batch 2 g_loss : 1.630169
# batch 3 d_loss : 0.295974
# batch 3 g_loss : 2.380034
#
# Epoch: 243
# batch 1 d_loss : 0.201672
# batch 1 g_loss : 1.575075
# batch 2 d_loss : 0.235946
# batch 2 g_loss : 1.525089
# batch 3 d_loss : 0.181352
# batch 3 g_loss : 1.349344
#
# Epoch: 244
# batch 1 d_loss : 0.312512
# batch 1 g_loss : 2.517497
# batch 2 d_loss : 0.335115
# batch 2 g_loss : 2.262919
# batch 3 d_loss : 0.199331
# batch 3 g_loss : 2.241871
#
# Epoch: 245
# batch 1 d_loss : 0.194469
# batch 1 g_loss : 1.885237
# batch 2 d_loss : 0.278106
# batch 2 g_loss : 1.619856
# batch 3 d_loss : 0.239931
# batch 3 g_loss : 1.830459
#
# Epoch: 246
# batch 1 d_loss : 0.227244
# batch 1 g_loss : 2.447344
# batch 2 d_loss : 0.258662
# batch 2 g_loss : 1.728100
# batch 3 d_loss : 0.233471
# batch 3 g_loss : 1.747631
#
# Epoch: 247
# batch 1 d_loss : 0.223537
# batch 1 g_loss : 2.374846
# batch 2 d_loss : 0.287277
# batch 2 g_loss : 1.418445
# batch 3 d_loss : 0.302320
# batch 3 g_loss : 2.484096
#
# Epoch: 248
# batch 1 d_loss : 0.231061
# batch 1 g_loss : 1.701074
# batch 2 d_loss : 0.228210
# batch 2 g_loss : 1.533550
# batch 3 d_loss : 0.164732
# batch 3 g_loss : 1.756343
#
# Epoch: 249
# batch 1 d_loss : 0.385257
# batch 1 g_loss : 2.878498
# batch 2 d_loss : 0.407627
# batch 2 g_loss : 1.738209
# batch 3 d_loss : 0.250462
# batch 3 g_loss : 2.757827
#
# Epoch: 250
# batch 1 d_loss : 0.348315
# batch 1 g_loss : 2.495444
# batch 2 d_loss : 0.337432
# batch 2 g_loss : 1.658700
# batch 3 d_loss : 0.264050
# batch 3 g_loss : 1.668651
#
# Epoch: 251
# batch 1 d_loss : 0.205338
# batch 1 g_loss : 2.037641
# batch 2 d_loss : 0.312640
# batch 2 g_loss : 1.866976
# batch 3 d_loss : 0.139804
# batch 3 g_loss : 1.879774
#
# Epoch: 252
# batch 1 d_loss : 0.288898
# batch 1 g_loss : 2.777081
# batch 2 d_loss : 0.352752
# batch 2 g_loss : 1.729109
# batch 3 d_loss : 0.175855
# batch 3 g_loss : 1.892093
#
# Epoch: 253
# batch 1 d_loss : 0.224853
# batch 1 g_loss : 2.068672
# batch 2 d_loss : 0.273886
# batch 2 g_loss : 2.232522
# batch 3 d_loss : 0.145966
# batch 3 g_loss : 1.799034
#
# Epoch: 254
# batch 1 d_loss : 0.222481
# batch 1 g_loss : 2.038719
# batch 2 d_loss : 0.250449
# batch 2 g_loss : 1.583086
# batch 3 d_loss : 0.207880
# batch 3 g_loss : 2.229364
#
# Epoch: 255
# batch 1 d_loss : 0.294504
# batch 1 g_loss : 2.234555
# batch 2 d_loss : 0.260121
# batch 2 g_loss : 1.537903
# batch 3 d_loss : 0.280748
# batch 3 g_loss : 2.303449
#
# Epoch: 256
# batch 1 d_loss : 0.251218
# batch 1 g_loss : 2.185150
# batch 2 d_loss : 0.274073
# batch 2 g_loss : 1.739120
# batch 3 d_loss : 0.188447
# batch 3 g_loss : 2.083704
#
# Epoch: 257
# batch 1 d_loss : 0.219672
# batch 1 g_loss : 2.608446
# batch 2 d_loss : 0.291311
# batch 2 g_loss : 2.044330
# batch 3 d_loss : 0.274781
# batch 3 g_loss : 2.793029
#
# Epoch: 258
# batch 1 d_loss : 0.219931
# batch 1 g_loss : 1.802706
# batch 2 d_loss : 0.225448
# batch 2 g_loss : 1.264069
# batch 3 d_loss : 0.215994
# batch 3 g_loss : 2.540113
#
# Epoch: 259
# batch 1 d_loss : 0.209898
# batch 1 g_loss : 1.625743
# batch 2 d_loss : 0.298942
# batch 2 g_loss : 2.193546
# batch 3 d_loss : 0.166127
# batch 3 g_loss : 2.192635
#
# Epoch: 260
# batch 1 d_loss : 0.284905
# batch 1 g_loss : 2.795588
# batch 2 d_loss : 0.309903
# batch 2 g_loss : 1.989482
# batch 3 d_loss : 0.201580
# batch 3 g_loss : 2.139985
#
# Epoch: 261
# batch 1 d_loss : 0.220461
# batch 1 g_loss : 2.083129
# batch 2 d_loss : 0.211377
# batch 2 g_loss : 1.674255
# batch 3 d_loss : 0.250182
# batch 3 g_loss : 2.356086
#
# Epoch: 262
# batch 1 d_loss : 0.216256
# batch 1 g_loss : 1.803616
# batch 2 d_loss : 0.305459
# batch 2 g_loss : 2.386222
# batch 3 d_loss : 0.241837
# batch 3 g_loss : 2.484626
#
# Epoch: 263
# batch 1 d_loss : 0.222516
# batch 1 g_loss : 1.999754
# batch 2 d_loss : 0.240241
# batch 2 g_loss : 1.857306
# batch 3 d_loss : 0.189627
# batch 3 g_loss : 2.607935
#
# Epoch: 264
# batch 1 d_loss : 0.204412
# batch 1 g_loss : 1.970387
# batch 2 d_loss : 0.219614
# batch 2 g_loss : 1.979424
# batch 3 d_loss : 0.206755
# batch 3 g_loss : 2.522198
#
# Epoch: 265
# batch 1 d_loss : 0.332766
# batch 1 g_loss : 2.632933
# batch 2 d_loss : 0.310645
# batch 2 g_loss : 2.174423
# batch 3 d_loss : 0.144748
# batch 3 g_loss : 1.348349
#
# Epoch: 266
# batch 1 d_loss : 0.339158
# batch 1 g_loss : 3.035374
# batch 2 d_loss : 0.340156
# batch 2 g_loss : 2.236681
# batch 3 d_loss : 0.235997
# batch 3 g_loss : 2.749673
#
# Epoch: 267
# batch 1 d_loss : 0.268216
# batch 1 g_loss : 2.766362
# batch 2 d_loss : 0.232786
# batch 2 g_loss : 2.035474
# batch 3 d_loss : 0.228731
# batch 3 g_loss : 2.504356
#
# Epoch: 268
# batch 1 d_loss : 0.203077
# batch 1 g_loss : 2.178567
# batch 2 d_loss : 0.237392
# batch 2 g_loss : 2.245746
# batch 3 d_loss : 0.114071
# batch 3 g_loss : 2.405609
#
# Epoch: 269
# batch 1 d_loss : 0.206996
# batch 1 g_loss : 2.285970
# batch 2 d_loss : 0.277903
# batch 2 g_loss : 1.803602
# batch 3 d_loss : 0.139693
# batch 3 g_loss : 2.115674
#
# Epoch: 270
# batch 1 d_loss : 0.241330
# batch 1 g_loss : 1.754400
# batch 2 d_loss : 0.295562
# batch 2 g_loss : 1.747931
# batch 3 d_loss : 0.186491
# batch 3 g_loss : 2.727942
#
# Epoch: 271
# batch 1 d_loss : 0.225569
# batch 1 g_loss : 2.028621
# batch 2 d_loss : 0.256137
# batch 2 g_loss : 2.699922
# batch 3 d_loss : 0.137240
# batch 3 g_loss : 2.350068
#
# Epoch: 272
# batch 1 d_loss : 0.217978
# batch 1 g_loss : 2.085241
# batch 2 d_loss : 0.260280
# batch 2 g_loss : 2.737353
# batch 3 d_loss : 0.145155
# batch 3 g_loss : 2.315635
#
# Epoch: 273
# batch 1 d_loss : 0.181967
# batch 1 g_loss : 2.455162
# batch 2 d_loss : 0.227934
# batch 2 g_loss : 2.165638
# batch 3 d_loss : 0.145393
# batch 3 g_loss : 2.172994
#
# Epoch: 274
# batch 1 d_loss : 0.226652
# batch 1 g_loss : 2.626271
# batch 2 d_loss : 0.197378
# batch 2 g_loss : 1.698841
# batch 3 d_loss : 0.171923
# batch 3 g_loss : 1.858288
#
# Epoch: 275
# batch 1 d_loss : 0.175466
# batch 1 g_loss : 2.214842
# batch 2 d_loss : 0.253627
# batch 2 g_loss : 2.996929
# batch 3 d_loss : 0.141624
# batch 3 g_loss : 1.814930
#
# Epoch: 276
# batch 1 d_loss : 0.210560
# batch 1 g_loss : 2.097537
# batch 2 d_loss : 0.242936
# batch 2 g_loss : 2.027953
# batch 3 d_loss : 0.126464
# batch 3 g_loss : 1.982184
#
# Epoch: 277
# batch 1 d_loss : 0.170326
# batch 1 g_loss : 2.287387
# batch 2 d_loss : 0.234745
# batch 2 g_loss : 2.385715
# batch 3 d_loss : 0.164910
# batch 3 g_loss : 2.960807
#
# Epoch: 278
# batch 1 d_loss : 0.195845
# batch 1 g_loss : 2.159642
# batch 2 d_loss : 0.243997
# batch 2 g_loss : 2.350413
# batch 3 d_loss : 0.120432
# batch 3 g_loss : 2.199633
#
# Epoch: 279
# batch 1 d_loss : 0.175997
# batch 1 g_loss : 2.139272
# batch 2 d_loss : 0.286740
# batch 2 g_loss : 2.019896
# batch 3 d_loss : 0.162672
# batch 3 g_loss : 2.692165
#
# Epoch: 280
# batch 1 d_loss : 0.167660
# batch 1 g_loss : 2.166300
# batch 2 d_loss : 0.197830
# batch 2 g_loss : 1.799508
# batch 3 d_loss : 0.184188
# batch 3 g_loss : 3.024362
#
# Epoch: 281
# batch 1 d_loss : 0.185299
# batch 1 g_loss : 2.825026
# batch 2 d_loss : 0.372276
# batch 2 g_loss : 2.182343
# batch 3 d_loss : 0.218766
# batch 3 g_loss : 2.569668
#
# Epoch: 282
# batch 1 d_loss : 0.211692
# batch 1 g_loss : 1.882552
# batch 2 d_loss : 0.168088
# batch 2 g_loss : 1.919420
# batch 3 d_loss : 0.188692
# batch 3 g_loss : 2.040057
#
# Epoch: 283
# batch 1 d_loss : 0.157650
# batch 1 g_loss : 2.968792
# batch 2 d_loss : 0.203172
# batch 2 g_loss : 1.831744
# batch 3 d_loss : 0.113991
# batch 3 g_loss : 2.333111
#
# Epoch: 284
# batch 1 d_loss : 0.184271
# batch 1 g_loss : 2.975827
# batch 2 d_loss : 0.205650
# batch 2 g_loss : 1.793349
# batch 3 d_loss : 0.186510
# batch 3 g_loss : 2.222976
#
# Epoch: 285
# batch 1 d_loss : 0.126638
# batch 1 g_loss : 1.616527
# batch 2 d_loss : 0.161477
# batch 2 g_loss : 1.777986
# batch 3 d_loss : 0.212398
# batch 3 g_loss : 2.865648
#
# Epoch: 286
# batch 1 d_loss : 0.150845
# batch 1 g_loss : 2.097103
# batch 2 d_loss : 0.176376
# batch 2 g_loss : 1.760576
# batch 3 d_loss : 0.209078
# batch 3 g_loss : 2.218383
#
# Epoch: 287
# batch 1 d_loss : 0.146343
# ...
#
# Epoch: 306
# batch 1 d_loss : 0.141877
# batch 1 g_loss : 2.128360
# batch 2 d_loss : 0.176640
# batch 2 g_loss : 2.805791
# batch 3 d_loss : 0.168039
# batch 3 g_loss : 2.779628
#
# Epoch: 307
# batch 1 d_loss : 0.131141
# batch 1 g_loss : 2.536523
# batch 2 d_loss : 0.258453
# batch 2 g_loss : 3.237847
# batch 3 d_loss : 0.233982
# batch 3 g_loss : 4.243128
#
# Epoch: 308
# batch 1 d_loss : 0.228759
# batch 1 g_loss : 3.227204
# batch 2 d_loss : 0.277332
# batch 2 g_loss : 2.884118
# batch 3 d_loss : 0.100992
# batch 3 g_loss : 2.608449
#
# Epoch: 309
# batch 1 d_loss : 0.194369
# batch 1 g_loss : 2.574186
# batch 2 d_loss : 0.209860
# batch 2 g_loss : 2.033458
# batch 3 d_loss : 0.138508
# batch 3 g_loss : 2.929400
#
# Epoch: 310
# batch 1 d_loss : 0.143192
# batch 1 g_loss : 2.728559
# batch 2 d_loss : 0.180737
# batch 2 g_loss : 2.070074
# batch 3 d_loss : 0.130877
# batch 3 g_loss : 3.218254
#
# Epoch: 311
# batch 1 d_loss : 0.126381
# batch 1 g_loss : 2.184291
# batch 2 d_loss : 0.156088
# batch 2 g_loss : 1.421562
# batch 3 d_loss : 0.144059
# batch 3 g_loss : 2.332421
#
# Epoch: 312
# batch 1 d_loss : 0.122025
# batch 1 g_loss : 1.987879
# batch 2 d_loss : 0.236436
# batch 2 g_loss : 2.894525
# batch 3 d_loss : 0.140368
# batch 3 g_loss : 2.714345
#
# Epoch: 313
# batch 1 d_loss : 0.156382
# batch 1 g_loss : 2.360781
# batch 2 d_loss : 0.201288
# batch 2 g_loss : 2.201589
# batch 3 d_loss : 0.178113
# batch 3 g_loss : 2.536782
#
# Epoch: 314
# batch 1 d_loss : 0.156251
# batch 1 g_loss : 2.571152
# batch 2 d_loss : 0.208227
# batch 2 g_loss : 2.887530
# batch 3 d_loss : 0.155494
# batch 3 g_loss : 2.863783
#
# Epoch: 315
# batch 1 d_loss : 0.143020
# batch 1 g_loss : 1.908635
# batch 2 d_loss : 0.146917
# batch 2 g_loss : 2.229992
# batch 3 d_loss : 0.159387
# batch 3 g_loss : 1.982684
#
# Epoch: 316
# batch 1 d_loss : 0.198790
# batch 1 g_loss : 3.476677
# batch 2 d_loss : 0.206299
# batch 2 g_loss : 1.999032
# batch 3 d_loss : 0.271429
# batch 3 g_loss : 4.063967
#
# Epoch: 317
# batch 1 d_loss : 0.196782
# batch 1 g_loss : 2.590927
# batch 2 d_loss : 0.178043
# batch 2 g_loss : 2.219380
# batch 3 d_loss : 0.145954
# batch 3 g_loss : 2.851379
#
# Epoch: 318
# batch 1 d_loss : 0.228550
# batch 1 g_loss : 3.623707
# batch 2 d_loss : 0.268736
# batch 2 g_loss : 2.922016
# batch 3 d_loss : 0.203028
# batch 3 g_loss : 3.667943
#
# Epoch: 319
# batch 1 d_loss : 0.183236
# batch 1 g_loss : 3.236007
# batch 2 d_loss : 0.185176
# batch 2 g_loss : 2.187338
# batch 3 d_loss : 0.128708
# batch 3 g_loss : 2.834900
#
# Epoch: 320
# batch 1 d_loss : 0.123400
# batch 1 g_loss : 2.698362
# batch 2 d_loss : 0.207082
# batch 2 g_loss : 2.349846
# batch 3 d_loss : 0.114347
# batch 3 g_loss : 3.102387
#
# Epoch: 321
# batch 1 d_loss : 0.087665
# batch 1 g_loss : 1.690534
# batch 2 d_loss : 0.215189
# batch 2 g_loss : 2.845290
# batch 3 d_loss : 0.183734
# batch 3 g_loss : 3.432025
#
# Epoch: 322
# batch 1 d_loss : 0.179346
# batch 1 g_loss : 1.885035
# batch 2 d_loss : 0.148734
# batch 2 g_loss : 2.184121
# batch 3 d_loss : 0.110567
# batch 3 g_loss : 2.402432
#
# Epoch: 323
# batch 1 d_loss : 0.131687
# batch 1 g_loss : 3.445268
# batch 2 d_loss : 0.208806
# batch 2 g_loss : 2.645677
# batch 3 d_loss : 0.114341
# batch 3 g_loss : 1.977686
#
# Epoch: 324
# batch 1 d_loss : 0.108896
# batch 1 g_loss : 1.739109
# batch 2 d_loss : 0.166274
# batch 2 g_loss : 2.627310
# batch 3 d_loss : 0.122906
# batch 3 g_loss : 2.711488
#
# Epoch: 325
# batch 1 d_loss : 0.122703
# batch 1 g_loss : 2.442942
# batch 2 d_loss : 0.187321
# batch 2 g_loss : 2.418348
# batch 3 d_loss : 0.150247
# batch 3 g_loss : 3.699060
#
# Epoch: 326
# batch 1 d_loss : 0.148746
# batch 1 g_loss : 2.736104
# batch 2 d_loss : 0.211334
# batch 2 g_loss : 2.529772
# batch 3 d_loss : 0.123059
# batch 3 g_loss : 2.805495
#
# Epoch: 327
# batch 1 d_loss : 0.175730
# batch 1 g_loss : 4.075446
# batch 2 d_loss : 0.299092
# batch 2 g_loss : 2.271906
# batch 3 d_loss : 0.184988
# batch 3 g_loss : 2.862076
#
# Epoch: 328
# batch 1 d_loss : 0.152718
# batch 1 g_loss : 2.261802
# batch 2 d_loss : 0.164521
# batch 2 g_loss : 2.229803
# batch 3 d_loss : 0.155495
# batch 3 g_loss : 2.416078
#
# Epoch: 329
# batch 1 d_loss : 0.125148
# batch 1 g_loss : 2.604706
# batch 2 d_loss : 0.248200
# batch 2 g_loss : 3.446568
# batch 3 d_loss : 0.152168
# batch 3 g_loss : 3.546984
#
# Epoch: 330
# batch 1 d_loss : 0.161606
# batch 1 g_loss : 3.018631
# batch 2 d_loss : 0.149001
# batch 2 g_loss : 2.214596
# batch 3 d_loss : 0.151144
# batch 3 g_loss : 2.558103
#
# Epoch: 331
# batch 1 d_loss : 0.231259
# batch 1 g_loss : 2.781043
# batch 2 d_loss : 0.196449
# batch 2 g_loss : 2.369915
# batch 3 d_loss : 0.290266
# batch 3 g_loss : 2.889657
#
# Epoch: 332
# batch 1 d_loss : 0.162590
# batch 1 g_loss : 2.849317
# batch 2 d_loss : 0.223304
# batch 2 g_loss : 2.661312
# batch 3 d_loss : 0.168448
# batch 3 g_loss : 2.773859
#
# Epoch: 333
# batch 1 d_loss : 0.197559
# batch 1 g_loss : 3.017771
# batch 2 d_loss : 0.220107
# batch 2 g_loss : 2.957335
# batch 3 d_loss : 0.144801
# batch 3 g_loss : 2.997945
#
# Epoch: 334
# batch 1 d_loss : 0.162976
# batch 1 g_loss : 3.304637
# batch 2 d_loss : 0.209481
# batch 2 g_loss : 2.992426
# batch 3 d_loss : 0.092028
# batch 3 g_loss : 2.093205
#
# Epoch: 335
# batch 1 d_loss : 0.094685
# batch 1 g_loss : 2.388982
# batch 2 d_loss : 0.132773
# batch 2 g_loss : 1.805032
# batch 3 d_loss : 0.085862
# batch 3 g_loss : 2.562976
#
# Epoch: 336
# batch 1 d_loss : 0.207055
# batch 1 g_loss : 3.294075
# batch 2 d_loss : 0.192164
# batch 2 g_loss : 2.556379
# batch 3 d_loss : 0.170975
# batch 3 g_loss : 2.894353
#
# Epoch: 337
# batch 1 d_loss : 0.230911
# batch 1 g_loss : 2.896311
# batch 2 d_loss : 0.194592
# batch 2 g_loss : 2.889360
# batch 3 d_loss : 0.160094
# batch 3 g_loss : 3.052365
#
# Epoch: 338
# batch 1 d_loss : 0.116449
# batch 1 g_loss : 2.938175
# batch 2 d_loss : 0.119673
# batch 2 g_loss : 2.316083
# batch 3 d_loss : 0.245851
# batch 3 g_loss : 3.176113
#
# Epoch: 339
# batch 1 d_loss : 0.154126
# batch 1 g_loss : 3.350094
# batch 2 d_loss : 0.186647
# batch 2 g_loss : 2.246449
# batch 3 d_loss : 0.141929
# batch 3 g_loss : 2.960638
#
# Epoch: 340
# batch 1 d_loss : 0.167060
# batch 1 g_loss : 3.557437
# batch 2 d_loss : 0.154865
# batch 2 g_loss : 2.349131
# batch 3 d_loss : 0.143280
# batch 3 g_loss : 2.114569
#
# Epoch: 341
# batch 1 d_loss : 0.139679
# batch 1 g_loss : 3.120006
# batch 2 d_loss : 0.206708
# batch 2 g_loss : 2.321012
# batch 3 d_loss : 0.121210
# batch 3 g_loss : 3.026080
#
# Epoch: 342
# batch 1 d_loss : 0.117694
# batch 1 g_loss : 2.950310
# batch 2 d_loss : 0.092813
# batch 2 g_loss : 1.870499
# batch 3 d_loss : 0.219673
# batch 3 g_loss : 2.346313
#
# Epoch: 343
# batch 1 d_loss : 0.137479
# batch 1 g_loss : 3.152735
# batch 2 d_loss : 0.177228
# batch 2 g_loss : 2.876021
# batch 3 d_loss : 0.250120
# batch 3 g_loss : 3.325449
#
# Epoch: 344
# batch 1 d_loss : 0.166709
# batch 1 g_loss : 2.496333
# batch 2 d_loss : 0.115730
# batch 2 g_loss : 1.911052
# batch 3 d_loss : 0.325196
# batch 3 g_loss : 3.408610
#
# Epoch: 345
# batch 1 d_loss : 0.197151
# batch 1 g_loss : 3.390933
# batch 2 d_loss : 0.202729
# batch 2 g_loss : 2.328582
# batch 3 d_loss : 0.119360
# batch 3 g_loss : 2.598208
#
# Epoch: 346
# batch 1 d_loss : 0.140669
# batch 1 g_loss : 2.636992
# batch 2 d_loss : 0.229004
# batch 2 g_loss : 3.077944
# batch 3 d_loss : 0.192690
# batch 3 g_loss : 3.377566
#
# Epoch: 347
# batch 1 d_loss : 0.191905
# batch 1 g_loss : 2.798266
# batch 2 d_loss : 0.167548
# batch 2 g_loss : 2.390188
# batch 3 d_loss : 0.127387
# batch 3 g_loss : 2.760846
#
# Epoch: 348
# batch 1 d_loss : 0.158932
# batch 1 g_loss : 3.588716
# batch 2 d_loss : 0.186348
# batch 2 g_loss : 2.035718
# batch 3 d_loss : 0.161131
# batch 3 g_loss : 3.034944
#
# Epoch: 349
# batch 1 d_loss : 0.123107
# batch 1 g_loss : 2.647936
# batch 2 d_loss : 0.146449
# batch 2 g_loss : 2.141827
# batch 3 d_loss : 0.167361
# batch 3 g_loss : 3.922840
#
# Epoch: 350
# batch 1 d_loss : 0.106131
# batch 1 g_loss : 2.818577
# batch 2 d_loss : 0.208403
# batch 2 g_loss : 3.103235
# batch 3 d_loss : 0.108013
# batch 3 g_loss : 2.874247
#
# Epoch: 351
# batch 1 d_loss : 0.115739
# batch 1 g_loss : 2.474465
# batch 2 d_loss : 0.186069
# batch 2 g_loss : 2.310692
# batch 3 d_loss : 0.260623
# batch 3 g_loss : 3.987453
#
# Epoch: 352
# batch 1 d_loss : 0.205571
# batch 1 g_loss : 3.266114
# batch 2 d_loss : 0.211228
# batch 2 g_loss : 2.442412
# batch 3 d_loss : 0.110257
# batch 3 g_loss : 3.010500
#
# Epoch: 353
# batch 1 d_loss : 0.152295
# batch 1 g_loss : 3.566422
# batch 2 d_loss : 0.181663
# batch 2 g_loss : 2.614780
# batch 3 d_loss : 0.144128
# batch 3 g_loss : 3.281029
#
# Epoch: 354
# batch 1 d_loss : 0.139465
# batch 1 g_loss : 2.728851
# batch 2 d_loss : 0.174549
# batch 2 g_loss : 2.913534
# batch 3 d_loss : 0.104340
# batch 3 g_loss : 3.039293
#
# Epoch: 355
# batch 1 d_loss : 0.134432
# batch 1 g_loss : 2.872042
# batch 2 d_loss : 0.170003
# batch 2 g_loss : 2.814588
# batch 3 d_loss : 0.190356
# batch 3 g_loss : 4.326088
#
# Epoch: 356
# batch 1 d_loss : 0.180435
# batch 1 g_loss : 2.948145
# batch 2 d_loss : 0.206328
# batch 2 g_loss : 2.177967
# batch 3 d_loss : 0.125032
# batch 3 g_loss : 2.364038
#
# Epoch: 357
# batch 1 d_loss : 0.129193
# batch 1 g_loss : 2.819452
# batch 2 d_loss : 0.181184
# batch 2 g_loss : 2.845335
# batch 3 d_loss : 0.110666
# batch 3 g_loss : 2.498694
#
# Epoch: 358
# batch 1 d_loss : 0.116227
# batch 1 g_loss : 2.732061
# batch 2 d_loss : 0.144643
# batch 2 g_loss : 2.126086
# batch 3 d_loss : 0.144093
# batch 3 g_loss : 2.813477
#
# Epoch: 359
# batch 1 d_loss : 0.215533
# batch 1 g_loss : 3.590139
# batch 2 d_loss : 0.227751
# batch 2 g_loss : 1.370804
# batch 3 d_loss : 0.130699
# batch 3 g_loss : 2.702690
#
# Epoch: 360
# batch 1 d_loss : 0.206414
# batch 1 g_loss : 3.529558
# batch 2 d_loss : 0.219284
# batch 2 g_loss : 2.441786
# batch 3 d_loss : 0.073863
# batch 3 g_loss : 2.634113
#
# Epoch: 361
# batch 1 d_loss : 0.120371
# batch 1 g_loss : 2.545435
# batch 2 d_loss : 0.138487
# batch 2 g_loss : 2.387306
# batch 3 d_loss : 0.122798
# batch 3 g_loss : 3.180142
#
# Epoch: 362
# batch 1 d_loss : 0.122762
# batch 1 g_loss : 3.348283
# batch 2 d_loss : 0.171101
# batch 2 g_loss : 2.495450
# batch 3 d_loss : 0.106534
# batch 3 g_loss : 2.572301
#
# Epoch: 363
# batch 1 d_loss : 0.128036
# batch 1 g_loss : 3.393154
# batch 2 d_loss : 0.154421
# batch 2 g_loss : 2.746757
# batch 3 d_loss : 0.213647
# batch 3 g_loss : 4.001141
#
# Epoch: 364
# batch 1 d_loss : 0.136090
# batch 1 g_loss : 3.111276
# batch 2 d_loss : 0.162092
# batch 2 g_loss : 2.174842
# batch 3 d_loss : 0.079745
# batch 3 g_loss : 2.359069
#
# Epoch: 365
# batch 1 d_loss : 0.097378
# batch 1 g_loss : 2.632550
# batch 2 d_loss : 0.204702
# batch 2 g_loss : 3.152079
# batch 3 d_loss : 0.085062
# batch 3 g_loss : 3.332398
#
# Epoch: 366
# batch 1 d_loss : 0.166330
# batch 1 g_loss : 3.454356
# batch 2 d_loss : 0.207869
# batch 2 g_loss : 2.637816
# batch 3 d_loss : 0.099348
# batch 3 g_loss : 2.532769
#
# Epoch: 367
# batch 1 d_loss : 0.091902
# batch 1 g_loss : 2.218868
# batch 2 d_loss : 0.180895
# batch 2 g_loss : 2.472630
# batch 3 d_loss : 0.140276
# batch 3 g_loss : 3.259106
#
# Epoch: 368
# batch 1 d_loss : 0.151437
# batch 1 g_loss : 2.990424
# batch 2 d_loss : 0.166023
# batch 2 g_loss : 2.864962
# batch 3 d_loss : 0.067972
# batch 3 g_loss : 2.439946
#
# Epoch: 369
# batch 1 d_loss : 0.156672
# batch 1 g_loss : 2.823432
# batch 2 d_loss : 0.185476
# batch 2 g_loss : 2.411572
# batch 3 d_loss : 0.092217
# batch 3 g_loss : 2.811663
#
# Epoch: 370
# batch 1 d_loss : 0.093653
# batch 1 g_loss : 3.206191
# batch 2 d_loss : 0.145143
# batch 2 g_loss : 2.685623
# batch 3 d_loss : 0.067614
# batch 3 g_loss : 2.223582
#
# Epoch: 371
# batch 1 d_loss : 0.176913
# batch 1 g_loss : 3.738462
# batch 2 d_loss : 0.170542
# batch 2 g_loss : 2.819495
# batch 3 d_loss : 0.120453
# batch 3 g_loss : 3.032828
#
# Epoch: 372
# batch 1 d_loss : 0.122536
# batch 1 g_loss : 3.115214
# batch 2 d_loss : 0.132221
# batch 2 g_loss : 2.096511
# batch 3 d_loss : 0.089615
# batch 3 g_loss : 2.019765
#
# Epoch: 373
# batch 1 d_loss : 0.111831
# batch 1 g_loss : 2.699375
# batch 2 d_loss : 0.193253
# batch 2 g_loss : 3.304142
# batch 3 d_loss : 0.096327
# batch 3 g_loss : 3.561549
#
# Epoch: 374
# batch 1 d_loss : 0.173491
# batch 1 g_loss : 3.698432
# batch 2 d_loss : 0.204708
# batch 2 g_loss : 2.343315
# batch 3 d_loss : 0.099023
# batch 3 g_loss : 2.489029
#
# Epoch: 375
# batch 1 d_loss : 0.085835
# batch 1 g_loss : 2.344343
# batch 2 d_loss : 0.150697
# batch 2 g_loss : 2.455817
# batch 3 d_loss : 0.111315
# batch 3 g_loss : 3.298834
#
# Epoch: 376
# batch 1 d_loss : 0.153771
# batch 1 g_loss : 3.188327
# batch 2 d_loss : 0.215038
# batch 2 g_loss : 2.908511
# batch 3 d_loss : 0.222934
# batch 3 g_loss : 4.234924
#
# Epoch: 377
# batch 1 d_loss : 0.181702
# batch 1 g_loss : 2.456724
# batch 2 d_loss : 0.204592
# batch 2 g_loss : 2.816197
# batch 3 d_loss : 0.143041
# batch 3 g_loss : 3.665273
#
# Epoch: 378
# batch 1 d_loss : 0.146511
# batch 1 g_loss : 3.558379
# batch 2 d_loss : 0.212451
# batch 2 g_loss : 2.162177
# batch 3 d_loss : 0.087424
# batch 3 g_loss : 2.925075
#
# Epoch: 379
# batch 1 d_loss : 0.202911
# batch 1 g_loss : 3.323986
# batch 2 d_loss : 0.211896
# batch 2 g_loss : 3.741233
# batch 3 d_loss : 0.080397
# batch 3 g_loss : 3.342606
#
# Epoch: 380
# batch 1 d_loss : 0.102651
# batch 1 g_loss : 2.405098
# batch 2 d_loss : 0.169554
# batch 2 g_loss : 3.357609
# batch 3 d_loss : 0.101259
# batch 3 g_loss : 3.474257
#
# Epoch: 381
# batch 1 d_loss : 0.113961
# batch 1 g_loss : 2.703598
# batch 2 d_loss : 0.130314
# batch 2 g_loss : 2.178683
# batch 3 d_loss : 0.138835
# batch 3 g_loss : 2.810728
#
# Epoch: 382
# batch 1 d_loss : 0.112113
# batch 1 g_loss : 2.965159
# batch 2 d_loss : 0.209011
# batch 2 g_loss : 2.407192
# batch 3 d_loss : 0.064116
# batch 3 g_loss : 2.567901
#
# Epoch: 383
# batch 1 d_loss : 0.101037
# batch 1 g_loss : 2.483185
# batch 2 d_loss : 0.137722
# batch 2 g_loss : 2.427627
# batch 3 d_loss : 0.143207
# batch 3 g_loss : 2.847414
#
# Epoch: 384
# batch 1 d_loss : 0.113563
# batch 1 g_loss : 3.787194
# batch 2 d_loss : 0.190706
# batch 2 g_loss : 2.738991
# batch 3 d_loss : 0.145651
# batch 3 g_loss : 3.406667
#
# Epoch: 385
# batch 1 d_loss : 0.111628
# batch 1 g_loss : 2.585646
# batch 2 d_loss : 0.204041
# batch 2 g_loss : 2.820238
# batch 3 d_loss : 0.073347
# batch 3 g_loss : 2.593178
#
# Epoch: 386
# batch 1 d_loss : 0.154911
# batch 1 g_loss : 2.594876
# batch 2 d_loss : 0.160606
# batch 2 g_loss : 2.750540
# batch 3 d_loss : 0.125754
# batch 3 g_loss : 3.540216
#
# Epoch: 387
# batch 1 d_loss : 0.112546
# batch 1 g_loss : 2.334788
# batch 2 d_loss : 0.125520
# batch 2 g_loss : 1.936428
# batch 3 d_loss : 0.150639
# batch 3 g_loss : 2.718505
#
# Epoch: 388
# batch 1 d_loss : 0.100048
# batch 1 g_loss : 2.721592
# batch 2 d_loss : 0.224599
# batch 2 g_loss : 2.963195
# batch 3 d_loss : 0.077536
# batch 3 g_loss : 3.066781
#
# Epoch: 389
# batch 1 d_loss : 0.113743
# batch 1 g_loss : 2.769120
# batch 2 d_loss : 0.154866
# batch 2 g_loss : 2.806776
# batch 3 d_loss : 0.190692
# batch 3 g_loss : 3.632960
#
# Epoch: 390
# batch 1 d_loss : 0.150687
# batch 1 g_loss : 2.982833
# batch 2 d_loss : 0.163807
# batch 2 g_loss : 2.225757
# batch 3 d_loss : 0.089858
# batch 3 g_loss : 2.570828
#
# Epoch: 391
# batch 1 d_loss : 0.159701
# batch 1 g_loss : 2.822355
# batch 2 d_loss : 0.211053
# batch 2 g_loss : 2.633970
# batch 3 d_loss : 0.106097
# batch 3 g_loss : 3.085096
#
# Epoch: 392
# batch 1 d_loss : 0.141403
# batch 1 g_loss : 3.161921
# batch 2 d_loss : 0.166601
# batch 2 g_loss : 1.511963
# batch 3 d_loss : 0.083675
# batch 3 g_loss : 2.848798
#
# Epoch: 393
# batch 1 d_loss : 0.174592
# batch 1 g_loss : 3.458705
# batch 2 d_loss : 0.160034
# batch 2 g_loss : 2.985144
# batch 3 d_loss : 0.131031
# batch 3 g_loss : 3.004231
#
# Epoch: 394
# batch 1 d_loss : 0.107647
# batch 1 g_loss : 3.046173
# batch 2 d_loss : 0.163055
# batch 2 g_loss : 2.573143
# batch 3 d_loss : 0.145200
# batch 3 g_loss : 3.108005
#
# Epoch: 395
# batch 1 d_loss : 0.164400
# batch 1 g_loss : 2.961859
# batch 2 d_loss : 0.160514
# batch 2 g_loss : 2.288252
# batch 3 d_loss : 0.165540
# batch 3 g_loss : 2.950718
#
# Epoch: 396
# batch 1 d_loss : 0.083605
# batch 1 g_loss : 2.566344
# batch 2 d_loss : 0.144450
# batch 2 g_loss : 2.466664
# batch 3 d_loss : 0.108053
# batch 3 g_loss : 3.438806
#
# Epoch: 397
# batch 1 d_loss : 0.195467
# batch 1 g_loss : 4.552744
# batch 2 d_loss : 0.198653
# batch 2 g_loss : 2.301984
# batch 3 d_loss : 0.071359
# batch 3 g_loss : 2.772134
#
# Epoch: 398
# batch 1 d_loss : 0.206363
# batch 1 g_loss : 3.187725
# batch 2 d_loss : 0.179503
# batch 2 g_loss : 2.177392
# batch 3 d_loss : 0.099602
# batch 3 g_loss : 3.135759
#
# Epoch: 399
# batch 1 d_loss : 0.099066
# batch 1 g_loss : 2.364593
# batch 2 d_loss : 0.196379
# batch 2 g_loss : 3.005977
# batch 3 d_loss : 0.073514
# batch 3 g_loss : 3.188531
#
# Epoch: 400
# batch 1 d_loss : 0.159697
# batch 1 g_loss : 3.170359
# batch 2 d_loss : 0.217632
# batch 2 g_loss : 2.409689
# batch 3 d_loss : 0.136877
# batch 3 g_loss : 3.143941
#
# Training complete

# %% [markdown]
# ## Generating Image

# %%
class ImageGenerator:
    
    def generate_image(self, batch_size):
        modelCreator = ModelCreator()
        
        generator = modelCreator.generator_model()
        generator.compile(loss=ENTROPY, optimizer=SGD_OPT)
        generator.load_weights(G_WGTS_FILE)
        
        imageProcessor = ImageProcessor()
        
        noise = np.zeros((batch_size, 100))
        Util().randomize_noise(noise, batch_size)
  
        generated_images = generator.predict(noise, verbose=1)
        
        print('generated_images.shape: {}'.format(generated_images.shape))
        
        for image in generated_images:
            image = image[0]
            image = image*127.5+127.5
            Image.fromarray(image.astype(np.uint8)).save("dirty.png")
            Image.fromarray(image.astype(np.uint8)).show()
            imageProcessor.clean(image)
            image = Image.fromarray(image.astype(np.uint8))
            image.show()        
            image.save("clean.png")

# %%
imageGenerator = ImageGenerator()

imageGenerator.generate_image(1)
# Out:
# 1/1 [==============================] - 0s
# generated_images.shape: (1, 1, 128, 128)
