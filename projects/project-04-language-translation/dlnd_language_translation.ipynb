# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids.
    
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    source_id_text = [[source_vocab_to_int[word] for word in line.split(' ') if word != ''] \
                      for line in source_text.split('\n')]
    target_id_text = [[target_vocab_to_int[word] for word in line.split(' ') if word != ''] \
                          + [target_vocab_to_int['<EOS>']] \
                      for line in target_text.split('\n')]

    return (source_id_text, target_id_text)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    # TODO: Implement Function
    inputs = tf.placeholder(tf.int32, (None, None), name='input')
    targets = tf.placeholder(tf.int32, (None, None), name='targets')
    
    learning_rate = tf.placeholder(tf.float32, name='learning_rate')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    
    target_seq_len = tf.placeholder(tf.int32, (None,), name='target_sequence_length')
    max_target_seq_len = tf.reduce_max(target_seq_len, name='max_target_len')
    source_seq_len = tf.placeholder(tf.float32, (None,), name='source_sequence_length')
    
    return (inputs, targets, learning_rate, keep_prob, \
            target_seq_len, max_target_seq_len, source_seq_len)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding.
    
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    ending = tf.strided_slice(target_data, [0,0], [batch_size, -1], [1,1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)        
    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer.
    
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function

    # Encodder embedding
    enc_embed = tf.contrib.layers.embed_sequence(rnn_inputs,
                                                 source_vocab_size,
                                                 encoding_embedding_size)

    # Encoder cell
    def make_cell(rnn_size):
        initializer = tf.random_uniform_initializer(-0.1, 0.1, seed=2)
        cell = tf.contrib.rnn.LSTMCell(rnn_size,
                                       initializer=initializer)
        cell = tf.contrib.rnn.DropoutWrapper(cell, keep_prob)
        return cell

    enc_cell = tf.contrib.rnn.MultiRNNCell(
        [make_cell(rnn_size) for _ in range(num_layers)])

    enc_output, enc_state = tf.nn.dynamic_rnn(enc_cell, 
                                              enc_embed, 
                                              sequence_length=source_sequence_length,
                                              dtype=tf.float32)

    return (enc_output, enc_state)
    

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_target_sequence_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training.
    
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    
    helper = tf.contrib.seq2seq.TrainingHelper(dec_embed_input,
                                               target_sequence_length,
                                               time_major=False)

    decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, helper, encoder_state, output_layer)

    return tf.contrib.seq2seq.dynamic_decode(decoder,
                                             impute_finished=True,
                                             maximum_iterations=max_target_sequence_length)[0]
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference.
    
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS ID
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function
    
    start_tokens = tf.tile(tf.constant([start_of_sequence_id], dtype=tf.int32),
                           [batch_size],
                           name='start_tokens')

    helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings,
                                                      start_tokens,
                                                      end_of_sequence_id)

    decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, helper, encoder_state, output_layer)

    return tf.contrib.seq2seq.dynamic_decode(decoder,
                                             impute_finished=True,
                                             maximum_iterations=max_target_sequence_length)[0]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer.
    
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    
    # Decoder embedding
    dec_embedding = tf.Variable(
        tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed = tf.nn.embedding_lookup(dec_embedding, dec_input)

    # Decoder cell
    def make_cell(rnn_size):
        initializer = tf.random_uniform_initializer(-0.1, 0.1, seed=2)
        cell = tf.contrib.rnn.LSTMCell(rnn_size,
                                       initializer=initializer)
        cell = tf.contrib.rnn.DropoutWrapper(cell, keep_prob)
        return cell

    dec_cell = tf.contrib.rnn.MultiRNNCell(
        [make_cell(rnn_size) for _ in range(num_layers)])

    # Dense layer to translate the decoder's output at each time step
    # into a chocie from the target vocabulary
    initializer = tf.truncated_normal_initializer(mean=0.0, stddev=0.1)
    output_layer = Dense(target_vocab_size,
                         kernel_initializer=initializer)

    with tf.variable_scope("decode")as decoding_scope:
        
        # Training decoder
        training_decoder_output = decoding_layer_train(encoder_state, 
                                                       dec_cell, 
                                                       dec_embed, 
                                                       target_sequence_length, 
                                                       max_target_sequence_length, 
                                                       output_layer,
                                                       keep_prob)

        decoding_scope.reuse_variables()
        
        # Inference decoder
        inference_decoder_output = decoding_layer_infer(encoder_state, 
                                                        dec_cell, 
                                                        dec_embedding, 
                                                        target_vocab_to_int['<GO>'],
                                                        target_vocab_to_int['<EOS>'],
                                                        max_target_sequence_length,
                                                        target_vocab_size,
                                                        output_layer,
                                                        batch_size,
                                                        keep_prob)
 
    return (training_decoder_output, inference_decoder_output)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network.
    
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    
    # Encode the input
    _, enc_state = encoding_layer(input_data, 
                                  rnn_size, 
                                  num_layers, 
                                  keep_prob, 
                                  source_sequence_length, 
                                  source_vocab_size, 
                                  enc_embedding_size)
    
    # Process target data
    dec_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)

    # Decode the encoded input
    training_decoder_output, inference_decoder_output = decoding_layer(dec_input, 
                                                                       enc_state,
                                                                       target_sequence_length, 
                                                                       max_target_sentence_length,
                                                                       rnn_size,
                                                                       num_layers, 
                                                                       target_vocab_to_int, 
                                                                       target_vocab_size,
                                                                       batch_size, 
                                                                       keep_prob, 
                                                                       dec_embedding_size)
    
    return (training_decoder_output, inference_decoder_output)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 10
# Batch Size
batch_size = 128
# RNN Size
rnn_size = 256
# Number of Layers
num_layers = 3
# Embedding Size
encoding_embedding_size = 128
decoding_embedding_size = 128
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.75
display_step = 20

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   20/1077 - Train Accuracy: 0.3734, Validation Accuracy: 0.4315, Loss: 2.8836
# Epoch   0 Batch   40/1077 - Train Accuracy: 0.4191, Validation Accuracy: 0.4663, Loss: 2.4601
# Epoch   0 Batch   60/1077 - Train Accuracy: 0.4691, Validation Accuracy: 0.5014, Loss: 2.2271
# Epoch   0 Batch   80/1077 - Train Accuracy: 0.4676, Validation Accuracy: 0.5245, Loss: 2.0013
# Epoch   0 Batch  100/1077 - Train Accuracy: 0.4691, Validation Accuracy: 0.5210, Loss: 1.8304
# Epoch   0 Batch  120/1077 - Train Accuracy: 0.4902, Validation Accuracy: 0.5384, Loss: 1.6836
# Epoch   0 Batch  140/1077 - Train Accuracy: 0.4334, Validation Accuracy: 0.5085, Loss: 1.6857
# Epoch   0 Batch  160/1077 - Train Accuracy: 0.5074, Validation Accuracy: 0.5227, Loss: 1.5744
# Epoch   0 Batch  180/1077 - Train Accuracy: 0.4961, Validation Accuracy: 0.5440, Loss: 1.4789
# Epoch   0 Batch  200/1077 - Train Accuracy: 0.4977, Validation Accuracy: 0.5462, Loss: 1.3744
# Epoch   0 Batch  220/1077 - Train Accuracy: 0.5062, Validation Accuracy: 0.5408, Loss: 1.3429
# Epoch   0 Batch  240/1077 - Train Accuracy: 0.5395, Validation Accuracy: 0.5604, Loss: 1.2163
# Epoch   0 Batch  260/1077 - Train Accuracy: 0.5339, Validation Accuracy: 0.5366, Loss: 1.0943
# Epoch   0 Batch  280/1077 - Train Accuracy: 0.5652, Validation Accuracy: 0.5597, Loss: 1.1475
# Epoch   0 Batch  300/1077 - Train Accuracy: 0.5152, Validation Accuracy: 0.5597, Loss: 1.0920
# Epoch   0 Batch  320/1077 - Train Accuracy: 0.5441, Validation Accuracy: 0.5579, Loss: 1.0109
# Epoch   0 Batch  340/1077 - Train Accuracy: 0.5403, Validation Accuracy: 0.5756, Loss: 0.9898
# Epoch   0 Batch  360/1077 - Train Accuracy: 0.5516, Validation Accuracy: 0.5618, Loss: 0.9572
# Epoch   0 Batch  380/1077 - Train Accuracy: 0.5699, Validation Accuracy: 0.5934, Loss: 0.9078
# Epoch   0 Batch  400/1077 - Train Accuracy: 0.5762, Validation Accuracy: 0.5763, Loss: 0.9292
# Epoch   0 Batch  420/1077 - Train Accuracy: 0.5758, Validation Accuracy: 0.5827, Loss: 0.8564
# Epoch   0 Batch  440/1077 - Train Accuracy: 0.5492, Validation Accuracy: 0.6108, Loss: 0.9025
# Epoch   0 Batch  460/1077 - Train Accuracy: 0.5633, Validation Accuracy: 0.6009, Loss: 0.8311
# Epoch   0 Batch  480/1077 - Train Accuracy: 0.5839, Validation Accuracy: 0.6005, Loss: 0.8258
# Epoch   0 Batch  500/1077 - Train Accuracy: 0.5738, Validation Accuracy: 0.6033, Loss: 0.7914
# Epoch   0 Batch  520/1077 - Train Accuracy: 0.6094, Validation Accuracy: 0.6072, Loss: 0.7407
# Epoch   0 Batch  540/1077 - Train Accuracy: 0.5746, Validation Accuracy: 0.6037, Loss: 0.7369
# Epoch   0 Batch  560/1077 - Train Accuracy: 0.5750, Validation Accuracy: 0.6069, Loss: 0.7301
# Epoch   0 Batch  580/1077 - Train Accuracy: 0.6243, Validation Accuracy: 0.6179, Loss: 0.6606
# Epoch   0 Batch  600/1077 - Train Accuracy: 0.6220, Validation Accuracy: 0.6154, Loss: 0.6825
# Epoch   0 Batch  620/1077 - Train Accuracy: 0.5910, Validation Accuracy: 0.6097, Loss: 0.6813
# Epoch   0 Batch  640/1077 - Train Accuracy: 0.5923, Validation Accuracy: 0.6296, Loss: 0.6606
# Epoch   0 Batch  660/1077 - Train Accuracy: 0.5965, Validation Accuracy: 0.6293, Loss: 0.6716
# Epoch   0 Batch  680/1077 - Train Accuracy: 0.6202, Validation Accuracy: 0.6207, Loss: 0.6437
# Epoch   0 Batch  700/1077 - Train Accuracy: 0.5863, Validation Accuracy: 0.6211, Loss: 0.6394
# Epoch   0 Batch  720/1077 - Train Accuracy: 0.6065, Validation Accuracy: 0.6030, Loss: 0.6995
# Epoch   0 Batch  740/1077 - Train Accuracy: 0.6340, Validation Accuracy: 0.6303, Loss: 0.6215
# Epoch   0 Batch  760/1077 - Train Accuracy: 0.6180, Validation Accuracy: 0.6183, Loss: 0.6207
# Epoch   0 Batch  780/1077 - Train Accuracy: 0.6137, Validation Accuracy: 0.6374, Loss: 0.6240
# Epoch   0 Batch  800/1077 - Train Accuracy: 0.6113, Validation Accuracy: 0.6328, Loss: 0.5931
# Epoch   0 Batch  820/1077 - Train Accuracy: 0.6207, Validation Accuracy: 0.6353, Loss: 0.6057
# Epoch   0 Batch  840/1077 - Train Accuracy: 0.6348, Validation Accuracy: 0.6534, Loss: 0.5668
# Epoch   0 Batch  860/1077 - Train Accuracy: 0.6068, Validation Accuracy: 0.6449, Loss: 0.5692
# Epoch   0 Batch  880/1077 - Train Accuracy: 0.6707, Validation Accuracy: 0.6602, Loss: 0.5538
# Epoch   0 Batch  900/1077 - Train Accuracy: 0.6559, Validation Accuracy: 0.6499, Loss: 0.5665
# Epoch   0 Batch  920/1077 - Train Accuracy: 0.6406, Validation Accuracy: 0.6531, Loss: 0.5590
# Epoch   0 Batch  940/1077 - Train Accuracy: 0.6352, Validation Accuracy: 0.6605, Loss: 0.5239
# Epoch   0 Batch  960/1077 - Train Accuracy: 0.6644, Validation Accuracy: 0.6467, Loss: 0.5108
# Epoch   0 Batch  980/1077 - Train Accuracy: 0.6680, Validation Accuracy: 0.6612, Loss: 0.5254
# Epoch   0 Batch 1000/1077 - Train Accuracy: 0.7113, Validation Accuracy: 0.6538, Loss: 0.4702
# Epoch   0 Batch 1020/1077 - Train Accuracy: 0.6645, Validation Accuracy: 0.6523, Loss: 0.4849
# Epoch   0 Batch 1040/1077 - Train Accuracy: 0.6637, Validation Accuracy: 0.6630, Loss: 0.5265
# Epoch   0 Batch 1060/1077 - Train Accuracy: 0.6602, Validation Accuracy: 0.6641, Loss: 0.4746
# Epoch   1 Batch   20/1077 - Train Accuracy: 0.6609, Validation Accuracy: 0.6768, Loss: 0.4576
# Epoch   1 Batch   40/1077 - Train Accuracy: 0.6656, Validation Accuracy: 0.6779, Loss: 0.4653
# Epoch   1 Batch   60/1077 - Train Accuracy: 0.6734, Validation Accuracy: 0.6847, Loss: 0.4397
# Epoch   1 Batch   80/1077 - Train Accuracy: 0.6969, Validation Accuracy: 0.6786, Loss: 0.4466
# Epoch   1 Batch  100/1077 - Train Accuracy: 0.6875, Validation Accuracy: 0.6903, Loss: 0.4337
# Epoch   1 Batch  120/1077 - Train Accuracy: 0.7152, Validation Accuracy: 0.6964, Loss: 0.4395
# Epoch   1 Batch  140/1077 - Train Accuracy: 0.6945, Validation Accuracy: 0.6974, Loss: 0.4255
# Epoch   1 Batch  160/1077 - Train Accuracy: 0.7250, Validation Accuracy: 0.7156, Loss: 0.4109
# Epoch   1 Batch  180/1077 - Train Accuracy: 0.6832, Validation Accuracy: 0.6974, Loss: 0.4046
# Epoch   1 Batch  200/1077 - Train Accuracy: 0.6801, Validation Accuracy: 0.6942, Loss: 0.4112
# Epoch   1 Batch  220/1077 - Train Accuracy: 0.7159, Validation Accuracy: 0.7148, Loss: 0.3992
# Epoch   1 Batch  240/1077 - Train Accuracy: 0.7465, Validation Accuracy: 0.7070, Loss: 0.3601
# Epoch   1 Batch  260/1077 - Train Accuracy: 0.7489, Validation Accuracy: 0.7088, Loss: 0.3339
# Epoch   1 Batch  280/1077 - Train Accuracy: 0.7332, Validation Accuracy: 0.7159, Loss: 0.3671
# Epoch   1 Batch  300/1077 - Train Accuracy: 0.7130, Validation Accuracy: 0.7148, Loss: 0.3534
# Epoch   1 Batch  320/1077 - Train Accuracy: 0.7457, Validation Accuracy: 0.6999, Loss: 0.3421
# Epoch   1 Batch  340/1077 - Train Accuracy: 0.7368, Validation Accuracy: 0.7180, Loss: 0.3307
# Epoch   1 Batch  360/1077 - Train Accuracy: 0.7477, Validation Accuracy: 0.7433, Loss: 0.3131
# Epoch   1 Batch  380/1077 - Train Accuracy: 0.7398, Validation Accuracy: 0.7035, Loss: 0.3253
# Epoch   1 Batch  400/1077 - Train Accuracy: 0.7758, Validation Accuracy: 0.7290, Loss: 0.3254
# Epoch   1 Batch  420/1077 - Train Accuracy: 0.7574, Validation Accuracy: 0.7507, Loss: 0.2857
# Epoch   1 Batch  440/1077 - Train Accuracy: 0.7266, Validation Accuracy: 0.7415, Loss: 0.3132
# Epoch   1 Batch  460/1077 - Train Accuracy: 0.7719, Validation Accuracy: 0.7326, Loss: 0.2860
# Epoch   1 Batch  480/1077 - Train Accuracy: 0.8109, Validation Accuracy: 0.7514, Loss: 0.2784
# Epoch   1 Batch  500/1077 - Train Accuracy: 0.7875, Validation Accuracy: 0.7337, Loss: 0.2577
# Epoch   1 Batch  520/1077 - Train Accuracy: 0.8281, Validation Accuracy: 0.7468, Loss: 0.2438
# Epoch   1 Batch  540/1077 - Train Accuracy: 0.7969, Validation Accuracy: 0.7667, Loss: 0.2326
# Epoch   1 Batch  560/1077 - Train Accuracy: 0.7535, Validation Accuracy: 0.7656, Loss: 0.2424
# Epoch   1 Batch  580/1077 - Train Accuracy: 0.8170, Validation Accuracy: 0.7699, Loss: 0.2192
# Epoch   1 Batch  600/1077 - Train Accuracy: 0.8158, Validation Accuracy: 0.7749, Loss: 0.2208
# Epoch   1 Batch  620/1077 - Train Accuracy: 0.8020, Validation Accuracy: 0.7749, Loss: 0.2284
# Epoch   1 Batch  640/1077 - Train Accuracy: 0.7783, Validation Accuracy: 0.7766, Loss: 0.2209
# Epoch   1 Batch  660/1077 - Train Accuracy: 0.7816, Validation Accuracy: 0.7607, Loss: 0.2320
# Epoch   1 Batch  680/1077 - Train Accuracy: 0.8039, Validation Accuracy: 0.7567, Loss: 0.2090
# Epoch   1 Batch  700/1077 - Train Accuracy: 0.8094, Validation Accuracy: 0.7898, Loss: 0.1939
# Epoch   1 Batch  720/1077 - Train Accuracy: 0.8331, Validation Accuracy: 0.7940, Loss: 0.2195
# Epoch   1 Batch  740/1077 - Train Accuracy: 0.8262, Validation Accuracy: 0.7802, Loss: 0.1839
# Epoch   1 Batch  760/1077 - Train Accuracy: 0.8629, Validation Accuracy: 0.8178, Loss: 0.1981
# Epoch   1 Batch  780/1077 - Train Accuracy: 0.8227, Validation Accuracy: 0.8207, Loss: 0.1982
# Epoch   1 Batch  800/1077 - Train Accuracy: 0.8434, Validation Accuracy: 0.8196, Loss: 0.1761
# Epoch   1 Batch  820/1077 - Train Accuracy: 0.8160, Validation Accuracy: 0.8285, Loss: 0.1983
# Epoch   1 Batch  840/1077 - Train Accuracy: 0.8187, Validation Accuracy: 0.8331, Loss: 0.1662
# Epoch   1 Batch  860/1077 - Train Accuracy: 0.8363, Validation Accuracy: 0.8434, Loss: 0.1842
# Epoch   1 Batch  880/1077 - Train Accuracy: 0.8793, Validation Accuracy: 0.8377, Loss: 0.1710
# Epoch   1 Batch  900/1077 - Train Accuracy: 0.8625, Validation Accuracy: 0.8345, Loss: 0.1727
# Epoch   1 Batch  920/1077 - Train Accuracy: 0.8383, Validation Accuracy: 0.8512, Loss: 0.1558
# Epoch   1 Batch  940/1077 - Train Accuracy: 0.8383, Validation Accuracy: 0.8260, Loss: 0.1557
# Epoch   1 Batch  960/1077 - Train Accuracy: 0.8583, Validation Accuracy: 0.8430, Loss: 0.1515
# Epoch   1 Batch  980/1077 - Train Accuracy: 0.8699, Validation Accuracy: 0.8469, Loss: 0.1536
# Epoch   1 Batch 1000/1077 - Train Accuracy: 0.9029, Validation Accuracy: 0.8555, Loss: 0.1298
# Epoch   1 Batch 1020/1077 - Train Accuracy: 0.9039, Validation Accuracy: 0.8839, Loss: 0.1263
# Epoch   1 Batch 1040/1077 - Train Accuracy: 0.9067, Validation Accuracy: 0.8629, Loss: 0.1466
# Epoch   1 Batch 1060/1077 - Train Accuracy: 0.8621, Validation Accuracy: 0.8675, Loss: 0.1167
# Epoch   2 Batch   20/1077 - Train Accuracy: 0.8887, Validation Accuracy: 0.8778, Loss: 0.1141
# Epoch   2 Batch   40/1077 - Train Accuracy: 0.9230, Validation Accuracy: 0.8814, Loss: 0.1160
# Epoch   2 Batch   60/1077 - Train Accuracy: 0.9029, Validation Accuracy: 0.8718, Loss: 0.1100
# Epoch   2 Batch   80/1077 - Train Accuracy: 0.9223, Validation Accuracy: 0.9006, Loss: 0.1138
# Epoch   2 Batch  100/1077 - Train Accuracy: 0.9102, Validation Accuracy: 0.8938, Loss: 0.1034
# Epoch   2 Batch  120/1077 - Train Accuracy: 0.9211, Validation Accuracy: 0.8988, Loss: 0.1140
# Epoch   2 Batch  140/1077 - Train Accuracy: 0.9128, Validation Accuracy: 0.8668, Loss: 0.1063
# Epoch   2 Batch  160/1077 - Train Accuracy: 0.9176, Validation Accuracy: 0.8828, Loss: 0.0925
# Epoch   2 Batch  180/1077 - Train Accuracy: 0.9059, Validation Accuracy: 0.8910, Loss: 0.0914
# Epoch   2 Batch  200/1077 - Train Accuracy: 0.8777, Validation Accuracy: 0.8967, Loss: 0.1067
# Epoch   2 Batch  220/1077 - Train Accuracy: 0.9013, Validation Accuracy: 0.8977, Loss: 0.0889
# Epoch   2 Batch  240/1077 - Train Accuracy: 0.9176, Validation Accuracy: 0.8952, Loss: 0.0915
# Epoch   2 Batch  260/1077 - Train Accuracy: 0.9271, Validation Accuracy: 0.9016, Loss: 0.0713
# Epoch   2 Batch  280/1077 - Train Accuracy: 0.8992, Validation Accuracy: 0.9002, Loss: 0.0913
# Epoch   2 Batch  300/1077 - Train Accuracy: 0.9470, Validation Accuracy: 0.8988, Loss: 0.0815
# Epoch   2 Batch  320/1077 - Train Accuracy: 0.9215, Validation Accuracy: 0.8800, Loss: 0.0876
# Epoch   2 Batch  340/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.8778, Loss: 0.0768
# Epoch   2 Batch  360/1077 - Train Accuracy: 0.9152, Validation Accuracy: 0.8839, Loss: 0.0706
# Epoch   2 Batch  380/1077 - Train Accuracy: 0.9199, Validation Accuracy: 0.8867, Loss: 0.0723
# Epoch   2 Batch  400/1077 - Train Accuracy: 0.9129, Validation Accuracy: 0.8810, Loss: 0.0881
# Epoch   2 Batch  420/1077 - Train Accuracy: 0.9547, Validation Accuracy: 0.9041, Loss: 0.0640
# Epoch   2 Batch  440/1077 - Train Accuracy: 0.8859, Validation Accuracy: 0.8888, Loss: 0.0901
# Epoch   2 Batch  460/1077 - Train Accuracy: 0.9168, Validation Accuracy: 0.8892, Loss: 0.0742
# Epoch   2 Batch  480/1077 - Train Accuracy: 0.9305, Validation Accuracy: 0.8984, Loss: 0.0768
# Epoch   2 Batch  500/1077 - Train Accuracy: 0.9391, Validation Accuracy: 0.9013, Loss: 0.0554
# Epoch   2 Batch  520/1077 - Train Accuracy: 0.9587, Validation Accuracy: 0.8999, Loss: 0.0622
# Epoch   2 Batch  540/1077 - Train Accuracy: 0.9379, Validation Accuracy: 0.9009, Loss: 0.0588
# Epoch   2 Batch  560/1077 - Train Accuracy: 0.9406, Validation Accuracy: 0.8974, Loss: 0.0632
# Epoch   2 Batch  580/1077 - Train Accuracy: 0.9524, Validation Accuracy: 0.9134, Loss: 0.0593
# Epoch   2 Batch  600/1077 - Train Accuracy: 0.9237, Validation Accuracy: 0.8924, Loss: 0.0692
# Epoch   2 Batch  620/1077 - Train Accuracy: 0.9512, Validation Accuracy: 0.9091, Loss: 0.0599
# Epoch   2 Batch  640/1077 - Train Accuracy: 0.9178, Validation Accuracy: 0.8821, Loss: 0.0644
# Epoch   2 Batch  660/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.9148, Loss: 0.0607
# Epoch   2 Batch  680/1077 - Train Accuracy: 0.9070, Validation Accuracy: 0.8892, Loss: 0.0632
# Epoch   2 Batch  700/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9137, Loss: 0.0487
# Epoch   2 Batch  720/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.9336, Loss: 0.0617
# Epoch   2 Batch  740/1077 - Train Accuracy: 0.9250, Validation Accuracy: 0.9283, Loss: 0.0531
# Epoch   2 Batch  760/1077 - Train Accuracy: 0.9410, Validation Accuracy: 0.9272, Loss: 0.0652
# Epoch   2 Batch  780/1077 - Train Accuracy: 0.9125, Validation Accuracy: 0.9244, Loss: 0.0696
# Epoch   2 Batch  800/1077 - Train Accuracy: 0.9398, Validation Accuracy: 0.9293, Loss: 0.0553
# Epoch   2 Batch  820/1077 - Train Accuracy: 0.9152, Validation Accuracy: 0.9070, Loss: 0.0575
# Epoch   2 Batch  840/1077 - Train Accuracy: 0.9574, Validation Accuracy: 0.9244, Loss: 0.0553
# Epoch   2 Batch  860/1077 - Train Accuracy: 0.9475, Validation Accuracy: 0.9382, Loss: 0.0644
# Epoch   2 Batch  880/1077 - Train Accuracy: 0.9332, Validation Accuracy: 0.9126, Loss: 0.0724
# Epoch   2 Batch  900/1077 - Train Accuracy: 0.9441, Validation Accuracy: 0.9226, Loss: 0.0605
# Epoch   2 Batch  920/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.9169, Loss: 0.0491
# Epoch   2 Batch  940/1077 - Train Accuracy: 0.9488, Validation Accuracy: 0.9201, Loss: 0.0458
# Epoch   2 Batch  960/1077 - Train Accuracy: 0.9334, Validation Accuracy: 0.9332, Loss: 0.0531
# Epoch   2 Batch  980/1077 - Train Accuracy: 0.9137, Validation Accuracy: 0.9244, Loss: 0.0595
# Epoch   2 Batch 1000/1077 - Train Accuracy: 0.9342, Validation Accuracy: 0.9251, Loss: 0.0501
# Epoch   2 Batch 1020/1077 - Train Accuracy: 0.9645, Validation Accuracy: 0.9283, Loss: 0.0437
# Epoch   2 Batch 1040/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.9226, Loss: 0.0491
# Epoch   2 Batch 1060/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9247, Loss: 0.0421
# Epoch   3 Batch   20/1077 - Train Accuracy: 0.9180, Validation Accuracy: 0.9435, Loss: 0.0446
# Epoch   3 Batch   40/1077 - Train Accuracy: 0.9738, Validation Accuracy: 0.9439, Loss: 0.0347
# Epoch   3 Batch   60/1077 - Train Accuracy: 0.9394, Validation Accuracy: 0.9261, Loss: 0.0412
# Epoch   3 Batch   80/1077 - Train Accuracy: 0.9340, Validation Accuracy: 0.9368, Loss: 0.0477
# Epoch   3 Batch  100/1077 - Train Accuracy: 0.9508, Validation Accuracy: 0.9240, Loss: 0.0453
# Epoch   3 Batch  120/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9258, Loss: 0.0505
# Epoch   3 Batch  140/1077 - Train Accuracy: 0.9416, Validation Accuracy: 0.9158, Loss: 0.0467
# Epoch   3 Batch  160/1077 - Train Accuracy: 0.9500, Validation Accuracy: 0.9432, Loss: 0.0395
# Epoch   3 Batch  180/1077 - Train Accuracy: 0.9445, Validation Accuracy: 0.9208, Loss: 0.0409
# Epoch   3 Batch  200/1077 - Train Accuracy: 0.9543, Validation Accuracy: 0.9347, Loss: 0.0457
# Epoch   3 Batch  220/1077 - Train Accuracy: 0.9457, Validation Accuracy: 0.9357, Loss: 0.0458
# Epoch   3 Batch  240/1077 - Train Accuracy: 0.9633, Validation Accuracy: 0.9325, Loss: 0.0424
# Epoch   3 Batch  260/1077 - Train Accuracy: 0.9464, Validation Accuracy: 0.9329, Loss: 0.0353
# Epoch   3 Batch  280/1077 - Train Accuracy: 0.9246, Validation Accuracy: 0.9357, Loss: 0.0442
# Epoch   3 Batch  300/1077 - Train Accuracy: 0.9622, Validation Accuracy: 0.9386, Loss: 0.0378
# Epoch   3 Batch  320/1077 - Train Accuracy: 0.9570, Validation Accuracy: 0.9332, Loss: 0.0442
# Epoch   3 Batch  340/1077 - Train Accuracy: 0.9696, Validation Accuracy: 0.9371, Loss: 0.0386
# Epoch   3 Batch  360/1077 - Train Accuracy: 0.9598, Validation Accuracy: 0.9329, Loss: 0.0331
# Epoch   3 Batch  380/1077 - Train Accuracy: 0.9547, Validation Accuracy: 0.9300, Loss: 0.0412
# Epoch   3 Batch  400/1077 - Train Accuracy: 0.9242, Validation Accuracy: 0.9386, Loss: 0.0473
# Epoch   3 Batch  420/1077 - Train Accuracy: 0.9711, Validation Accuracy: 0.9364, Loss: 0.0293
# Epoch   3 Batch  440/1077 - Train Accuracy: 0.9422, Validation Accuracy: 0.9205, Loss: 0.0510
# Epoch   3 Batch  460/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9517, Loss: 0.0443
# Epoch   3 Batch  480/1077 - Train Accuracy: 0.9544, Validation Accuracy: 0.9325, Loss: 0.0399
# Epoch   3 Batch  500/1077 - Train Accuracy: 0.9508, Validation Accuracy: 0.9389, Loss: 0.0305
# Epoch   3 Batch  520/1077 - Train Accuracy: 0.9792, Validation Accuracy: 0.9563, Loss: 0.0333
# Epoch   3 Batch  540/1077 - Train Accuracy: 0.9695, Validation Accuracy: 0.9407, Loss: 0.0320
# Epoch   3 Batch  560/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.9329, Loss: 0.0323
# Epoch   3 Batch  580/1077 - Train Accuracy: 0.9754, Validation Accuracy: 0.9268, Loss: 0.0342
# Epoch   3 Batch  600/1077 - Train Accuracy: 0.9635, Validation Accuracy: 0.9357, Loss: 0.0493
# Epoch   3 Batch  620/1077 - Train Accuracy: 0.9793, Validation Accuracy: 0.9503, Loss: 0.0351
# Epoch   3 Batch  640/1077 - Train Accuracy: 0.9382, Validation Accuracy: 0.9588, Loss: 0.0387
# Epoch   3 Batch  660/1077 - Train Accuracy: 0.9680, Validation Accuracy: 0.9545, Loss: 0.0374
# Epoch   3 Batch  680/1077 - Train Accuracy: 0.9416, Validation Accuracy: 0.9474, Loss: 0.0338
# Epoch   3 Batch  700/1077 - Train Accuracy: 0.9754, Validation Accuracy: 0.9517, Loss: 0.0300
# Epoch   3 Batch  720/1077 - Train Accuracy: 0.9548, Validation Accuracy: 0.9368, Loss: 0.0369
# Epoch   3 Batch  740/1077 - Train Accuracy: 0.9551, Validation Accuracy: 0.9400, Loss: 0.0358
# Epoch   3 Batch  760/1077 - Train Accuracy: 0.9648, Validation Accuracy: 0.9560, Loss: 0.0431
# Epoch   3 Batch  780/1077 - Train Accuracy: 0.9328, Validation Accuracy: 0.9553, Loss: 0.0483
# Epoch   3 Batch  800/1077 - Train Accuracy: 0.9418, Validation Accuracy: 0.9506, Loss: 0.0366
# Epoch   3 Batch  820/1077 - Train Accuracy: 0.9652, Validation Accuracy: 0.9435, Loss: 0.0391
# Epoch   3 Batch  840/1077 - Train Accuracy: 0.9797, Validation Accuracy: 0.9531, Loss: 0.0304
# Epoch   3 Batch  860/1077 - Train Accuracy: 0.9565, Validation Accuracy: 0.9535, Loss: 0.0387
# Epoch   3 Batch  880/1077 - Train Accuracy: 0.9566, Validation Accuracy: 0.9524, Loss: 0.0432
# Epoch   3 Batch  900/1077 - Train Accuracy: 0.9570, Validation Accuracy: 0.9478, Loss: 0.0410
# Epoch   3 Batch  920/1077 - Train Accuracy: 0.9430, Validation Accuracy: 0.9510, Loss: 0.0295
# Epoch   3 Batch  940/1077 - Train Accuracy: 0.9578, Validation Accuracy: 0.9450, Loss: 0.0256
# Epoch   3 Batch  960/1077 - Train Accuracy: 0.9740, Validation Accuracy: 0.9482, Loss: 0.0318
# Epoch   3 Batch  980/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.9489, Loss: 0.0407
# Epoch   3 Batch 1000/1077 - Train Accuracy: 0.9635, Validation Accuracy: 0.9482, Loss: 0.0378
# Epoch   3 Batch 1020/1077 - Train Accuracy: 0.9555, Validation Accuracy: 0.9276, Loss: 0.0311
# Epoch   3 Batch 1040/1077 - Train Accuracy: 0.9659, Validation Accuracy: 0.9513, Loss: 0.0349
# Epoch   3 Batch 1060/1077 - Train Accuracy: 0.9660, Validation Accuracy: 0.9482, Loss: 0.0220
# Epoch   4 Batch   20/1077 - Train Accuracy: 0.9488, Validation Accuracy: 0.9652, Loss: 0.0304
# Epoch   4 Batch   40/1077 - Train Accuracy: 0.9840, Validation Accuracy: 0.9592, Loss: 0.0275
# Epoch   4 Batch   60/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9446, Loss: 0.0290
# Epoch   4 Batch   80/1077 - Train Accuracy: 0.9395, Validation Accuracy: 0.9496, Loss: 0.0261
# Epoch   4 Batch  100/1077 - Train Accuracy: 0.9547, Validation Accuracy: 0.9517, Loss: 0.0312
# Epoch   4 Batch  120/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9553, Loss: 0.0324
# Epoch   4 Batch  140/1077 - Train Accuracy: 0.9576, Validation Accuracy: 0.9585, Loss: 0.0304
# Epoch   4 Batch  160/1077 - Train Accuracy: 0.9648, Validation Accuracy: 0.9549, Loss: 0.0303
# Epoch   4 Batch  180/1077 - Train Accuracy: 0.9664, Validation Accuracy: 0.9371, Loss: 0.0263
# Epoch   4 Batch  200/1077 - Train Accuracy: 0.9547, Validation Accuracy: 0.9549, Loss: 0.0310
# Epoch   4 Batch  220/1077 - Train Accuracy: 0.9638, Validation Accuracy: 0.9606, Loss: 0.0279
# Epoch   4 Batch  240/1077 - Train Accuracy: 0.9719, Validation Accuracy: 0.9521, Loss: 0.0285
# Epoch   4 Batch  260/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9545, Loss: 0.0267
# Epoch   4 Batch  280/1077 - Train Accuracy: 0.9492, Validation Accuracy: 0.9418, Loss: 0.0318
# Epoch   4 Batch  300/1077 - Train Accuracy: 0.9593, Validation Accuracy: 0.9457, Loss: 0.0264
# Epoch   4 Batch  320/1077 - Train Accuracy: 0.9695, Validation Accuracy: 0.9482, Loss: 0.0317
# Epoch   4 Batch  340/1077 - Train Accuracy: 0.9873, Validation Accuracy: 0.9513, Loss: 0.0250
# Epoch   4 Batch  360/1077 - Train Accuracy: 0.9508, Validation Accuracy: 0.9506, Loss: 0.0252
# Epoch   4 Batch  380/1077 - Train Accuracy: 0.9773, Validation Accuracy: 0.9517, Loss: 0.0228
# Epoch   4 Batch  400/1077 - Train Accuracy: 0.9680, Validation Accuracy: 0.9382, Loss: 0.0394
# Epoch   4 Batch  420/1077 - Train Accuracy: 0.9773, Validation Accuracy: 0.9474, Loss: 0.0207
# Epoch   4 Batch  440/1077 - Train Accuracy: 0.9422, Validation Accuracy: 0.9354, Loss: 0.0328
# Epoch   4 Batch  460/1077 - Train Accuracy: 0.9586, Validation Accuracy: 0.9549, Loss: 0.0278
# Epoch   4 Batch  480/1077 - Train Accuracy: 0.9663, Validation Accuracy: 0.9439, Loss: 0.0228
# Epoch   4 Batch  500/1077 - Train Accuracy: 0.9676, Validation Accuracy: 0.9581, Loss: 0.0218
# Epoch   4 Batch  520/1077 - Train Accuracy: 0.9918, Validation Accuracy: 0.9705, Loss: 0.0207
# Epoch   4 Batch  540/1077 - Train Accuracy: 0.9703, Validation Accuracy: 0.9624, Loss: 0.0252
# Epoch   4 Batch  560/1077 - Train Accuracy: 0.9785, Validation Accuracy: 0.9542, Loss: 0.0241
# Epoch   4 Batch  580/1077 - Train Accuracy: 0.9766, Validation Accuracy: 0.9680, Loss: 0.0230
# Epoch   4 Batch  600/1077 - Train Accuracy: 0.9807, Validation Accuracy: 0.9631, Loss: 0.0305
# Epoch   4 Batch  620/1077 - Train Accuracy: 0.9828, Validation Accuracy: 0.9741, Loss: 0.0281
# Epoch   4 Batch  640/1077 - Train Accuracy: 0.9606, Validation Accuracy: 0.9705, Loss: 0.0275
# Epoch   4 Batch  660/1077 - Train Accuracy: 0.9742, Validation Accuracy: 0.9549, Loss: 0.0269
# Epoch   4 Batch  680/1077 - Train Accuracy: 0.9673, Validation Accuracy: 0.9585, Loss: 0.0252
# Epoch   4 Batch  700/1077 - Train Accuracy: 0.9848, Validation Accuracy: 0.9563, Loss: 0.0227
# Epoch   4 Batch  720/1077 - Train Accuracy: 0.9548, Validation Accuracy: 0.9602, Loss: 0.0240
# Epoch   4 Batch  740/1077 - Train Accuracy: 0.9719, Validation Accuracy: 0.9503, Loss: 0.0253
# Epoch   4 Batch  760/1077 - Train Accuracy: 0.9773, Validation Accuracy: 0.9581, Loss: 0.0268
# Epoch   4 Batch  780/1077 - Train Accuracy: 0.9586, Validation Accuracy: 0.9535, Loss: 0.0355
# Epoch   4 Batch  800/1077 - Train Accuracy: 0.9578, Validation Accuracy: 0.9680, Loss: 0.0249
# Epoch   4 Batch  820/1077 - Train Accuracy: 0.9824, Validation Accuracy: 0.9656, Loss: 0.0217
# Epoch   4 Batch  840/1077 - Train Accuracy: 0.9914, Validation Accuracy: 0.9727, Loss: 0.0207
# Epoch   4 Batch  860/1077 - Train Accuracy: 0.9725, Validation Accuracy: 0.9688, Loss: 0.0265
# Epoch   4 Batch  880/1077 - Train Accuracy: 0.9754, Validation Accuracy: 0.9581, Loss: 0.0329
# Epoch   4 Batch  900/1077 - Train Accuracy: 0.9680, Validation Accuracy: 0.9538, Loss: 0.0277
# Epoch   4 Batch  920/1077 - Train Accuracy: 0.9602, Validation Accuracy: 0.9730, Loss: 0.0223
# Epoch   4 Batch  940/1077 - Train Accuracy: 0.9695, Validation Accuracy: 0.9659, Loss: 0.0223
# Epoch   4 Batch  960/1077 - Train Accuracy: 0.9788, Validation Accuracy: 0.9602, Loss: 0.0226
# Epoch   4 Batch  980/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9499, Loss: 0.0273
# Epoch   4 Batch 1000/1077 - Train Accuracy: 0.9505, Validation Accuracy: 0.9560, Loss: 0.0271
# Epoch   4 Batch 1020/1077 - Train Accuracy: 0.9695, Validation Accuracy: 0.9624, Loss: 0.0187
# Epoch   4 Batch 1040/1077 - Train Accuracy: 0.9737, Validation Accuracy: 0.9638, Loss: 0.0237
# Epoch   4 Batch 1060/1077 - Train Accuracy: 0.9805, Validation Accuracy: 0.9535, Loss: 0.0171
# Epoch   5 Batch   20/1077 - Train Accuracy: 0.9801, Validation Accuracy: 0.9702, Loss: 0.0226
# Epoch   5 Batch   40/1077 - Train Accuracy: 0.9840, Validation Accuracy: 0.9581, Loss: 0.0193
# Epoch   5 Batch   60/1077 - Train Accuracy: 0.9594, Validation Accuracy: 0.9627, Loss: 0.0182
# Epoch   5 Batch   80/1077 - Train Accuracy: 0.9559, Validation Accuracy: 0.9677, Loss: 0.0188
# Epoch   5 Batch  100/1077 - Train Accuracy: 0.9848, Validation Accuracy: 0.9567, Loss: 0.0204
# Epoch   5 Batch  120/1077 - Train Accuracy: 0.9746, Validation Accuracy: 0.9659, Loss: 0.0264
# Epoch   5 Batch  140/1077 - Train Accuracy: 0.9618, Validation Accuracy: 0.9709, Loss: 0.0239
# Epoch   5 Batch  160/1077 - Train Accuracy: 0.9754, Validation Accuracy: 0.9712, Loss: 0.0184
# Epoch   5 Batch  180/1077 - Train Accuracy: 0.9883, Validation Accuracy: 0.9609, Loss: 0.0216
# Epoch   5 Batch  200/1077 - Train Accuracy: 0.9668, Validation Accuracy: 0.9574, Loss: 0.0217
# Epoch   5 Batch  220/1077 - Train Accuracy: 0.9757, Validation Accuracy: 0.9425, Loss: 0.0261
# Epoch   5 Batch  240/1077 - Train Accuracy: 0.9805, Validation Accuracy: 0.9656, Loss: 0.0223
# Epoch   5 Batch  260/1077 - Train Accuracy: 0.9565, Validation Accuracy: 0.9744, Loss: 0.0187
# Epoch   5 Batch  280/1077 - Train Accuracy: 0.9465, Validation Accuracy: 0.9574, Loss: 0.0279
# Epoch   5 Batch  300/1077 - Train Accuracy: 0.9667, Validation Accuracy: 0.9577, Loss: 0.0194
# Epoch   5 Batch  320/1077 - Train Accuracy: 0.9832, Validation Accuracy: 0.9709, Loss: 0.0250
# Epoch   5 Batch  340/1077 - Train Accuracy: 0.9840, Validation Accuracy: 0.9666, Loss: 0.0197
# Epoch   5 Batch  360/1077 - Train Accuracy: 0.9652, Validation Accuracy: 0.9783, Loss: 0.0166
# Epoch   5 Batch  380/1077 - Train Accuracy: 0.9742, Validation Accuracy: 0.9695, Loss: 0.0161
# Epoch   5 Batch  400/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9709, Loss: 0.0233
# Epoch   5 Batch  420/1077 - Train Accuracy: 0.9801, Validation Accuracy: 0.9638, Loss: 0.0170
# Epoch   5 Batch  440/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9645, Loss: 0.0289
# Epoch   5 Batch  460/1077 - Train Accuracy: 0.9676, Validation Accuracy: 0.9652, Loss: 0.0216
# Epoch   5 Batch  480/1077 - Train Accuracy: 0.9667, Validation Accuracy: 0.9556, Loss: 0.0245
# Epoch   5 Batch  500/1077 - Train Accuracy: 0.9734, Validation Accuracy: 0.9570, Loss: 0.0156
# Epoch   5 Batch  520/1077 - Train Accuracy: 0.9900, Validation Accuracy: 0.9666, Loss: 0.0139
# Epoch   5 Batch  540/1077 - Train Accuracy: 0.9801, Validation Accuracy: 0.9680, Loss: 0.0151
# Epoch   5 Batch  560/1077 - Train Accuracy: 0.9727, Validation Accuracy: 0.9599, Loss: 0.0169
# Epoch   5 Batch  580/1077 - Train Accuracy: 0.9754, Validation Accuracy: 0.9595, Loss: 0.0185
# Epoch   5 Batch  600/1077 - Train Accuracy: 0.9751, Validation Accuracy: 0.9538, Loss: 0.0279
# Epoch   5 Batch  620/1077 - Train Accuracy: 0.9734, Validation Accuracy: 0.9641, Loss: 0.0244
# Epoch   5 Batch  640/1077 - Train Accuracy: 0.9624, Validation Accuracy: 0.9702, Loss: 0.0203
# Epoch   5 Batch  660/1077 - Train Accuracy: 0.9898, Validation Accuracy: 0.9574, Loss: 0.0228
# Epoch   5 Batch  680/1077 - Train Accuracy: 0.9576, Validation Accuracy: 0.9673, Loss: 0.0196
# Epoch   5 Batch  700/1077 - Train Accuracy: 0.9910, Validation Accuracy: 0.9656, Loss: 0.0152
# Epoch   5 Batch  720/1077 - Train Accuracy: 0.9581, Validation Accuracy: 0.9670, Loss: 0.0245
# Epoch   5 Batch  740/1077 - Train Accuracy: 0.9727, Validation Accuracy: 0.9577, Loss: 0.0182
# Epoch   5 Batch  760/1077 - Train Accuracy: 0.9754, Validation Accuracy: 0.9620, Loss: 0.0250
# Epoch   5 Batch  780/1077 - Train Accuracy: 0.9625, Validation Accuracy: 0.9659, Loss: 0.0278
# Epoch   5 Batch  800/1077 - Train Accuracy: 0.9895, Validation Accuracy: 0.9730, Loss: 0.0174
# Epoch   5 Batch  820/1077 - Train Accuracy: 0.9852, Validation Accuracy: 0.9570, Loss: 0.0161
# Epoch   5 Batch  840/1077 - Train Accuracy: 0.9984, Validation Accuracy: 0.9656, Loss: 0.0189
# Epoch   5 Batch  860/1077 - Train Accuracy: 0.9762, Validation Accuracy: 0.9684, Loss: 0.0224
# Epoch   5 Batch  880/1077 - Train Accuracy: 0.9906, Validation Accuracy: 0.9638, Loss: 0.0251
# Epoch   5 Batch  900/1077 - Train Accuracy: 0.9777, Validation Accuracy: 0.9602, Loss: 0.0240
# Epoch   5 Batch  920/1077 - Train Accuracy: 0.9781, Validation Accuracy: 0.9812, Loss: 0.0143
# Epoch   5 Batch  940/1077 - Train Accuracy: 0.9711, Validation Accuracy: 0.9659, Loss: 0.0141
# Epoch   5 Batch  960/1077 - Train Accuracy: 0.9743, Validation Accuracy: 0.9709, Loss: 0.0224
# Epoch   5 Batch  980/1077 - Train Accuracy: 0.9559, Validation Accuracy: 0.9705, Loss: 0.0221
# Epoch   5 Batch 1000/1077 - Train Accuracy: 0.9721, Validation Accuracy: 0.9680, Loss: 0.0171
# Epoch   5 Batch 1020/1077 - Train Accuracy: 0.9949, Validation Accuracy: 0.9695, Loss: 0.0149
# Epoch   5 Batch 1040/1077 - Train Accuracy: 0.9770, Validation Accuracy: 0.9691, Loss: 0.0354
# Epoch   5 Batch 1060/1077 - Train Accuracy: 0.9703, Validation Accuracy: 0.9656, Loss: 0.0226
# Epoch   6 Batch   20/1077 - Train Accuracy: 0.9812, Validation Accuracy: 0.9624, Loss: 0.0169
# Epoch   6 Batch   40/1077 - Train Accuracy: 0.9871, Validation Accuracy: 0.9574, Loss: 0.0169
# Epoch   6 Batch   60/1077 - Train Accuracy: 0.9598, Validation Accuracy: 0.9716, Loss: 0.0164
# Epoch   6 Batch   80/1077 - Train Accuracy: 0.9594, Validation Accuracy: 0.9677, Loss: 0.0190
# Epoch   6 Batch  100/1077 - Train Accuracy: 0.9805, Validation Accuracy: 0.9751, Loss: 0.0178
# Epoch   6 Batch  120/1077 - Train Accuracy: 0.9734, Validation Accuracy: 0.9741, Loss: 0.0228
# Epoch   6 Batch  140/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9659, Loss: 0.0154
# Epoch   6 Batch  160/1077 - Train Accuracy: 0.9871, Validation Accuracy: 0.9723, Loss: 0.0181
# Epoch   6 Batch  180/1077 - Train Accuracy: 0.9906, Validation Accuracy: 0.9624, Loss: 0.0117
# Epoch   6 Batch  200/1077 - Train Accuracy: 0.9793, Validation Accuracy: 0.9616, Loss: 0.0202
# Epoch   6 Batch  220/1077 - Train Accuracy: 0.9720, Validation Accuracy: 0.9592, Loss: 0.0196
# Epoch   6 Batch  240/1077 - Train Accuracy: 0.9848, Validation Accuracy: 0.9673, Loss: 0.0155
# Epoch   6 Batch  260/1077 - Train Accuracy: 0.9621, Validation Accuracy: 0.9727, Loss: 0.0154
# Epoch   6 Batch  280/1077 - Train Accuracy: 0.9762, Validation Accuracy: 0.9691, Loss: 0.0186
# Epoch   6 Batch  300/1077 - Train Accuracy: 0.9790, Validation Accuracy: 0.9638, Loss: 0.0142
# Epoch   6 Batch  320/1077 - Train Accuracy: 0.9711, Validation Accuracy: 0.9734, Loss: 0.0192
# Epoch   6 Batch  340/1077 - Train Accuracy: 0.9922, Validation Accuracy: 0.9812, Loss: 0.0158
# Epoch   6 Batch  360/1077 - Train Accuracy: 0.9664, Validation Accuracy: 0.9730, Loss: 0.0102
# Epoch   6 Batch  380/1077 - Train Accuracy: 0.9836, Validation Accuracy: 0.9670, Loss: 0.0142
# Epoch   6 Batch  400/1077 - Train Accuracy: 0.9781, Validation Accuracy: 0.9641, Loss: 0.0178
# Epoch   6 Batch  420/1077 - Train Accuracy: 0.9824, Validation Accuracy: 0.9663, Loss: 0.0119
# Epoch   6 Batch  440/1077 - Train Accuracy: 0.9695, Validation Accuracy: 0.9709, Loss: 0.0195
# Epoch   6 Batch  460/1077 - Train Accuracy: 0.9738, Validation Accuracy: 0.9656, Loss: 0.0159
# Epoch   6 Batch  480/1077 - Train Accuracy: 0.9737, Validation Accuracy: 0.9631, Loss: 0.0159
# Epoch   6 Batch  500/1077 - Train Accuracy: 0.9793, Validation Accuracy: 0.9702, Loss: 0.0122
# Epoch   6 Batch  520/1077 - Train Accuracy: 0.9881, Validation Accuracy: 0.9712, Loss: 0.0116
# Epoch   6 Batch  540/1077 - Train Accuracy: 0.9844, Validation Accuracy: 0.9599, Loss: 0.0141
# Epoch   6 Batch  560/1077 - Train Accuracy: 0.9820, Validation Accuracy: 0.9595, Loss: 0.0145
# Epoch   6 Batch  580/1077 - Train Accuracy: 0.9788, Validation Accuracy: 0.9705, Loss: 0.0149
# Epoch   6 Batch  600/1077 - Train Accuracy: 0.9766, Validation Accuracy: 0.9734, Loss: 0.0188
# Epoch   6 Batch  620/1077 - Train Accuracy: 0.9812, Validation Accuracy: 0.9751, Loss: 0.0171
# Epoch   6 Batch  640/1077 - Train Accuracy: 0.9829, Validation Accuracy: 0.9709, Loss: 0.0128
# Epoch   6 Batch  660/1077 - Train Accuracy: 0.9895, Validation Accuracy: 0.9673, Loss: 0.0097
# Epoch   6 Batch  680/1077 - Train Accuracy: 0.9788, Validation Accuracy: 0.9751, Loss: 0.0133
# Epoch   6 Batch  700/1077 - Train Accuracy: 0.9980, Validation Accuracy: 0.9567, Loss: 0.0129
# Epoch   6 Batch  720/1077 - Train Accuracy: 0.9757, Validation Accuracy: 0.9677, Loss: 0.0194
# Epoch   6 Batch  740/1077 - Train Accuracy: 0.9586, Validation Accuracy: 0.9659, Loss: 0.0160
# Epoch   6 Batch  760/1077 - Train Accuracy: 0.9891, Validation Accuracy: 0.9599, Loss: 0.0151
# Epoch   6 Batch  780/1077 - Train Accuracy: 0.9625, Validation Accuracy: 0.9648, Loss: 0.0215
# Epoch   6 Batch  800/1077 - Train Accuracy: 0.9812, Validation Accuracy: 0.9730, Loss: 0.0133
# Epoch   6 Batch  820/1077 - Train Accuracy: 0.9844, Validation Accuracy: 0.9691, Loss: 0.0121
# Epoch   6 Batch  840/1077 - Train Accuracy: 0.9887, Validation Accuracy: 0.9759, Loss: 0.0156
# Epoch   6 Batch  860/1077 - Train Accuracy: 0.9799, Validation Accuracy: 0.9762, Loss: 0.0160
# Epoch   6 Batch  880/1077 - Train Accuracy: 0.9820, Validation Accuracy: 0.9663, Loss: 0.0183
# Epoch   6 Batch  900/1077 - Train Accuracy: 0.9699, Validation Accuracy: 0.9592, Loss: 0.0209
# Epoch   6 Batch  920/1077 - Train Accuracy: 0.9719, Validation Accuracy: 0.9822, Loss: 0.0135
# Epoch   6 Batch  940/1077 - Train Accuracy: 0.9711, Validation Accuracy: 0.9755, Loss: 0.0133
# Epoch   6 Batch  960/1077 - Train Accuracy: 0.9758, Validation Accuracy: 0.9712, Loss: 0.0154
# Epoch   6 Batch  980/1077 - Train Accuracy: 0.9715, Validation Accuracy: 0.9609, Loss: 0.0135
# Epoch   6 Batch 1000/1077 - Train Accuracy: 0.9803, Validation Accuracy: 0.9645, Loss: 0.0175
# Epoch   6 Batch 1020/1077 - Train Accuracy: 0.9910, Validation Accuracy: 0.9709, Loss: 0.0124
# Epoch   6 Batch 1040/1077 - Train Accuracy: 0.9774, Validation Accuracy: 0.9698, Loss: 0.0146
# Epoch   6 Batch 1060/1077 - Train Accuracy: 0.9883, Validation Accuracy: 0.9620, Loss: 0.0115
# Epoch   7 Batch   20/1077 - Train Accuracy: 0.9805, Validation Accuracy: 0.9648, Loss: 0.0135
# Epoch   7 Batch   40/1077 - Train Accuracy: 0.9934, Validation Accuracy: 0.9702, Loss: 0.0115
# Epoch   7 Batch   60/1077 - Train Accuracy: 0.9788, Validation Accuracy: 0.9656, Loss: 0.0141
# Epoch   7 Batch   80/1077 - Train Accuracy: 0.9824, Validation Accuracy: 0.9702, Loss: 0.0127
# Epoch   7 Batch  100/1077 - Train Accuracy: 0.9840, Validation Accuracy: 0.9656, Loss: 0.0142
# Epoch   7 Batch  120/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9741, Loss: 0.0149
# Epoch   7 Batch  140/1077 - Train Accuracy: 0.9827, Validation Accuracy: 0.9776, Loss: 0.0138
# Epoch   7 Batch  160/1077 - Train Accuracy: 0.9879, Validation Accuracy: 0.9645, Loss: 0.0128
# Epoch   7 Batch  180/1077 - Train Accuracy: 0.9820, Validation Accuracy: 0.9577, Loss: 0.0129
# Epoch   7 Batch  200/1077 - Train Accuracy: 0.9828, Validation Accuracy: 0.9553, Loss: 0.0138
# Epoch   7 Batch  220/1077 - Train Accuracy: 0.9774, Validation Accuracy: 0.9783, Loss: 0.0138
# Epoch   7 Batch  240/1077 - Train Accuracy: 0.9910, Validation Accuracy: 0.9673, Loss: 0.0109
# Epoch   7 Batch  260/1077 - Train Accuracy: 0.9818, Validation Accuracy: 0.9712, Loss: 0.0150
# Epoch   7 Batch  280/1077 - Train Accuracy: 0.9742, Validation Accuracy: 0.9709, Loss: 0.0186
# Epoch   7 Batch  300/1077 - Train Accuracy: 0.9778, Validation Accuracy: 0.9698, Loss: 0.0172
# Epoch   7 Batch  320/1077 - Train Accuracy: 0.9746, Validation Accuracy: 0.9723, Loss: 0.0205
# Epoch   7 Batch  340/1077 - Train Accuracy: 0.9934, Validation Accuracy: 0.9751, Loss: 0.0147
# Epoch   7 Batch  360/1077 - Train Accuracy: 0.9910, Validation Accuracy: 0.9609, Loss: 0.0091
# Epoch   7 Batch  380/1077 - Train Accuracy: 0.9898, Validation Accuracy: 0.9737, Loss: 0.0085
# Epoch   7 Batch  400/1077 - Train Accuracy: 0.9793, Validation Accuracy: 0.9847, Loss: 0.0148
# Epoch   7 Batch  420/1077 - Train Accuracy: 0.9852, Validation Accuracy: 0.9652, Loss: 0.0118
# Epoch   7 Batch  440/1077 - Train Accuracy: 0.9684, Validation Accuracy: 0.9691, Loss: 0.0140
# Epoch   7 Batch  460/1077 - Train Accuracy: 0.9695, Validation Accuracy: 0.9652, Loss: 0.0147
# Epoch   7 Batch  480/1077 - Train Accuracy: 0.9716, Validation Accuracy: 0.9734, Loss: 0.0131
# Epoch   7 Batch  500/1077 - Train Accuracy: 0.9836, Validation Accuracy: 0.9631, Loss: 0.0125
# Epoch   7 Batch  520/1077 - Train Accuracy: 0.9981, Validation Accuracy: 0.9705, Loss: 0.0105
# Epoch   7 Batch  540/1077 - Train Accuracy: 0.9836, Validation Accuracy: 0.9744, Loss: 0.0129
# Epoch   7 Batch  560/1077 - Train Accuracy: 0.9797, Validation Accuracy: 0.9606, Loss: 0.0174
# Epoch   7 Batch  580/1077 - Train Accuracy: 0.9632, Validation Accuracy: 0.9773, Loss: 0.0140
# Epoch   7 Batch  600/1077 - Train Accuracy: 0.9803, Validation Accuracy: 0.9780, Loss: 0.0151
# Epoch   7 Batch  620/1077 - Train Accuracy: 0.9922, Validation Accuracy: 0.9798, Loss: 0.0124
# Epoch   7 Batch  640/1077 - Train Accuracy: 0.9836, Validation Accuracy: 0.9819, Loss: 0.0129
# Epoch   7 Batch  660/1077 - Train Accuracy: 0.9898, Validation Accuracy: 0.9716, Loss: 0.0112
# Epoch   7 Batch  680/1077 - Train Accuracy: 0.9647, Validation Accuracy: 0.9759, Loss: 0.0145
# Epoch   7 Batch  700/1077 - Train Accuracy: 0.9906, Validation Accuracy: 0.9634, Loss: 0.0100
# Epoch   7 Batch  720/1077 - Train Accuracy: 0.9856, Validation Accuracy: 0.9805, Loss: 0.0110
# Epoch   7 Batch  740/1077 - Train Accuracy: 0.9754, Validation Accuracy: 0.9641, Loss: 0.0120
# Epoch   7 Batch  760/1077 - Train Accuracy: 0.9926, Validation Accuracy: 0.9780, Loss: 0.0102
# Epoch   7 Batch  780/1077 - Train Accuracy: 0.9734, Validation Accuracy: 0.9812, Loss: 0.0163
# Epoch   7 Batch  800/1077 - Train Accuracy: 0.9859, Validation Accuracy: 0.9872, Loss: 0.0106
# Epoch   7 Batch  820/1077 - Train Accuracy: 0.9910, Validation Accuracy: 0.9613, Loss: 0.0105
# Epoch   7 Batch  840/1077 - Train Accuracy: 0.9930, Validation Accuracy: 0.9716, Loss: 0.0148
# Epoch   7 Batch  860/1077 - Train Accuracy: 0.9929, Validation Accuracy: 0.9805, Loss: 0.0136
# Epoch   7 Batch  880/1077 - Train Accuracy: 0.9930, Validation Accuracy: 0.9691, Loss: 0.0159
# Epoch   7 Batch  900/1077 - Train Accuracy: 0.9836, Validation Accuracy: 0.9780, Loss: 0.0175
# Epoch   7 Batch  920/1077 - Train Accuracy: 0.9934, Validation Accuracy: 0.9790, Loss: 0.0093
# Epoch   7 Batch  940/1077 - Train Accuracy: 0.9660, Validation Accuracy: 0.9723, Loss: 0.0132
# Epoch   7 Batch  960/1077 - Train Accuracy: 0.9810, Validation Accuracy: 0.9698, Loss: 0.0120
# Epoch   7 Batch  980/1077 - Train Accuracy: 0.9730, Validation Accuracy: 0.9805, Loss: 0.0130
# Epoch   7 Batch 1000/1077 - Train Accuracy: 0.9773, Validation Accuracy: 0.9744, Loss: 0.0146
# Epoch   7 Batch 1020/1077 - Train Accuracy: 0.9859, Validation Accuracy: 0.9790, Loss: 0.0115
# Epoch   7 Batch 1040/1077 - Train Accuracy: 0.9782, Validation Accuracy: 0.9755, Loss: 0.0088
# Epoch   7 Batch 1060/1077 - Train Accuracy: 0.9949, Validation Accuracy: 0.9719, Loss: 0.0108
# Epoch   8 Batch   20/1077 - Train Accuracy: 0.9832, Validation Accuracy: 0.9755, Loss: 0.0126
# Epoch   8 Batch   40/1077 - Train Accuracy: 0.9867, Validation Accuracy: 0.9702, Loss: 0.0113
# Epoch   8 Batch   60/1077 - Train Accuracy: 0.9814, Validation Accuracy: 0.9808, Loss: 0.0139
# Epoch   8 Batch   80/1077 - Train Accuracy: 0.9789, Validation Accuracy: 0.9641, Loss: 0.0110
# Epoch   8 Batch  100/1077 - Train Accuracy: 0.9965, Validation Accuracy: 0.9734, Loss: 0.0113
# Epoch   8 Batch  120/1077 - Train Accuracy: 0.9883, Validation Accuracy: 0.9787, Loss: 0.0133
# Epoch   8 Batch  140/1077 - Train Accuracy: 0.9840, Validation Accuracy: 0.9794, Loss: 0.0141
# Epoch   8 Batch  160/1077 - Train Accuracy: 0.9832, Validation Accuracy: 0.9830, Loss: 0.0091
# Epoch   8 Batch  180/1077 - Train Accuracy: 0.9848, Validation Accuracy: 0.9819, Loss: 0.0186
# Epoch   8 Batch  200/1077 - Train Accuracy: 0.9875, Validation Accuracy: 0.9762, Loss: 0.0178
# Epoch   8 Batch  220/1077 - Train Accuracy: 0.9815, Validation Accuracy: 0.9883, Loss: 0.0160
# Epoch   8 Batch  240/1077 - Train Accuracy: 0.9930, Validation Accuracy: 0.9879, Loss: 0.0099
# Epoch   8 Batch  260/1077 - Train Accuracy: 0.9877, Validation Accuracy: 0.9819, Loss: 0.0111
# Epoch   8 Batch  280/1077 - Train Accuracy: 0.9730, Validation Accuracy: 0.9631, Loss: 0.0156
# Epoch   8 Batch  300/1077 - Train Accuracy: 0.9897, Validation Accuracy: 0.9702, Loss: 0.0146
# Epoch   8 Batch  320/1077 - Train Accuracy: 0.9777, Validation Accuracy: 0.9652, Loss: 0.0190
# Epoch   8 Batch  340/1077 - Train Accuracy: 0.9942, Validation Accuracy: 0.9794, Loss: 0.0129
# Epoch   8 Batch  360/1077 - Train Accuracy: 0.9910, Validation Accuracy: 0.9790, Loss: 0.0107
# Epoch   8 Batch  380/1077 - Train Accuracy: 0.9867, Validation Accuracy: 0.9808, Loss: 0.0068
# Epoch   8 Batch  400/1077 - Train Accuracy: 0.9797, Validation Accuracy: 0.9862, Loss: 0.0148
# Epoch   8 Batch  420/1077 - Train Accuracy: 0.9832, Validation Accuracy: 0.9727, Loss: 0.0088
# Epoch   8 Batch  440/1077 - Train Accuracy: 0.9660, Validation Accuracy: 0.9727, Loss: 0.0141
# Epoch   8 Batch  460/1077 - Train Accuracy: 0.9875, Validation Accuracy: 0.9680, Loss: 0.0094
# Epoch   8 Batch  480/1077 - Train Accuracy: 0.9774, Validation Accuracy: 0.9585, Loss: 0.0125
# Epoch   8 Batch  500/1077 - Train Accuracy: 0.9887, Validation Accuracy: 0.9730, Loss: 0.0080
# Epoch   8 Batch  520/1077 - Train Accuracy: 0.9851, Validation Accuracy: 0.9858, Loss: 0.0076
# Epoch   8 Batch  540/1077 - Train Accuracy: 0.9848, Validation Accuracy: 0.9744, Loss: 0.0130
# Epoch   8 Batch  560/1077 - Train Accuracy: 0.9805, Validation Accuracy: 0.9670, Loss: 0.0113
# Epoch   8 Batch  580/1077 - Train Accuracy: 0.9847, Validation Accuracy: 0.9751, Loss: 0.0103
# Epoch   8 Batch  600/1077 - Train Accuracy: 0.9781, Validation Accuracy: 0.9638, Loss: 0.0164
# Epoch   8 Batch  620/1077 - Train Accuracy: 0.9754, Validation Accuracy: 0.9819, Loss: 0.0136
# Epoch   8 Batch  640/1077 - Train Accuracy: 0.9855, Validation Accuracy: 0.9865, Loss: 0.0105
# Epoch   8 Batch  660/1077 - Train Accuracy: 0.9926, Validation Accuracy: 0.9748, Loss: 0.0104
# Epoch   8 Batch  680/1077 - Train Accuracy: 0.9814, Validation Accuracy: 0.9822, Loss: 0.0103
# Epoch   8 Batch  700/1077 - Train Accuracy: 0.9949, Validation Accuracy: 0.9734, Loss: 0.0053
# Epoch   8 Batch  720/1077 - Train Accuracy: 0.9753, Validation Accuracy: 0.9755, Loss: 0.0113
# Epoch   8 Batch  740/1077 - Train Accuracy: 0.9785, Validation Accuracy: 0.9734, Loss: 0.0118
# Epoch   8 Batch  760/1077 - Train Accuracy: 0.9906, Validation Accuracy: 0.9762, Loss: 0.0103
# Epoch   8 Batch  780/1077 - Train Accuracy: 0.9719, Validation Accuracy: 0.9719, Loss: 0.0145
# Epoch   8 Batch  800/1077 - Train Accuracy: 0.9938, Validation Accuracy: 0.9801, Loss: 0.0130
# Epoch   8 Batch  820/1077 - Train Accuracy: 0.9910, Validation Accuracy: 0.9744, Loss: 0.0101
# Epoch   8 Batch  840/1077 - Train Accuracy: 0.9875, Validation Accuracy: 0.9691, Loss: 0.0110
# Epoch   8 Batch  860/1077 - Train Accuracy: 0.9922, Validation Accuracy: 0.9801, Loss: 0.0092
# Epoch   8 Batch  880/1077 - Train Accuracy: 0.9938, Validation Accuracy: 0.9688, Loss: 0.0133
# Epoch   8 Batch  900/1077 - Train Accuracy: 0.9859, Validation Accuracy: 0.9666, Loss: 0.0147
# Epoch   8 Batch  920/1077 - Train Accuracy: 0.9902, Validation Accuracy: 0.9794, Loss: 0.0110
# Epoch   8 Batch  940/1077 - Train Accuracy: 0.9715, Validation Accuracy: 0.9769, Loss: 0.0099
# Epoch   8 Batch  960/1077 - Train Accuracy: 0.9870, Validation Accuracy: 0.9819, Loss: 0.0104
# Epoch   8 Batch  980/1077 - Train Accuracy: 0.9695, Validation Accuracy: 0.9812, Loss: 0.0125
# Epoch   8 Batch 1000/1077 - Train Accuracy: 0.9781, Validation Accuracy: 0.9719, Loss: 0.0121
# Epoch   8 Batch 1020/1077 - Train Accuracy: 0.9840, Validation Accuracy: 0.9755, Loss: 0.0112
# Epoch   8 Batch 1040/1077 - Train Accuracy: 0.9737, Validation Accuracy: 0.9702, Loss: 0.0164
# Epoch   8 Batch 1060/1077 - Train Accuracy: 0.9934, Validation Accuracy: 0.9776, Loss: 0.0085
# Epoch   9 Batch   20/1077 - Train Accuracy: 0.9863, Validation Accuracy: 0.9805, Loss: 0.0123
# Epoch   9 Batch   40/1077 - Train Accuracy: 0.9887, Validation Accuracy: 0.9862, Loss: 0.0070
# Epoch   9 Batch   60/1077 - Train Accuracy: 0.9795, Validation Accuracy: 0.9698, Loss: 0.0099
# Epoch   9 Batch   80/1077 - Train Accuracy: 0.9855, Validation Accuracy: 0.9702, Loss: 0.0104
# Epoch   9 Batch  100/1077 - Train Accuracy: 0.9750, Validation Accuracy: 0.9769, Loss: 0.0119
# Epoch   9 Batch  120/1077 - Train Accuracy: 0.9914, Validation Accuracy: 0.9787, Loss: 0.0114
# Epoch   9 Batch  140/1077 - Train Accuracy: 0.9947, Validation Accuracy: 0.9727, Loss: 0.0121
# Epoch   9 Batch  160/1077 - Train Accuracy: 0.9906, Validation Accuracy: 0.9727, Loss: 0.0072
# Epoch   9 Batch  180/1077 - Train Accuracy: 0.9863, Validation Accuracy: 0.9805, Loss: 0.0100
# Epoch   9 Batch  200/1077 - Train Accuracy: 0.9820, Validation Accuracy: 0.9737, Loss: 0.0131
# Epoch   9 Batch  220/1077 - Train Accuracy: 0.9663, Validation Accuracy: 0.9719, Loss: 0.0107
# Epoch   9 Batch  240/1077 - Train Accuracy: 0.9941, Validation Accuracy: 0.9759, Loss: 0.0114
# Epoch   9 Batch  260/1077 - Train Accuracy: 0.9821, Validation Accuracy: 0.9776, Loss: 0.0102
# Epoch   9 Batch  280/1077 - Train Accuracy: 0.9754, Validation Accuracy: 0.9727, Loss: 0.0140
# Epoch   9 Batch  300/1077 - Train Accuracy: 0.9918, Validation Accuracy: 0.9567, Loss: 0.0107
# Epoch   9 Batch  320/1077 - Train Accuracy: 0.9797, Validation Accuracy: 0.9705, Loss: 0.0139
# Epoch   9 Batch  340/1077 - Train Accuracy: 0.9942, Validation Accuracy: 0.9801, Loss: 0.0112
# Epoch   9 Batch  360/1077 - Train Accuracy: 0.9910, Validation Accuracy: 0.9684, Loss: 0.0063
# Epoch   9 Batch  380/1077 - Train Accuracy: 0.9926, Validation Accuracy: 0.9712, Loss: 0.0080
# Epoch   9 Batch  400/1077 - Train Accuracy: 0.9941, Validation Accuracy: 0.9805, Loss: 0.0111
# Epoch   9 Batch  420/1077 - Train Accuracy: 0.9824, Validation Accuracy: 0.9801, Loss: 0.0105
# Epoch   9 Batch  440/1077 - Train Accuracy: 0.9824, Validation Accuracy: 0.9826, Loss: 0.0118
# Epoch   9 Batch  460/1077 - Train Accuracy: 0.9934, Validation Accuracy: 0.9776, Loss: 0.0080
# Epoch   9 Batch  480/1077 - Train Accuracy: 0.9811, Validation Accuracy: 0.9688, Loss: 0.0102
# Epoch   9 Batch  500/1077 - Train Accuracy: 0.9945, Validation Accuracy: 0.9666, Loss: 0.0116
# Epoch   9 Batch  520/1077 - Train Accuracy: 0.9900, Validation Accuracy: 0.9854, Loss: 0.0056
# Epoch   9 Batch  540/1077 - Train Accuracy: 0.9824, Validation Accuracy: 0.9869, Loss: 0.0087
# Epoch   9 Batch  560/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9876, Loss: 0.0110
# Epoch   9 Batch  580/1077 - Train Accuracy: 0.9859, Validation Accuracy: 0.9858, Loss: 0.0087
# Epoch   9 Batch  600/1077 - Train Accuracy: 0.9851, Validation Accuracy: 0.9858, Loss: 0.0115
# Epoch   9 Batch  620/1077 - Train Accuracy: 0.9762, Validation Accuracy: 0.9805, Loss: 0.0108
# Epoch   9 Batch  640/1077 - Train Accuracy: 0.9885, Validation Accuracy: 0.9890, Loss: 0.0110
# Epoch   9 Batch  660/1077 - Train Accuracy: 0.9965, Validation Accuracy: 0.9727, Loss: 0.0079
# Epoch   9 Batch  680/1077 - Train Accuracy: 0.9781, Validation Accuracy: 0.9798, Loss: 0.0104
# Epoch   9 Batch  700/1077 - Train Accuracy: 0.9988, Validation Accuracy: 0.9659, Loss: 0.0110
# Epoch   9 Batch  720/1077 - Train Accuracy: 0.9885, Validation Accuracy: 0.9727, Loss: 0.0120
# Epoch   9 Batch  740/1077 - Train Accuracy: 0.9672, Validation Accuracy: 0.9776, Loss: 0.0138
# Epoch   9 Batch  760/1077 - Train Accuracy: 0.9895, Validation Accuracy: 0.9776, Loss: 0.0129
# Epoch   9 Batch  780/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9801, Loss: 0.0173
# Epoch   9 Batch  800/1077 - Train Accuracy: 0.9859, Validation Accuracy: 0.9773, Loss: 0.0103
# Epoch   9 Batch  820/1077 - Train Accuracy: 0.9902, Validation Accuracy: 0.9744, Loss: 0.0111
# Epoch   9 Batch  840/1077 - Train Accuracy: 0.9930, Validation Accuracy: 0.9901, Loss: 0.0136
# Epoch   9 Batch  860/1077 - Train Accuracy: 0.9862, Validation Accuracy: 0.9851, Loss: 0.0117
# Epoch   9 Batch  880/1077 - Train Accuracy: 0.9883, Validation Accuracy: 0.9897, Loss: 0.0116
# Epoch   9 Batch  900/1077 - Train Accuracy: 0.9824, Validation Accuracy: 0.9830, Loss: 0.0137
# Epoch   9 Batch  920/1077 - Train Accuracy: 0.9895, Validation Accuracy: 0.9798, Loss: 0.0118
# Epoch   9 Batch  940/1077 - Train Accuracy: 0.9918, Validation Accuracy: 0.9925, Loss: 0.0117
# Epoch   9 Batch  960/1077 - Train Accuracy: 0.9754, Validation Accuracy: 0.9844, Loss: 0.0140
# Epoch   9 Batch  980/1077 - Train Accuracy: 0.9742, Validation Accuracy: 0.9751, Loss: 0.0107
# Epoch   9 Batch 1000/1077 - Train Accuracy: 0.9803, Validation Accuracy: 0.9787, Loss: 0.0091
# Epoch   9 Batch 1020/1077 - Train Accuracy: 0.9871, Validation Accuracy: 0.9805, Loss: 0.0111
# Epoch   9 Batch 1040/1077 - Train Accuracy: 0.9770, Validation Accuracy: 0.9830, Loss: 0.0087
# Epoch   9 Batch 1060/1077 - Train Accuracy: 0.9953, Validation Accuracy: 0.9762, Loss: 0.0088
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    words = sentence.lower().split(' ')
    return [vocab_to_int.get(word, vocab_to_int['<UNK>']) for word in words]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [194, 94, 228, 222, 91, 151, 49]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [44, 157, 281, 199, 322, 211, 1]
#   French Words: il a vu un vieux camion <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
